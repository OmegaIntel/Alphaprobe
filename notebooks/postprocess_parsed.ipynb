# %%
import os
import pandas as pd

import anthropic
from dotenv import load_dotenv
from pdf2image import convert_from_path
import base64
import requests
from llama_index.core import Document

# %%
use_braintrust_dataset = True

COMPARISON_FILE = 'claude-3-5-sonnet-20240620_qa.csv'
PDF_LOCATION = 'IndustrySource/Misc/62 Healthcare and Social Assistance in the US Industry Report.pdf'
DOC_ID = 'ibis-healthcare-social-assistance'
MODEL_ID = 'gpt-4o-mini'
QUESTION_COL = 'question'
RESPONSE_COL = 'rag_model_response'
NUM_QUESTIONS = -1
PARSER = "claude" # "claude" or "llama-parse"
CHUNK_SIZE = 600
SPLITTER = "custom_tree"
TOP_K = 3
OUTPUT_FOLDER = f'./rag_outputs/{DOC_ID}'
if not os.path.exists(OUTPUT_FOLDER):
    os.makedirs(OUTPUT_FOLDER)
OUTPUT_FILE = f'{OUTPUT_FOLDER}/output_{MODEL_ID}_{PARSER}_{CHUNK_SIZE}_{SPLITTER}_{TOP_K}.csv'

# %%
import pickle
documents = pickle.load(open(f'./rag_outputs/ibis-healthcare-social-assistance_gpt-4o-mini_claude_600_sentence_3/_claude-3-5-sonnet-20240620_pages.pkl', 'rb'))

# %%
title = "Healthcare and Social Assistance in the US"
docs = [document.text for document in documents]

# %%
# iterate over docs and see if the first sentence contains the title, then remove the whole line from the text
all_sentences = []
for i, doc in enumerate(docs):
    sentences = doc.split("\n")
    # if title in sentences[0]:
    #     sentences = sentences[1:]
    all_sentences.append(sentences)

# %%
all_sentences[30]
# Out:
# ['# IBISWorld | Healthcare and Social Assistance in the US',
#  '',
#  'Mar 2024',
#  '',
#  "## How are the industry's products and services performing?",
#  '',
#  '### Hospitals are central to healthcare delivery',
#  '',
#  '- Hospitals provide inpatient and outpatient medical services (diagnostic, treatment, etc.) via physicians, nursing and other health services. This subsector includes Hospitals (IBISWorld 62211), Psychiatric Hospitals (62221) and Specialty Hospitals (62231).',
#  '',
#  '- Rising incomes, broader access to public and private insurance programs and the medical needs of older citizens sustained hospital patient volumes before the COVID-19 pandemic. Yet hospitals were hit particularly hard by the drop in elective procedures and patient volumes following the onset of the pandemic.',
#  '',
#  '- Federal policies and billions of dollars in funding directed to hospitals alleviated the initial financial impact of revenue loss stemming from delays in elective care and drops in ER visits. According to the Kaiser Family Foundation (KFF), the size of grants varied significantly per hospital based on the payor mix.',
#  '',
#  '- Rapidly escalating costs for medical consumables, equipment and pharmaceuticals along with staffing shortages and employee burnout combine to create instability in the sector.',
#  '',
#  "- Financial pressures have accelerated hospitals' shift away from inpatient care. The popularity of telemedicine, an uptick in ambulatory surgery centers (ASCs) and new medical technologies facilitate the transition to outpatient care.",
#  '',
#  '### Ambulatory healthcare services are an alternative care site',
#  '',
#  "- Ambulatory healthcare service providers deliver healthcare services to patients and don't provide inpatient services. The primary industries in this subsector include Specialist Doctors (62111b), Primary Care Doctors (62111a) and Dentists (62121).",
#  '',
#  '- Rising incomes and expanding insurance coverage have facilitated access to ambulatory healthcare service providers. The medical needs of older people also create demand for these providers, and adults of advanced age exhibit the highest consumption of healthcare services.',
#  '',
#  '- Patient volumes dropped in 2020 as patients adopted stay-at-home measures and offices temporarily closed. These closures resulted in long care backlogs, leading patients to fulfill pent-up need for ambulatory medical services as vaccines became available and lockdowns lifted.',
#  '',
#  "- Extensive staffing shortages at ambulatory healthcare service providers compromise these facilities' ability to meet demand.",
#  '',
#  '- Consolidation activity is occurring across this subsector. The COVID-19 pandemic accelerated this trend, but rapidly growing demand and continual staffing shortages incentivize small providers to merge with larger health groups.',
#  '',
#  '- Primary care and dental practices both demonstrate consolidation activity. Smaller practices are joining larger health systems or private equity-backed groups to reap the benefits of negotiating power and economies of scale.',
#  '',
#  '### Nursing and residential care facilities are critical for people over 65',
#  '',
#  '- Nursing and residential care facilities provide residential care combined with either nursing, supervisory or medical care services. Key industries in this subsector include Nursing Care Facilities']

# %%
all_sentences[4]
# Out:
# ['# 1. About',
#  '',
#  'https://my.ibisworld.com/us/en/industry/62/about',
#  '',
#  '## Codes',
#  '',
#  '| NAICS 2017 - USA | 62 |',
#  '|-------------------|-----|',
#  '| NAICS 2022 - USA | 62 |',
#  '',
#  'The table shows the NAICS (North American Industry Classification System) codes for the Healthcare and Social Assistance sector in the USA. Both the 2017 and 2022 versions of NAICS assign the code 62 to this sector, indicating consistency in classification over time.',
#  '',
#  '## Definition',
#  '',
#  'The Healthcare and Social Assistance sector is composed of enterprises that provide healthcare and social assistance for individuals in the United States, including hospitals, ambulatory service providers and nursing and residential care facilities. Social assistance also includes counselors and social workers, family and welfare services and natural disaster and emergency relief services.',
#  '',
#  '## Related Terms',
#  '',
#  '### ELECTRONIC HEALTH RECORD (EHR)',
#  '',
#  'The systematic collection and maintenance of electronic health information about an individual patient.',
#  '',
#  '### TELEMEDICINE',
#  '',
#  'An application of clinical medicine whereby medical information is transferred through interactive audiovisual media for the purpose of consulting and remote medical procedures or examinations.',
#  '',
#  '### HEALTH INSURANCE EXCHANGE',
#  '',
#  'A set of state-regulated and standardized healthcare plans from which individuals may purchase health insurance eligible for federal subsidies.',
#  '',
#  '### FEE-FOR-SERVICE',
#  '',
#  'A health plan where individuals choose the doctor, hospital or clinic and the insurance pays for part or all of the cost according to a schedule laid out in the policy.',
#  '',
#  '### MEDICARE AND MEDICAID',
#  '',
#  'Cost-coverage programs. Medicare pays all or part of a stay following hospitalization of at least three days; Medicaid covers a stay of any length for individuals who meet income requirements.',
#  '',
#  '### LONG-TERM CARE',
#  '',
#  "Treatment for a chronic condition, trauma, or illness that limits a person's ability to carry out basic self-care tasks, called activities of daily living (ADLs).",
#  '',
#  '### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)',
#  '',
#  'A federal agency designed to prepare for, mitigate against, respond to and help individuals and communities recover from natural and man-made disasters.']

# %%
headings = []

for i, sentences in enumerate(all_sentences):
    for j, sentence in enumerate(sentences):
        # sentence is a heading if it starts with # or ## or ### or #### or #####
        if sentence.startswith("#"):
            headings.append({"text": sentence, "page": i+1, "sentence_number": j+1})

headings[:20]
# Out:
# [{'text': '# IBISWorld', 'page': 1, 'sentence_number': 1},
#  {'text': '## INDUSTRY REPORT', 'page': 1, 'sentence_number': 3},
#  {'text': '# Healthcare and Social Assistance in the US',
#   'page': 1,
#   'sentence_number': 5},
#  {'text': '### Mar 2024', 'page': 1, 'sentence_number': 7},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US Mar 2024',
#   'page': 2,
#   'sentence_number': 1},
#  {'text': '## About IBISWorld', 'page': 2, 'sentence_number': 3},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 3,
#   'sentence_number': 1},
#  {'text': '## Table Of Contents', 'page': 3, 'sentence_number': 5},
#  {'text': '# About', 'page': 4, 'sentence_number': 1},
#  {'text': '# 1. About', 'page': 5, 'sentence_number': 1},
#  {'text': '## Codes', 'page': 5, 'sentence_number': 5},
#  {'text': '## Definition', 'page': 5, 'sentence_number': 13},
#  {'text': '## Related Terms', 'page': 5, 'sentence_number': 17},
#  {'text': '### ELECTRONIC HEALTH RECORD (EHR)',
#   'page': 5,
#   'sentence_number': 19},
#  {'text': '### TELEMEDICINE', 'page': 5, 'sentence_number': 23},
#  {'text': '### HEALTH INSURANCE EXCHANGE', 'page': 5, 'sentence_number': 27},
#  {'text': '### FEE-FOR-SERVICE', 'page': 5, 'sentence_number': 31},
#  {'text': '### MEDICARE AND MEDICAID', 'page': 5, 'sentence_number': 35},
#  {'text': '### LONG-TERM CARE', 'page': 5, 'sentence_number': 39},
#  {'text': '### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)',
#   'page': 5,
#   'sentence_number': 43}]

# %%
len(headings)
# Out:
# 300

# %%
HEADINGS_PROMPT = ''' You will be given a text containing headings and subheadings parsed from the market research report of the industry 'Healthcare and Social Assistance in the US' in markdown format. 
However, the issue is that these subheadings were parsed one page at a time. So this makes it possible that the structure of the document is not preserved.
The heading 2 in the document might be parsed as heading 1 if it is the first heading on the page. Similarly, all the following subheadings on the same page might be parsed as different heading levels.
However, the order of the headings is preserved from top to bottom of each page. So you don't have to worry about the order of the headings.
Other issue is that parsed headings/ subheadings may accidentally include date or page number or report title that might have been present as a header or footer in the document.
Your task is to identify the correct structure of the document by taking into account the semantic meanings of the headings and subheadings.
Your input will be a text file with each line starting with <page_number, line_number> of the heading/ subheading followed by the heading or subheading text starting with # or ## or ### or #### or ##### denoting heading 1, heading 2, heading 3, heading 4 and heading 5 respectively.
Your output will be a text file with each line containing the same <page_number, line_number> as the one in input followed by the heading or subheading text with the correct heading level denoted by # or ## or ### or #### or #####. 
You must not change the page number and line number of the respective heading or subheading. You may entrirely remove the heading or subheading if it is a report title or date that was incorrectly parsed as a heading. Otherwise, you should correct the heading level if you think it was parsed incorrectly.
'''

SYSTEM_MESSAGE = "You are an expert in identifying the correct structure of a document by taking into account the page numbers, line numbers and the semantic meanings of the headings and subheadings."

FINAL_MESSAGE = "Please identify the correct structure of the document by taking into account the page numbers, line numbers and the semantic meanings of the headings and subheadings. Output the headings with the correct heading level denoted by # or ## or ### or #### or #####."

# %%
# llama-parse is async-first, running the async code in a notebook requires the use of nest_asyncio
load_dotenv("/Users/mbajaj/.env")
# API access to llama-cloud
os.environ["LLAMA_CLOUD_API_KEY"] = os.getenv('LLAMA_CLOUD_API_KEY')
# Using OpenAI API for embeddings/llms
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')
os.environ["ANTHROPIC_API_KEY"] = os.getenv('ANTHROPIC_API_KEY')
os.environ["BRAINTRUST_API_KEY"]=os.getenv('BRAINTRUST_API_KEY')
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# %%
input_text = ""
for heading in headings:
    input_text += f"<{heading['page']}, {heading['sentence_number']}> {heading['text']}\n"
input_text
# Out:
# "<1, 1> # IBISWorld\n<1, 3> ## INDUSTRY REPORT\n<1, 5> # Healthcare and Social Assistance in the US\n<1, 7> ### Mar 2024\n<2, 1> # IBISWorld | Healthcare and Social Assistance in the US Mar 2024\n<2, 3> ## About IBISWorld\n<3, 1> # IBISWorld | Healthcare and Social Assistance in the US\n<3, 5> ## Table Of Contents\n<4, 1> # About\n<5, 1> # 1. About\n<5, 5> ## Codes\n<5, 13> ## Definition\n<5, 17> ## Related Terms\n<5, 19> ### ELECTRONIC HEALTH RECORD (EHR)\n<5, 23> ### TELEMEDICINE\n<5, 27> ### HEALTH INSURANCE EXCHANGE\n<5, 31> ### FEE-FOR-SERVICE\n<5, 35> ### MEDICARE AND MEDICAID\n<5, 39> ### LONG-TERM CARE\n<5, 43> ### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)\n<6, 1> # IBISWorld | Healthcare and Social Assistance in the US\n<6, 5> ## GROUP HOME\n<6, 9> ## MANAGED CARE\n<6, 13> ## What's Included\n<6, 20> ## Companies\n<6, 28> ## Related Industries\n<6, 30> ### Industries in the Same Sector\n<6, 40> ### International Industries\n<6, 46> ## Additional Resources\n<7, 1> # IBISWorld | Healthcare and Social Assistance in the US Mar 2024\n<8, 1> # At a Glance\n<9, 1> # IBISWorld | Healthcare and Social Assistance in the US\n<9, 3> ## 2. At a Glance\n<9, 19> ## Key Takeaways\n<9, 21> ### Performance\n<9, 26> ### External Environment\n<10, 1> # IBISWorld | Healthcare and Social Assistance in the US\n<10, 5> ## Products and Services\n<10, 7> ### Products & Services Segmentation\n<11, 1> # IBISWorld | Healthcare and Social Assistance in the US Mar 2024\n<11, 3> ## Major Players\n<11, 5> ### Major Players\n<12, 1> # IBISWorld | Healthcare and Social Assistance in the US\n<12, 5> ## Key External Drivers\n<12, 16> ## Industry Structure\n<13, 1> # IBISWorld | Healthcare and Social Assistance in the US Mar 2024\n<13, 3> ## SWOT\n<13, 5> ### Strengths\n<13, 11> ### Weaknesses\n<13, 14> ### Opportunities\n<13, 20> ### Threats\n<13, 25> ## Executive Summary\n<14, 1> # Performance\n<15, 1> # IBISWorld | Healthcare and Social Assistance in the US\n<15, 3> ## 3. Performance\n<15, 7> ### Highlights\n<15, 19> ### Key Takeaways\n<16, 1> # IBISWorld | Healthcare and Social Assistance in the US Mar 2024\n<16, 3> ## Performance Snapshot\n<16, 5> ### Revenue:\n<16, 9> ### Revenue\n<16, 13> ### 2024 Revenue CAGR\n<16, 17> ### Revenue Volatility\n<16, 21> ### Revenue\n<17, 1> # IBISWorld | Healthcare and Social Assistance in the US Mar 2024\n<17, 3> ## Employees:\n<17, 7> ### Key Metrics:\n<17, 17> ## Employees\n<18, 1> # IBISWorld | Healthcare and Social Assistance in the US\n<18, 5> ## Businesses:\n<18, 17> ## Business\n<19, 1> # IBISWorld | Healthcare and Social Assistance in the US\n<19, 5> ## Profit:\n<19, 9> ### Key Metrics:\n<19, 17> ## Healthcare and Social Assistance in the US\n<19, 19> ### Profit Margin\n<20, 1> # IBISWorld | Healthcare and Social Assistance in the US\n<20, 5> ## Current Performance\n<20, 7> ### What's driving current industry performance?\n<20, 9> #### Demographic trends shape the healthcare landscape\n<20, 17> #### Healthcare providers grapple with persistent workforce shortages\n<20, 27> #### The pandemic accelerated existing consolidation trends in healthcare\n<21, 1> # IBISWorld | Healthcare and Social Assistance in the US Mar 2024\n<21, 7> ## Social assistance providers fill in the gaps as pandemic-era benefits end\n<22, 1> # IBISWorld | Healthcare and Social Assistance in the US\n<22, 5> ## What influences industry volatility?\n<22, 7> ### Healthcare services are vital to public health\n<22, 17> ### Healthcare facilities' financial health relies on reimbursements\n<22, 23> ### COVID-19 strains healthcare delivery\n<23, 1> # IBISWorld | Healthcare and Social Assistance in the US Mar 2024\n<23, 3> ## Low & slow\n<23, 19> ## Key Success Factor\n<23, 21> ### How do successful businesses overcome volatility?\n<23, 23> #### Ability to take advantage of government subsidies and other grants\n<23, 27> #### Secure a multiskilled workforce\n<24, 1> # IBISWorld | Healthcare and Social Assistance in the US\n<25, 1> # IBISWorld | ...

# %%
import anthropic

from llama_index.core import Document

client = anthropic.Anthropic()
model = "claude-3-5-sonnet-20240620"

response = client.messages.create(
    model=model,
    max_tokens=5000,
    system = SYSTEM_MESSAGE,
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": HEADINGS_PROMPT},
                {
                    "type": "text",
                    "text": input_text
                },
                {"type": "text", "text": FINAL_MESSAGE},
            ],
        }
    ],
)

# %%
output = response.content[0].text
output
# Out:
# "Here's the corrected structure of the document with appropriate heading levels:\n\n<1, 5> # Healthcare and Social Assistance in the US\n\n<2, 3> ## About IBISWorld\n\n<3, 5> ## Table Of Contents\n\n<5, 1> ## About\n<5, 5> ### Codes\n<5, 13> ### Definition\n<5, 17> ### Related Terms\n<5, 19> #### ELECTRONIC HEALTH RECORD (EHR)\n<5, 23> #### TELEMEDICINE\n<5, 27> #### HEALTH INSURANCE EXCHANGE\n<5, 31> #### FEE-FOR-SERVICE\n<5, 35> #### MEDICARE AND MEDICAID\n<5, 39> #### LONG-TERM CARE\n<5, 43> #### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)\n<6, 5> #### GROUP HOME\n<6, 9> #### MANAGED CARE\n<6, 13> ### What's Included\n<6, 20> ### Companies\n<6, 28> ### Related Industries\n<6, 30> #### Industries in the Same Sector\n<6, 40> #### International Industries\n<6, 46> ### Additional Resources\n\n<9, 3> ## At a Glance\n<9, 19> ### Key Takeaways\n<9, 21> #### Performance\n<9, 26> #### External Environment\n\n<10, 5> ### Products and Services\n<10, 7> #### Products & Services Segmentation\n\n<11, 3> ### Major Players\n<11, 5> #### Major Players\n\n<12, 5> ### Key External Drivers\n\n<12, 16> ### Industry Structure\n\n<13, 3> ### SWOT\n<13, 5> #### Strengths\n<13, 11> #### Weaknesses\n<13, 14> #### Opportunities\n<13, 20> #### Threats\n\n<13, 25> ### Executive Summary\n\n<15, 3> ## Performance\n<15, 7> ### Highlights\n<15, 19> ### Key Takeaways\n\n<16, 3> ### Performance Snapshot\n<16, 5> #### Revenue\n<16, 17> #### Employees\n<18, 5> #### Businesses\n<19, 5> #### Profit\n\n<20, 5> ### Current Performance\n<20, 7> #### What's driving current performance?\n<20, 9> ##### Demographic trends shape the healthcare landscape\n<20, 17> ##### Healthcare providers grapple with persistent workforce shortages\n<20, 27> ##### The pandemic accelerated existing consolidation trends in healthcare\n<21, 7> ##### Social assistance providers fill in the gaps as pandemic-era benefits end\n\n<22, 5> ### What influences industry volatility?\n<22, 7> #### Healthcare services are vital to public health\n<22, 17> #### Healthcare facilities' financial health relies on reimbursements\n<22, 23> #### COVID-19 strains healthcare delivery\n\n<23, 19> ### Key Success Factor\n<23, 21> #### How do successful businesses overcome volatility?\n<23, 23> ##### Ability to take advantage of government subsidies and other grants\n<23, 27> ##### Secure a multiskilled workforce\n\n<25, 5> ### Outlook\n<25, 9> #### What's driving the industry outlook?\n<25, 11> ##### Demographic trends are behind rising healthcare spending\n<25, 19> ##### The pandemic's long-term effects are emerging\n<25, 29> ##### Tech advances will reshape healthcare delivery\n<26, 9> ##### Financial pressures will accelerate consolidation activity\n\n<28, 5> ### Life Cycle: Growth\n<28, 7> #### Why is the industry growing?\n<28, 9> ##### Contribution to GDP\n<28, 13> ##### Market Saturation\n<28, 17> ##### Innovation\n<28, 21> ##### Consolidation\n<28, 25> ##### Technology & Systems\n\n<30, 3> ## Products and Markets\n<30, 11> ### Key Takeaways\n<30, 16> ### Products and Services\n<30, 18> #### Products & Services Segmentation\n\n<31, 5> ### How are the industry's products and services performing?\n<31, 7> #### Hospitals are central to healthcare delivery\n<31, 19> #### Ambulatory healthcare services are an alternative care site\n<31, 33> #### Nursing and residential care facilities are critical for people over 65\n<32, 13> #### Social assistance providers have an outsized role\n\n<32, 21> ### What are innovations in industry products and services?\n<32, 23> #### Budding artificial intelligence partnerships are transforming service delivery\n<32, 29> #### Digital health applications abound\n\n<34, 5> ### Key Success Factor\n<34, 7> #### What products or services do successful businesses offer?\n\n<35, 3> ### Major Markets\n<35, 5> #### Major Market Segmentation\n<35, 10> #### What's influencing demand from the industry's markets?\n<35, 12> ##### Private insurers are the largest payer to healthcare and social  ...

# %%
# headings[:100]

# %%
output_list = output.split("\n")
# filter output list that do not start with <
output_list = [line for line in output_list if line.lstrip().startswith("<")]
print(len(output_list))
output_list[:100]
# Out:
# 207
# ['<1, 5> # Healthcare and Social Assistance in the US',
#  '<2, 3> ## About IBISWorld',
#  '<3, 5> ## Table Of Contents',
#  '<5, 1> ## About',
#  '<5, 5> ### Codes',
#  '<5, 13> ### Definition',
#  '<5, 17> ### Related Terms',
#  '<5, 19> #### ELECTRONIC HEALTH RECORD (EHR)',
#  '<5, 23> #### TELEMEDICINE',
#  '<5, 27> #### HEALTH INSURANCE EXCHANGE',
#  '<5, 31> #### FEE-FOR-SERVICE',
#  '<5, 35> #### MEDICARE AND MEDICAID',
#  '<5, 39> #### LONG-TERM CARE',
#  '<5, 43> #### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)',
#  '<6, 5> #### GROUP HOME',
#  '<6, 9> #### MANAGED CARE',
#  "<6, 13> ### What's Included",
#  '<6, 20> ### Companies',
#  '<6, 28> ### Related Industries',
#  '<6, 30> #### Industries in the Same Sector',
#  '<6, 40> #### International Industries',
#  '<6, 46> ### Additional Resources',
#  '<9, 3> ## At a Glance',
#  '<9, 19> ### Key Takeaways',
#  '<9, 21> #### Performance',
#  '<9, 26> #### External Environment',
#  '<10, 5> ### Products and Services',
#  '<10, 7> #### Products & Services Segmentation',
#  '<11, 3> ### Major Players',
#  '<11, 5> #### Major Players',
#  '<12, 5> ### Key External Drivers',
#  '<12, 16> ### Industry Structure',
#  '<13, 3> ### SWOT',
#  '<13, 5> #### Strengths',
#  '<13, 11> #### Weaknesses',
#  '<13, 14> #### Opportunities',
#  '<13, 20> #### Threats',
#  '<13, 25> ### Executive Summary',
#  '<15, 3> ## Performance',
#  '<15, 7> ### Highlights',
#  '<15, 19> ### Key Takeaways',
#  '<16, 3> ### Performance Snapshot',
#  '<16, 5> #### Revenue',
#  '<16, 17> #### Employees',
#  '<18, 5> #### Businesses',
#  '<19, 5> #### Profit',
#  '<20, 5> ### Current Performance',
#  "<20, 7> #### What's driving current performance?",
#  '<20, 9> ##### Demographic trends shape the healthcare landscape',
#  '<20, 17> ##### Healthcare providers grapple with persistent workforce shortages',
#  '<20, 27> ##### The pandemic accelerated existing consolidation trends in healthcare',
#  '<21, 7> ##### Social assistance providers fill in the gaps as pandemic-era benefits end',
#  '<22, 5> ### What influences industry volatility?',
#  '<22, 7> #### Healthcare services are vital to public health',
#  "<22, 17> #### Healthcare facilities' financial health relies on reimbursements",
#  '<22, 23> #### COVID-19 strains healthcare delivery',
#  '<23, 19> ### Key Success Factor',
#  '<23, 21> #### How do successful businesses overcome volatility?',
#  '<23, 23> ##### Ability to take advantage of government subsidies and other grants',
#  '<23, 27> ##### Secure a multiskilled workforce',
#  '<25, 5> ### Outlook',
#  "<25, 9> #### What's driving the industry outlook?",
#  '<25, 11> ##### Demographic trends are behind rising healthcare spending',
#  "<25, 19> ##### The pandemic's long-term effects are emerging",
#  '<25, 29> ##### Tech advances will reshape healthcare delivery',
#  '<26, 9> ##### Financial pressures will accelerate consolidation activity',
#  '<28, 5> ### Life Cycle: Growth',
#  '<28, 7> #### Why is the industry growing?',
#  '<28, 9> ##### Contribution to GDP',
#  '<28, 13> ##### Market Saturation',
#  '<28, 17> ##### Innovation',
#  '<28, 21> ##### Consolidation',
#  '<28, 25> ##### Technology & Systems',
#  '<30, 3> ## Products and Markets',
#  '<30, 11> ### Key Takeaways',
#  '<30, 16> ### Products and Services',
#  '<30, 18> #### Products & Services Segmentation',
#  "<31, 5> ### How are the industry's products and services performing?",
#  '<31, 7> #### Hospitals are central to healthcare delivery',
#  '<31, 19> #### Ambulatory healthcare services are an alternative care site',
#  '<31, 33> #### Nursing and residential care facilities are critical for people over 65',
#  '<32, 13> #### Social assistance providers have an outsized role',
#  '<32, 21> ### What are innovations in industry products and services?',
#  '<32, 23> #### Budding artificial intelligence partnerships are transforming service delivery',
#  '<32, 29> #### Digital health applications abound',
#  '<34, 5> ### Key Success Factor',
#  '<34, 7> #### What products or services do successful businesses offer?',
#  '<35, 3> ### Major Markets',
#  '<35, 5> #### Major Market Segmentation',
#  "<35, 10> #### What's influencing demand from the industry's markets?",
#  '<35, 12> ##### Private insurers are the largest payer to healthcare and social assistance providers',
#  '<35, 18> ##### Public insurers pay more as older adults age',
#  '<36, 11> ##### Insurance limitations create out-of-pocket costs',
#  '<36, 21> ##### Healthcare and social assistance receive payments from a mix of sources',
#  '<37, 5> ### International Trade',
#  '<39, 3> ## Geographic Breakdown',
#  '<39, 7> ### Key Takeaways',
#  '<40, 3> ### Business Locations',
#  '<40, 5> #### Business Concentration',
#  '<43, 5> ### Where are industry businesses located?']

# %%
headings[:100]
# Out:
# [{'text': '# IBISWorld', 'page': 1, 'sentence_number': 1},
#  {'text': '## INDUSTRY REPORT', 'page': 1, 'sentence_number': 3},
#  {'text': '# Healthcare and Social Assistance in the US',
#   'page': 1,
#   'sentence_number': 5},
#  {'text': '### Mar 2024', 'page': 1, 'sentence_number': 7},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US Mar 2024',
#   'page': 2,
#   'sentence_number': 1},
#  {'text': '## About IBISWorld', 'page': 2, 'sentence_number': 3},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 3,
#   'sentence_number': 1},
#  {'text': '## Table Of Contents', 'page': 3, 'sentence_number': 5},
#  {'text': '# About', 'page': 4, 'sentence_number': 1},
#  {'text': '# 1. About', 'page': 5, 'sentence_number': 1},
#  {'text': '## Codes', 'page': 5, 'sentence_number': 5},
#  {'text': '## Definition', 'page': 5, 'sentence_number': 13},
#  {'text': '## Related Terms', 'page': 5, 'sentence_number': 17},
#  {'text': '### ELECTRONIC HEALTH RECORD (EHR)',
#   'page': 5,
#   'sentence_number': 19},
#  {'text': '### TELEMEDICINE', 'page': 5, 'sentence_number': 23},
#  {'text': '### HEALTH INSURANCE EXCHANGE', 'page': 5, 'sentence_number': 27},
#  {'text': '### FEE-FOR-SERVICE', 'page': 5, 'sentence_number': 31},
#  {'text': '### MEDICARE AND MEDICAID', 'page': 5, 'sentence_number': 35},
#  {'text': '### LONG-TERM CARE', 'page': 5, 'sentence_number': 39},
#  {'text': '### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)',
#   'page': 5,
#   'sentence_number': 43},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 6,
#   'sentence_number': 1},
#  {'text': '## GROUP HOME', 'page': 6, 'sentence_number': 5},
#  {'text': '## MANAGED CARE', 'page': 6, 'sentence_number': 9},
#  {'text': "## What's Included", 'page': 6, 'sentence_number': 13},
#  {'text': '## Companies', 'page': 6, 'sentence_number': 20},
#  {'text': '## Related Industries', 'page': 6, 'sentence_number': 28},
#  {'text': '### Industries in the Same Sector',
#   'page': 6,
#   'sentence_number': 30},
#  {'text': '### International Industries', 'page': 6, 'sentence_number': 40},
#  {'text': '## Additional Resources', 'page': 6, 'sentence_number': 46},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US Mar 2024',
#   'page': 7,
#   'sentence_number': 1},
#  {'text': '# At a Glance', 'page': 8, 'sentence_number': 1},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 9,
#   'sentence_number': 1},
#  {'text': '## 2. At a Glance', 'page': 9, 'sentence_number': 3},
#  {'text': '## Key Takeaways', 'page': 9, 'sentence_number': 19},
#  {'text': '### Performance', 'page': 9, 'sentence_number': 21},
#  {'text': '### External Environment', 'page': 9, 'sentence_number': 26},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 10,
#   'sentence_number': 1},
#  {'text': '## Products and Services', 'page': 10, 'sentence_number': 5},
#  {'text': '### Products & Services Segmentation',
#   'page': 10,
#   'sentence_number': 7},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US Mar 2024',
#   'page': 11,
#   'sentence_number': 1},
#  {'text': '## Major Players', 'page': 11, 'sentence_number': 3},
#  {'text': '### Major Players', 'page': 11, 'sentence_number': 5},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 12,
#   'sentence_number': 1},
#  {'text': '## Key External Drivers', 'page': 12, 'sentence_number': 5},
#  {'text': '## Industry Structure', 'page': 12, 'sentence_number': 16},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US Mar 2024',
#   'page': 13,
#   'sentence_number': 1},
#  {'text': '## SWOT', 'page': 13, 'sentence_number': 3},
#  {'text': '### Strengths', 'page': 13, 'sentence_number': 5},
#  {'text': '### Weaknesses', 'page': 13, 'sentence_number': 11},
#  {'text': '### Opportunities', 'page': 13, 'sentence_number': 14},
#  {'text': '### Threats', 'page': 13, 'sentence_number': 20},
#  {'text': '## Executive Summary', 'page': 13, 'sentence_number': 25},
#  {'text': '# Performance', 'page': 14, 'sentence_number': 1},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 15,
#   'sentence_number': 1},
#  {'text': '## 3. Performance', 'page': 15, 'sentence_number': 3},
#  {'text': '### Highlights', 'page': 15, 'sentence_number': 7},
#  {'text': '### Key Takeaways', 'page': 15, 'sentence_number': 19},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US Mar 2024',
#   'page': 16,
#   'sentence_number': 1},
#  {'text': '## Performance Snapshot', 'page': 16, 'sentence_number': 3},
#  {'text': '### Revenue:', 'page': 16, 'sentence_number': 5},
#  {'text': '### Revenue', 'page': 16, 'sentence_number': 9},
#  {'text': '### 2024 Revenue CAGR', 'page': 16, 'sentence_number': 13},
#  {'text': '### Revenue Volatility', 'page': 16, 'sentence_number': 17},
#  {'text': '### Revenue', 'page': 16, 'sentence_number': 21},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US Mar 2024',
#   'page': 17,
#   'sentence_number': 1},
#  {'text': '## Employees:', 'page': 17, 'sentence_number': 3},
#  {'text': '### Key Metrics:', 'page': 17, 'sentence_number': 7},
#  {'text': '## Employees', 'page': 17, 'sentence_number': 17},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 18,
#   'sentence_number': 1},
#  {'text': '## Businesses:', 'page': 18, 'sentence_number': 5},
#  {'text': '## Business', 'page': 18, 'sentence_number': 17},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 19,
#   'sentence_number': 1},
#  {'text': '## Profit:', 'page': 19, 'sentence_number': 5},
#  {'text': '### Key Metrics:', 'page': 19, 'sentence_number': 9},
#  {'text': '## Healthcare and Social Assistance in the US',
#   'page': 19,
#   'sentence_number': 17},
#  {'text': '### Profit Margin', 'page': 19, 'sentence_number': 19},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 20,
#   'sentence_number': 1},
#  {'text': '## Current Performance', 'page': 20, 'sentence_number': 5},
#  {'text': "### What's driving current industry performance?",
#   'page': 20,
#   'sentence_number': 7},
#  {'text': '#### Demographic trends shape the healthcare landscape',
#   'page': 20,
#   'sentence_number': 9},
#  {'text': '#### Healthcare providers grapple with persistent workforce shortages',
#   'page': 20,
#   'sentence_number': 17},
#  {'text': '#### The pandemic accelerated existing consolidation trends in healthcare',
#   'page': 20,
#   'sentence_number': 27},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US Mar 2024',
#   'page': 21,
#   'sentence_number': 1},
#  {'text': '## Social assistance providers fill in the gaps as pandemic-era benefits end',
#   'page': 21,
#   'sentence_number': 7},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 22,
#   'sentence_number': 1},
#  {'text': '## What influences industry volatility?',
#   'page': 22,
#   'sentence_number': 5},
#  {'text': '### Healthcare services are vital to public health',
#   'page': 22,
#   'sentence_number': 7},
#  {'text': "### Healthcare facilities' financial health relies on reimbursements",
#   'page': 22,
#   'sentence_number': 17},
#  {'text': '### COVID-19 strains healthcare delivery',
#   'page': 22,
#   'sentence_number': 23},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US Mar 2024',
#   'page': 23,
#   'sentence_number': 1},
#  {'text': '## Low & slow', 'page': 23, 'sentence_number': 3},
#  {'text': '## Key Success Factor', 'page': 23, 'sentence_number': 19},
#  {'text': '### How do successful businesses overcome volatility?',
#   'page': 23,
#   'sentence_number': 21},
#  {'text': '#### Ability to take advantage of government subsidies and other grants',
#   'page': 23,
#   'sentence_number': 23},
#  {'text': '#### Secure a multiskilled workforce',
#   'page': 23,
#   'sentence_number': 27},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 24,
#   'sentence_number': 1},
#  {'text': '# IBISWorld | Healthcare and Social Assistance in the US',
#   'page': 25,
#   'sentence_number': 1},
#  {'text': '## Outlook', 'page': 25, 'sentence_number': 5},
#  {'text': "## What's driving the industry outlook?",
#   'page': 25,
#   'sentence_number': 9},
#  {'text': '### Demographic trends are behind rising healthcare spending',
#   'page': 25,
#   'sentence_number': 11}]

# %%
class Node:
    def __init__(self, heading, level, page, line_number, refined_output_idx):
        self.heading = heading
        self.text = None
        self.level = level
        self.page = page
        self.line_number = line_number
        self.children = []
        self.parent = None
        self.self_index = None
        self.is_partial_node = False
        self.is_partial_node_parent = False
        self.text_size = 0
        self.refined_output_idx = refined_output_idx  
        self.embedding_text = None      
    
    def add_child(self, child):
        child.self_index = len(self.children)
        self.children.append(child)
        child.parent = self
    
    def __repr__(self):
        return f"self index: {self.self_index} level: {self.level} loc: <{self.page, self.line_number}> content: {self.heading}"
    
    def __str__(self):
        return f"self index: {self.self_index} level: {self.level} loc: <{self.page, self.line_number}> content: {self.heading}"

# %%
# make a tree structure of the headings and subheadings from output_list such as level 1 is parent of level 2 and so on

def get_level(heading):
    text = heading.lstrip()
    level = 0
    for char in text:
        if char == "#":
            level += 1
        else:
            break
    return level

def get_fields_from_line(text):
    level = 0
    line = text.lstrip()
    if line.startswith("<"):
        prefix = (line.split("> ")[0]).split("<")[1]
        page, line_number = int(prefix.split(",")[0]), int(prefix.split(",")[1])
        heading = line.split("> ")[1]
        level = get_level(heading)
        return page, line_number, heading, level
    else:
        return None, None, None, level


root = Node(heading="", level=0, page=0, line_number=0, refined_output_idx=-1)
parent = root
# construct the tree
# TODO: take page, line_number from the input instead of output to avoid any issues

refined_output = []
for i in range(len(output_list)):
    page, line_number, heading, level = get_fields_from_line(output_list[i])
    if level == 0:
        continue
    if level > parent.level:
        child = Node(heading, level, page, line_number, len(refined_output))
        parent.add_child(child)
        parent = child
    elif level == parent.level:
        child = Node(heading, level, page, line_number, len(refined_output))
        parent.parent.add_child(child)
        parent = child
    else: # level < parent.level
        while level < parent.level:
            parent = parent.parent
        child = Node(heading, level, page, line_number, len(refined_output))
        if level == parent.level:
            parent.parent.add_child(child)
        else:
            parent.add_child(child)
        parent = child
    refined_output.append((page, line_number, heading, level))

# %%
def get_node_text(node):
    if node.text is not None:
        return node.text
    
    if node.level == 0:
        return ""
    page = node.page
    line_number = node.line_number
    # check if there is any heading after this
    if len(refined_output) > node.refined_output_idx + 1:
        next_heading = refined_output[node.refined_output_idx + 1]
        next_page, next_line_number, next_heading_text, next_level = next_heading
        # get text between this heading and next heading using all_sentences
        text = ""
        if page == next_page:
            if line_number + 1 < next_line_number:
                text += "\n".join(all_sentences[page-1][line_number:next_line_number-1])
        else:
            text += "\n".join(all_sentences[page-1][line_number:])
            for p in range(page+1, next_page):
                text += "\n".join(all_sentences[p-1])
            text += "\n".join(all_sentences[next_page-1][:next_line_number-1])
        return text
    else:
        # get text from this heading to the end of the page
        text = "\n".join(all_sentences[page-1][line_number:])
        for p in range(page+1, len(all_sentences)):
            text += "\n".join(all_sentences[p-1])
        return text

# %%
# split text to chunk sizes less than 1024

def split_text_to_chunk_size(text, target_size=1024):
    text_sentences = text.split("\n")
    chunks = []
    current_chunk_len = 0
    current_chunk = ""
    for sentence in text_sentences:
        sentence_len = len(sentence.split(" "))
        if current_chunk_len + sentence_len < target_size:
            current_chunk += sentence + "\n"
            current_chunk_len += sentence_len
        else:
            chunks.append(current_chunk)
            current_chunk = sentence + "\n"
            current_chunk_len = sentence_len
    if current_chunk_len > 0:
        chunks.append(current_chunk)
    return chunks

# %%
# let's traverse the tree and see if we need to split some nodes into multiple nodes due to text size more than selected chunk size

# do pre-order traversal 



def set_text_and_split_necessary_nodes(node, splitter_func, chunk_size=500):
    if node.text is None:
        text = get_node_text(node)
        text_size = len(text.split(" "))
    else:
        text = node.text
        text_size = node.text_size
    
    if text_size > chunk_size:
        print("Splitting node: ", node.refined_output_idx)
        # split the node into multiple nodes
        text_chunks = splitter_func(text, target_size=chunk_size)
        # now we replace original node with dummy node which has heading but the text is empty. text will be added to children
        node.text = ""
        node.is_partial_node_parent = True
        node.text_size = 0
        # store the children of this node and remove them from the node
        original_children = node.children
        node.children = []
        print("Node children: ", len(original_children))
        print("Splitting into: ", len(text_chunks))

        for i in range(len(text_chunks)):
            child = Node(heading="", level=node.level, page=node.page, line_number=node.line_number, refined_output_idx=node.refined_output_idx)
            child.text = text_chunks[i]
            child.text_size = len(text_chunks[i].split(" "))
            # add this child to the parent
            node.add_child(child)
            child.is_partial_node = True
            # check if this is the last child, it last child add the original children to this child
            if i == len(text_chunks) - 1:
                for original_child in original_children:
                    child.add_child(original_child)
    else:
        node.text = text
        node.text_size = text_size
    
    if len(node.children) > 0:
        for child in node.children:
            set_text_and_split_necessary_nodes(child, splitter_func, chunk_size)
    return

# %%
root.children[0].children
# Out:
# [self index: 0 level: 2 loc: <(2, 3)> content: ## About IBISWorld,
#  self index: 1 level: 2 loc: <(3, 5)> content: ## Table Of Contents,
#  self index: 2 level: 2 loc: <(5, 1)> content: ## About,
#  self index: 3 level: 2 loc: <(9, 3)> content: ## At a Glance,
#  self index: 4 level: 2 loc: <(15, 3)> content: ## Performance,
#  self index: 5 level: 2 loc: <(30, 3)> content: ## Products and Markets,
#  self index: 6 level: 2 loc: <(39, 3)> content: ## Geographic Breakdown,
#  self index: 7 level: 2 loc: <(46, 5)> content: ## Competitive Forces,
#  self index: 8 level: 2 loc: <(52, 5)> content: ## Companies,
#  self index: 9 level: 2 loc: <(67, 5)> content: ## External Environment,
#  self index: 10 level: 2 loc: <(73, 1)> content: ## Financial Benchmarks,
#  self index: 11 level: 2 loc: <(77, 5)> content: ## Key Statistics]

# %%
# iterate over the tree and print nodes with text size more than 500 words
def print_nodes_with_text_size_more_than_500_words(node, large_nodes):
    node_text = get_node_text(node)
    text_size = len(node_text.split(" "))
    if text_size > 500:
        print(node)
        large_nodes.append(node)
    if len(node.children) > 0:
        for child in node.children:
            print_nodes_with_text_size_more_than_500_words(child, large_nodes)
    return

large_nodes = []
print_nodes_with_text_size_more_than_500_words(root, large_nodes)
print(len(large_nodes))
# Out:
# self index: 1 level: 4 loc: <(16, 17)> content: #### Employees
# self index: 0 level: 4 loc: <(40, 5)> content: #### Business Concentration
# self index: 4 level: 4 loc: <(55, 29)> content: #### Company's Industry Revenue, Market Share, and Profit Margin Over Time
# self index: 4 level: 4 loc: <(57, 31)> content: #### Company's Industry Revenue, Market Share, and Profit Margin Over Time
# self index: 3 level: 4 loc: <(60, 20)> content: #### Company's Industry Revenue, Market Share, and Profit Margin Over Time
# self index: 3 level: 4 loc: <(64, 18)> content: #### Company's Industry Revenue, Market Share, and Profit Margin Over Time
# self index: 3 level: 3 loc: <(74, 29)> content: ### Key Ratios
# self index: 0 level: 4 loc: <(77, 11)> content: #### Values
# self index: 1 level: 3 loc: <(79, 5)> content: ### Annual Change
# 9

# %%
# # try splitting one sample node text using split_text_to_chunk_size
# sample_node = large_nodes[0]
# sample_node_text = get_node_text(sample_node)
# print(len(sample_node_text.split(" ")))
# sample_node_text_chunks = split_text_to_chunk_size(sample_node_text, target_size=500)
# print(len(sample_node_text_chunks))
# for i in range(len(sample_node_text_chunks)):
#     num_words = len(sample_node_text_chunks[i].split(" "))
#     print(f"chunk {i+1}: {num_words} words")
# print(sample_node_text)
# print("***********")
# print(sample_node_text_chunks[0])
# print("***********")
# print(sample_node_text_chunks[1])

# %%
# print(len(refined_output))

# %%
# print the tree structure to see there is no loop in the tree
total_nodes = 0
def print_tree_structure(node):
    print(node)
    global total_nodes
    total_nodes += 1
    if len(node.children) > 0:
        for child in node.children:
            print_tree_structure(child)
    return

print_tree_structure(root)
print(total_nodes)
# Out:
# self index: None level: 0 loc: <(0, 0)> content:
# self index: 0 level: 1 loc: <(1, 5)> content: # Healthcare and Social Assistance in the US
# self index: 0 level: 2 loc: <(2, 3)> content: ## About IBISWorld
# self index: 1 level: 2 loc: <(3, 5)> content: ## Table Of Contents
# self index: 2 level: 2 loc: <(5, 1)> content: ## About
# self index: 0 level: 3 loc: <(5, 5)> content: ### Codes
# self index: 1 level: 3 loc: <(5, 13)> content: ### Definition
# self index: 2 level: 3 loc: <(5, 17)> content: ### Related Terms
# self index: 0 level: 4 loc: <(5, 19)> content: #### ELECTRONIC HEALTH RECORD (EHR)
# self index: 1 level: 4 loc: <(5, 23)> content: #### TELEMEDICINE
# self index: 2 level: 4 loc: <(5, 27)> content: #### HEALTH INSURANCE EXCHANGE
# self index: 3 level: 4 loc: <(5, 31)> content: #### FEE-FOR-SERVICE
# self index: 4 level: 4 loc: <(5, 35)> content: #### MEDICARE AND MEDICAID
# self index: 5 level: 4 loc: <(5, 39)> content: #### LONG-TERM CARE
# self index: 6 level: 4 loc: <(5, 43)> content: #### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)
# self index: 7 level: 4 loc: <(6, 5)> content: #### GROUP HOME
# self index: 8 level: 4 loc: <(6, 9)> content: #### MANAGED CARE
# self index: 3 level: 3 loc: <(6, 13)> content: ### What's Included
# self index: 4 level: 3 loc: <(6, 20)> content: ### Companies
# self index: 5 level: 3 loc: <(6, 28)> content: ### Related Industries
# self index: 0 level: 4 loc: <(6, 30)> content: #### Industries in the Same Sector
# self index: 1 level: 4 loc: <(6, 40)> content: #### International Industries
# self index: 6 level: 3 loc: <(6, 46)> content: ### Additional Resources
# self index: 3 level: 2 loc: <(9, 3)> content: ## At a Glance
# self index: 0 level: 3 loc: <(9, 19)> content: ### Key Takeaways
# self index: 0 level: 4 loc: <(9, 21)> content: #### Performance
# self index: 1 level: 4 loc: <(9, 26)> content: #### External Environment
# self index: 1 level: 3 loc: <(10, 5)> content: ### Products and Services
# self index: 0 level: 4 loc: <(10, 7)> content: #### Products & Services Segmentation
# self index: 2 level: 3 loc: <(11, 3)> content: ### Major Players
# self index: 0 level: 4 loc: <(11, 5)> content: #### Major Players
# self index: 3 level: 3 loc: <(12, 5)> content: ### Key External Drivers
# self index: 4 level: 3 loc: <(12, 16)> content: ### Industry Structure
# self index: 5 level: 3 loc: <(13, 3)> content: ### SWOT
# self index: 0 level: 4 loc: <(13, 5)> content: #### Strengths
# self index: 1 level: 4 loc: <(13, 11)> content: #### Weaknesses
# self index: 2 level: 4 loc: <(13, 14)> content: #### Opportunities
# self index: 3 level: 4 loc: <(13, 20)> content: #### Threats
# self index: 6 level: 3 loc: <(13, 25)> content: ### Executive Summary
# self index: 4 level: 2 loc: <(15, 3)> content: ## Performance
# self index: 0 level: 3 loc: <(15, 7)> content: ### Highlights
# self index: 1 level: 3 loc: <(15, 19)> content: ### Key Takeaways
# self index: 2 level: 3 loc: <(16, 3)> content: ### Performance Snapshot
# self index: 0 level: 4 loc: <(16, 5)> content: #### Revenue
# self index: 1 level: 4 loc: <(16, 17)> content: #### Employees
# self index: 2 level: 4 loc: <(18, 5)> content: #### Businesses
# self index: 3 level: 4 loc: <(19, 5)> content: #### Profit
# self index: 3 level: 3 loc: <(20, 5)> content: ### Current Performance
# self index: 0 level: 4 loc: <(20, 7)> content: #### What's driving current performance?
# self index: 0 level: 5 loc: <(20, 9)> content: ##### Demographic trends shape the healthcare landscape
# self index: 1 level: 5 loc: <(20, 17)> content: ##### Healthcare providers grapple with persistent workforce shortages
# self index: 2 level: 5 loc: <(20, 27)> content: ##### The pandemic accelerated existing consolidation trends in healthcare
# self index: 3 level: 5 loc: <(21, 7)> content: ##### Social assistance providers fill in the gaps as pandemic-era benefits end
# self index: 4 level: 3 loc: <(22, 5)> content: ### What influences industry volatility?
# self index: 0 level: 4 loc: <(22, 7)> content: #### Healthcare services are vital to public health
# self index: 1 level: 4 loc: <(22, 17)> content: #### Healthcare facilities' financial health relies on reimbursements
# self index: 2 level: 4 loc: <(22, 23)> content: #### COVID-19 strains healthcare delivery
# self index: 5 level: 3 loc: <(23, 19)> content: ### Key Success Factor
# self index: 0 level: 4 loc: <(23, 21)> content: #### How do successful businesses overcome volatility?
# self index: 0 level: 5 loc: <(23, 23)> content: ##### Ability to take advantage of government subsidies and other grants
# self index: 1 level: 5 loc: <(23, 27)> content: ##### Secure a multiskilled workforce
# self index: 6 level: 3 loc: <(25, 5)> content: ### Outlook
# self index: 0 level: 4 loc: <(25, 9)> content: #### What's driving the industry outlook?
# self index: 0 level: 5 loc: <(25, 11)> content: ##### Demographic trends are behind rising healthcare spending
# self index: 1 level: 5 loc: <(25, 19)> content: ##### The pandemic's long-term effects are emerging
# self index: 2 level: 5 loc: <(25, 29)> content: ##### Tech advances will reshape healthcare delivery
# self index: 3 level: 5 loc: <(26, 9)> content: ##### Financial pressures will accelerate consolidation activity
# self index: 7 level: 3 loc: <(28, 5)> content: ### Life Cycle: Growth
# self index: 0 level: 4 loc: <(28, 7)> content: #### Why is the industry growing?
# self index: 0 level: 5 loc: <(28, 9)> content: ##### Contribution to GDP
# self index: 1 level: 5 loc: <(28, 13)> content: ##### Market Saturation
# self index: 2 level: 5 loc: <(28, 17)> content: ##### Innovation
# self index: 3 level: 5 loc: <(28, 21)> content: ##### Consolidation
# self index: 4 level: 5 loc: <(28, 25)> content: ##### Technology & Systems
# self index: 5 level: 2 loc: <(30, 3)> content: ## Products and Markets
# self index: 0 level: 3 loc: <(30, 11)> content: ### Key Takeaways
# self index: 1 level: 3 loc: <(30, 16)> content: ### Products and Services
# self index: 0 level: 4 loc: <(30, 18)> content: #### Products & Services Segmentation
# self index: 2 level: 3 loc: <(31, 5)> content: ### How are the industry's products and services performing?
# self index: 0 level: 4 loc: <(31, 7)> content: #### Hospitals are central to healthcare delivery
# self index: 1 level: 4 loc: <(31, 19)> content: #### Ambulatory healthcare services are an alternative care site
# self index: 2 level: 4 loc: <(31, 33)> content: #### Nursing and residential care facilities are critical for people over 65
# self index: 3 level: 4 loc: <(32, 13)> content: #### Social assistance providers have an outsized role
# self index: 3 level: 3 loc: <(32, 21)> content: ### What are innovations in industry products and services?
# self index: 0 level: 4 loc: <(32, 23)> content: #### Budding artificial intelligence partnerships are transforming service delivery
# self index: 1 level: 4 loc: <(32, 29)> content: #### Digital health applications abound
# self index: 4 level: 3 loc: <(34, 5)> content: ### Key Success Factor
# self index: 0 level: 4 loc: <(34, 7)> content: #### What products or services do successful businesses offer?
# self index: 5 level: 3 loc: <(35, 3)> content: ### Major Markets
# self index: 0 level: 4 loc: <(35, 5)> content: #### Major Market Segmentation
# self index: 1 level: 4 loc: <(35, 10)> content: #### What's influencing demand from the industry's markets?
# self index: 0 level: 5 loc: <(35, 12)> content: ##### Private insurers are the largest payer to healthcare and social assistance providers
# self index: 1 level: 5 loc: <(35, 18)> content: ##### Public insurers pay more as older adults age
# self index: 2 level: 5 loc: <(36, 11)> content: ##### Insurance limitations create out-of-pocket costs
# self index: 3 level: 5 loc: <(36, 21)> content: ##### Healthcare and social assistance receive payments from a mix of sources
# self index: 6 level: 3 loc: <(37, 5)> content: ### International Trade
# self index: 6 level: 2 loc: <(39, 3)> content: ## Geographic Breakdown
# self index: 0 level: 3 loc: <(39, 7)> content: ### Key Takeaways
# self index: 1 level: 3 loc: <(40, 3)> content: ### Business Locations
# self index: 0 level: 4 loc: <(40, 5)> content: #### Business Concentration
# self index: 2 level: 3 loc: <(43, 5)> content: ### Where are industry businesses located?
# self index: 0 level: 4 loc: <(43, 7)> content: #### Healthcare utilization high in the Southeast
# self index: 1 level: 4 loc: <(43, 15)> content: #### Metro areas in the Mid-Atlantic drive the region's share of mental health clinics
# self index: 2 level: 4 loc: <(43, 25)> content: #### California ranks first in healthcare spending
# self index: 3 level: 4 loc: <(44, 7)> content: #### West has the largest spread of businesses compared to its population
# self index: 3 level: 3 loc: <(44, 29)> content: ### Key Success Factor
# self index: 0 level: 4 loc: <(44, 31)> content: #### How do businesses use location to their advantage?
# self index: 0 level: 5 loc: <(44, 33)> content: ##### Ability to attract local support
# self index: 7 level: 2 loc: <(46, 5)> content: ## Competitive Forces
# self index: 0 level: 3 loc: <(46, 9)> content: ### Key Takeaways
# self index: 1 level: 3 loc: <(46, 14)> content: ### Concentration
# self index: 0 level: 4 loc: <(46, 18)> content: #### Market Share Concentration
# self index: 1 level: 4 loc: <(46, 27)> content: #### What impacts the industry's market share concentration?
# self index: 0 level: 5 loc: <(46, 29)> content: ##### Fragmented care is the status quo
# self index: 1 level: 5 loc: <(47, 9)> content: ##### The regulatory environment keeps concentration low
# self index: 2 level: 3 loc: <(47, 15)> content: ### Key Success Factor
# self index: 0 level: 4 loc: <(47, 17)> content: #### How do successful businesses handle concentration?
# self index: 0 level: 5 loc: <(47, 19)> content: ##### Proximity to key markets
# self index: 3 level: 3 loc: <(47, 23)> content: ### Barriers to Entry
# self index: 0 level: 4 loc: <(47, 27)> content: #### What challenges do potential industry entrants face?
# self index: 0 level: 5 loc: <(47, 29)> content: ##### Legal
# self index: 1 level: 5 loc: <(47, 33)> content: ##### Start-Up Costs
# self index: 2 level: 5 loc: <(48, 5)> content: ##### Differentiation
# self index: 3 level: 5 loc: <(48, 9)> content: ##### Labor Expenses
# self index: 4 level: 3 loc: <(48, 13)> content: ### Substitutes
# self index: 0 level: 4 loc: <(48, 17)> content: #### What are substitutes for industry services?
# self index: 0 level: 5 loc: <(48, 19)> content: ##### No Substitutes
# self index: 5 level: 3 loc: <(49, 3)> content: ### Buyer & Supplier Power
# self index: 0 level: 4 loc: <(49, 5)> content: #### Supply Chain
# self index: 1 level: 4 loc: <(49, 33)> content: #### What power do buyers and suppliers have over the industry?
# self index: 0 level: 5 loc: <(49, 35)> content: ##### Buyer power: Contracts
# self index: 1 level: 5 loc: <(49, 44)> content: ##### Supplier power: Switching costs
# self index: 8 level: 2 loc: <(52, 5)> content: ## Companies
# self index: 0 level: 3 loc: <(52, 9)> content: ### Key Takeaways
# self index: 1 level: 3 loc: <(53, 3)> content: ### Market Share
# self index: 0 level: 4 loc: <(53, 7)> content: #### Industry Market Share by Company
# self index: 2 level: 3 loc: <(54, 5)> content: ### Companies
# self index: 3 level: 3 loc: <(55, 3)> content: ### Hca Healthcare, Inc.
# self index: 0 level: 4 loc: <(55, 5)> content: #### Company Details
# self index: 1 level: 4 loc: <(55, 12)> content: #### Description
# self index: 2 level: 4 loc: <(55, 16)> content: #### Brands and Trading Names
# self index: 3 level: 4 loc: <(55, 24)> content: #### Other Industries
# self index: 4 level: 4 loc: <(55, 29)> content: #### Company's Industry Revenue, Market Share, and Profit Margin Over Time
# self index: 4 level: 3 loc: <(57, 3)> content: ### Quest Diagnostics Inc.
# self index: 0 level: 4 loc: <(57, 5)> content: #### Company Details
# self index: 1 level: 4 loc: <(57, 13)> content: #### Description
# self index: 2 level: 4 loc: <(57, 17)> content: #### Brands and Trading Names
# self index: 3 level: 4 loc: <(57, 25)> content: #### Other Industries
# self index: 4 level: 4 loc: <(57, 31)> content: #### Company's Industry Revenue, Market Share, and Profit Margin Over Time
# self index: 5 level: 4 loc: <(58, 19)> content: #### What's impacting Quest Diagnostics Inc.'s performance?
# self index: 0 level: 5 loc: <(58, 21)> content: ##### Quest Diagnostics marks two years of COVID-19 testing
# self index: 1 level: 5 loc: <(58, 25)> content: ##### Quest to acquire Patient Engagement company Pack Health
# self index: 2 level: 5 loc: <(58, 29)> content: ##### Quest continues to be recognized for positive work environment
# self index: 5 level: 3 loc: <(60, 3)> content: ### Feeding America
# self index: 0 level: 4 loc: <(60, 5)> content: #### Company Details
# self index: 1 level: 4 loc: <(60, 12)> content: #### Description
# self index: 2 level: 4 loc: <(60, 16)> content: #### Other Industries
# self index: 3 level: 4 loc: <(60, 20)> content: #### Company's Industry Revenue, Market Share, and Profit Margin Over Time
# self index: 4 level: 4 loc: <(60, 36)> content: #### What's impacting Feeding America's performance?
# self index: 0 level: 5 loc: <(61, 7)> content: ##### Feeding America invests $1.0 billion to fight food insecurity
# self index: 6 level: 3 loc: <(62, 3)> content: ### Brookdale Senior Living Inc.
# self index: 0 level: 4 loc: <(62, 5)> content: #### Company Details
# self index: 1 level: 4 loc: <(62, 12)> content: #### Description
# self index: 2 level: 4 loc: <(62, 16)> content: #### Other Industries
# self index: 3 level: 4 loc: <(62, 20)> content: #### Company's Industry Revenue, Market Share, and Profit Margin Over Time
# self index: 4 level: 4 loc: <(63, 10)> content: #### What's impacting Brookdale Senior Living Inc.'s performance?
# self index: 0 level: 5 loc: <(63, 12)> content: ##### COVID-19 continues to challenge senior living communities
# self index: 1 level: 5 loc: <(63, 16)> content: ##### Brookdale Reopens Houston community following renovation
# self index: 2 level: 5 loc: <(63, 20)> content: ##### Brookdale expands memory care and Alzheimer's treatment programs
# self index: 7 level: 3 loc: <(64, 1)> content: ### Fresenius Kabi AG
# self index: 0 level: 4 loc: <(64, 3)> content: #### Company Details
# self index: 1 level: 4 loc: <(64, 10)> content: #### Description
# self index: 2 level: 4 loc: <(64, 14)> content: #### Other Industries
# self index: 3 level: 4 loc: <(64, 18)> content: #### Company's Industry Revenue, Market Share, and Profit Margin Over Time
# self index: 4 level: 4 loc: <(64, 34)> content: #### What's impacting Fresenius Kabi AG's performance?
# self index: 9 level: 2 loc: <(67, 5)> content: ## External Environment
# self index: 0 level: 3 loc: <(67, 9)> content: ### Key Takeaways
# self index: 1 level: 3 loc: <(67, 14)> content: ### External Drivers
# self index: 0 level: 4 loc: <(67, 16)> content: #### What demographic and macroeconomic factors impact the industry?
# self index: 0 level: 5 loc: <(68, 3)> content: ##### Federal funding for Medicare and Medicaid
# self index: 2 level: 3 loc: <(69, 3)> content: ### Regulation & Policy
# self index: 0 level: 4 loc: <(69, 7)> content: #### What regulations impact the industry?
# self index: 0 level: 5 loc: <(69, 9)> content: ##### Certificate of Need
# self index: 1 level: 5 loc: <(69, 13)> content: ##### Antikickback Statute and Physician Self-Referral Laws
# self index: 2 level: 5 loc: <(69, 17)> content: ##### Health Insurance Portability and Accountability Act
# self index: 3 level: 5 loc: <(69, 21)> content: ##### The HITECH Act
# self index: 4 level: 5 loc: <(69, 25)> content: ##### The Centers for Medicare and Medicaid Services provisions
# self index: 5 level: 5 loc: <(69, 29)> content: ##### The No Surprises Act
# self index: 6 level: 5 loc: <(70, 3)> content: ##### COVID-19 regulations
# self index: 3 level: 3 loc: <(71, 3)> content: ### Assistance
# self index: 0 level: 4 loc: <(71, 7)> content: #### What assistance is available to this industry?
# self index: 0 level: 5 loc: <(71, 9)> content: ##### The Centers for Medicare and Medicaid Services
# self index: 1 level: 5 loc: <(71, 13)> content: ##### COVID-19 response
# self index: 2 level: 5 loc: <(71, 17)> content: ##### Federal initiatives
# self index: 3 level: 5 loc: <(71, 21)> content: ##### The American Hospital Association
# self index: 4 level: 5 loc: <(71, 25)> content: ##### Industry organizations
# self index: 10 level: 2 loc: <(73, 1)> content: ## Financial Benchmarks
# self index: 0 level: 3 loc: <(73, 11)> content: ### Key Takeaways
# self index: 1 level: 3 loc: <(73, 16)> content: ### Cost Structure
# self index: 0 level: 4 loc: <(73, 18)> content: #### Cost Structure Benchmarks
# self index: 2 level: 3 loc: <(74, 7)> content: ### What trends impact industry costs?
# self index: 0 level: 4 loc: <(74, 9)> content: #### Healthcare providers confront the exodus of workers
# self index: 1 level: 4 loc: <(74, 19)> content: #### Financial pressures erode profit for healthcare and social assistance providers
# self index: 3 level: 3 loc: <(74, 29)> content: ### Key Ratios
# self index: 11 level: 2 loc: <(77, 5)> content: ## Key Statistics
# self index: 0 level: 3 loc: <(77, 9)> content: ### Industry Data
# self index: 0 level: 4 loc: <(77, 11)> content: #### Values
# self index: 1 level: 3 loc: <(79, 5)> content: ### Annual Change
# 208

# %%
# print the text of the long nodes
for node in large_nodes:
    print(node.refined_output_idx)
    print(get_node_text(node))
    print("************")
# Out:
# 43
#
# The Revenue Volatility is described as Moderate.
#
# ### Revenue
#
# The graph presents the total value ($) and annual change from 2011 - 2029, including a 5-year outlook.
#
# The graph illustrates the Annual Revenue ($bn) and Change (%) from 2011 to 2029, with forecasted data from 2024 onwards. Key observations include:
#
# 1. The Annual Revenue shows a general upward trend from 2011 to 2029.
# 2. The Change (%) fluctuates significantly over the years, with notable peaks and troughs.
# 3. For 2024, the Annual Revenue is projected to be $3554.9 billion, with a 0.3% change.
# 4. The graph indicates a sharp decline in the change percentage around 2020-2021, possibly reflecting the impact of external events.
# 5. After 2024, the revenue is forecasted to continue growing, while the change percentage shows moderate fluctuations.
# 6. The highest positive change appears to occur around 2014-2015.
# 7. The y-axis for Annual Revenue ranges from 0 to 5000 ($bn), while the Change (%) axis ranges from -5% to 7.5%.
# 8. The forecasted period (2024-2029) shows a relatively stable growth in revenue with slight variations in the change percentage.
#
# Source: IBISWorld# IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# ## Employees:
#
# The number of employees in the Healthcare and Social Assistance industry in the US is projected to grow at a Compound Annual Growth Rate (CAGR) of 0.9% from 2019 to 2024.
#
# ### Key Metrics:
#
# | Metric | Value | 2019-2024 Change | 2024-2029 Forecast |
# |--------|-------|------------------|-------------------|
# | Employees | 24m | +0.9% | +2.3% |
# | Employees per Business | 8 | -0.3% | +0.3% |
# | Revenue per Employee | $149k | -0.2% | +0.4% |
#
# This table presents key employee-related metrics for the Healthcare and Social Assistance industry in the US. The total number of employees is 24 million, with a growth of 0.9% from 2019 to 2024 and a projected growth of 2.3% from 2024 to 2029. The number of employees per business is 8, showing a slight decrease of 0.3% from 2019 to 2024 but expected to increase by 0.3% from 2024 to 2029. Revenue per employee stands at $149,000, with a small decline of 0.2% from 2019 to 2024 but anticipated to grow by 0.4% from 2024 to 2029.
#
# ## Employees
#
# Total number of employees and annual change from 2011 - 2029. Includes 5-year outlook.
#
# The graph illustrates the total number of employees and the annual percentage change in the Healthcare and Social Assistance industry in the US from 2011 to 2029, including a 5-year forecast. The blue line represents the number of annual employees, while the red dashed line shows the percentage change.
#
# Key observations from the graph:
#
# 1. The number of employees has been steadily increasing from 2011 to 2029, with a projected continued growth.
# 2. There's a notable dip in the percentage change around 2020-2021, likely due to the impact of the COVID-19 pandemic.
# 3. The 2024 Annual Employees are forecasted to be 23,929,599.
# 4. The 2024 Change is projected to be 0.6%.
# 5. After 2024, both the number of employees and the percentage change are expected to increase, with the change peaking around 2027-2028 before declining slightly.
# 6. The y-axis on the left shows the number of employees, ranging from 0 to 30,000,000.
# 7. The y-axis on the right shows the percentage change, ranging from -2.4% to 3.6%.
#
# Overall, the graph indicates a general trend of growth in employment in this sector, with some fluctuations in the rate of change over time.
#
# Source: IBISWorld# IBISWorld | Healthcare and Social Assistance in the US
#
# *Mar 2024*
#
# ************
# 98
# Percentage of total industry Establishments in each region
#
# The image shows a map of the United States illustrating the business concentration of healthcare and social assistance establishments across different states. The concentration is represented by varying shades of blue, with darker shades indicating a higher percentage of establishments.
#
# Key observations from the map:
# - California appears to have the highest concentration, represented by the darkest shade of blue.
# - Texas and Florida also show relatively high concentrations.
# - The Northeast region, including states like New York, Pennsylvania, and Massachusetts, displays moderate to high concentrations.
# - Many central and western states show lighter shades, suggesting lower concentrations of healthcare and social assistance establishments.
#
# The map includes a legend titled "Percentage of Establishments (%)" with a scale from 0 to 15, indicating the range of concentration percentages across states.
#
# Below the map is a table:
#
# | County | Establishments Units | Population % |
# |--------|----------------------|--------------|
# | California | 12.9 | |
# | Texas | 7.9 | |
# | Florida | 7.1 | |
# | New York | 6.3 | |
#
# This table provides specific data on the percentage of total industry establishments in four key states. California leads with 12.9% of establishments, followed by Texas (7.9%), Florida (7.1%), and New York (6.3%). The "Population %" column is empty in the provided image.
#
# The data in the table correlates with the map visualization, confirming that California has the highest concentration of healthcare and social assistance establishments among the states listed.
#
# At the bottom right corner of the page, there is a page number "40" in a red circle.# IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# | State           | Value |
# |-----------------|-------|
# | Pennsylvania    | 4.1   |
# | Illinois        | 3.8   |
# | Ohio            | 3.2   |
# | New Jersey      | 3.1   |
# | Michigan        | 3.0   |
# | Georgia         | 2.9   |
# | North Carolina  | 2.7   |
# | Missouri        | 2.4   |
# | Washington      | 2.4   |
# | Virginia        | 2.3   |
# | Arizona         | 2.1   |
# | Massachusetts   | 2.1   |
# | Colorado        | 1.9   |
# | Indiana         | 1.9   |
# | Maryland        | 1.9   |
# | Minnesota       | 1.9   |
# | Wisconsin       | 1.8   |
# | Tennessee       | 1.7   |
# | Oregon          | 1.6   |
# | Louisiana       | 1.4   |
# | Alabama         | 1.3   |
# | Kentucky        | 1.3   |
# | Connecticut     | 1.2   |
# | Oklahoma        | 1.2   |
# | South Carolina  | 1.2   |
# | Utah            | 1.0   |
# | Arkansas        | 0.9   |
# | Iowa            | 0.9   |
# | Kansas          | 0.9   |
# | Nevada          | 0.9   |
# | Mississippi     | 0.7   |
# | Idaho           | 0.6   |
# | Nebraska        | 0.6   |
#
# The table presents data related to Healthcare and Social Assistance in the United States, categorized by state. The values associated with each state likely represent a measure of significance or contribution to the sector, though the specific metric is not explicitly stated.
#
# Pennsylvania leads with the highest value of 4.1, followed by Illinois at 3.8 and Ohio at 3.2. The top five states (Pennsylvania, Illinois, Ohio, New Jersey, and Michigan) all have values of 3.0 or higher, indicating they are significant contributors to the Healthcare and Social Assistance sector in the US.
#
# There's a noticeable decline in values as we move down the list. The middle range of states, including Colorado, Indiana, Maryland, and Minnesota, all share a value of 1.9. The lowest values are observed for Mississippi (0.7), Idaho (0.6), and Nebraska (0.6), suggesting these states have a comparatively smaller impact on the sector.
#
# The data shows a wide range of values across states, from 4.1 to 0.6, indicating significant variation in the healthcare and social assistance landscape across different regions of the United States. This variation could be due to factors such as population size, state policies, economic conditions, or other regional characteristics.
#
# The page number 41 is visible at the bottom right corner of the image.# IBISWorld | Healthcare and Social Assistance in the US
#
# *Mar 2024*
#
# | State | Value |
# |-------|-------|
# | New Mexico | 0.6 |
# | Maine | 0.5 |
# | West Virginia | 0.5 |
# | Delaware | 0.4 |
# | Hawaii | 0.4 |
# | Montana | 0.4 |
# | New Hampshire | 0.4 |
# | Alaska | 0.3 |
# | Rhode Island | 0.3 |
# | South Dakota | 0.3 |
# | District of Columbia | 0.2 |
# | North Dakota | 0.2 |
# | Vermont | 0.2 |
# | Wyoming | 0.2 |
#
# This table presents data related to healthcare and social assistance across various states in the US. The values associated with each state likely represent a specific metric or indicator, though the exact measure is not specified in the image.
#
# New Mexico leads with the highest value of 0.6, followed by Maine and West Virginia, both at 0.5. Delaware, Hawaii, Montana, and New Hampshire share the same value of 0.4. Alaska, Rhode Island, and South Dakota have a value of 0.3 each. The lowest value of 0.2 is shared by the District of Columbia, North Dakota, Vermont, and Wyoming.
#
# The data shows a range from 0.2 to 0.6, with most states falling between 0.2 and 0.4. This could indicate variations in healthcare and social assistance provision, funding, or utilization across these states. However, without more context, it's difficult to determine the exact nature of these variations or their significance.
#
# The inclusion of the District of Columbia alongside states suggests this data covers all major US jurisdictions, not just states. The date "Mar 2024" at the top right corner implies this data is a projection or forecast for that future date.
#
# *42*# IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
# ************
# 141
#
# | Year | Industry Revenue ($ million) | Market Share (%) | Profit Margin (%) |
# |------|------------------------------|-------------------|-------------------|
# | 2008 | 20382                        | 1.1               | 11.6              |
# | 2009 | 21215                        | 1.1               | 11.6              |
# | 2010 | 21961                        | 1.1               | 11.6              |
# | 2011 | 22833                        | 1.1               | 11.6              |
# | 2012 | 23681                        | 1.1               | 11.6              |
# | 2013 | 26955                        | 1.3               | 11.6              |
# | 2014 | 30366                        | 1.4               | 11.6              |
#
# The table presents Hca Healthcare, Inc.'s performance from 2008 to 2014. The company's industry revenue showed consistent growth, increasing from $20,382 million in 2008 to $30,366 million in 2014. Market share remained stable at 1.1% from 2008 to 2012, then increased to 1.3% in 2013 and 1.4% in 2014. Notably, the profit margin remained constant at 11.6% throughout the entire period, indicating consistent profitability despite the growth in revenue and market share.# IBISWorld | Healthcare and Social Assistance in the US
#
# *Mar 2024*
#
# | Year | Column 2 | Column 3 | Column 4 |
# |------|----------|----------|----------|
# | 2015 | 35408    | 1.5      | 11.6     |
# | 2016 | 41490    | 1.7      | 11.6     |
# | 2017 | 43614    | 1.7      | 10.0     |
# | 2018 | 46677    | 1.7      | 11.4     |
# | 2019 | 51336    | 1.8      | 10.2     |
# | 2020 | 51533    | 1.8      | 10.5     |
# | 2021 | 52649    | 1.7      | 12.5     |
# | 2022 | 52649    | 1.6      | 12.5     |
# | 2023 | 52649    | 1.5      | 12.5     |
# | 2024 | 52649    | 1.5      | 12.5     |
#
# The table presents data for the Healthcare and Social Assistance industry in the US from 2015 to 2024. The second column shows a steady increase in values from 35,408 in 2015 to 52,649 in 2021, after which it remains constant through 2024. This could represent industry revenue or another key financial metric.
#
# The third column shows fluctuations in values between 1.5 and 1.8 over the years. These figures peak at 1.8 in 2019 and 2020, then decrease to 1.5 by 2023 and remain at that level in 2024. This might represent a ratio or percentage related to industry performance.
#
# The fourth column displays values ranging from 10.0 to 12.5. There's some variability in earlier years, but from 2021 onwards, the value stabilizes at 12.5. This could represent a growth rate, profit margin, or another important industry indicator.
#
# The data suggests a period of growth and subsequent stabilization in the Healthcare and Social Assistance industry in the US. The consistent values in recent years might indicate a mature market or the impact of regulatory changes.# IBISWorld | Healthcare and Social Assistance in the US
#
# ************
# 147
#
# | Year | Industry Revenue ($ million) | Market Share (%) | Profit Margin (%) |
# |------|------------------------------|-------------------|-------------------|
# | 2008 | 5253                         | 0.3               | 17.7              |
# | 2009 | 5467                         | 0.3               | 17.7              |
# | 2010 | 5660                         | 0.3               | 17.7              |
# | 2011 | 5884                         | 0.3               | 17.7              |
# | 2012 | 6103                         | 0.3               | 17.7              |
# | 2013 | 6237                         | 0.3               | 17.7              |
#
# The table shows Quest Diagnostics Inc.'s financial performance from 2008 to 2013. The company's industry revenue has shown steady growth over this period, increasing from $5,253 million in 2008 to $6,237 million in 2013. Despite this growth in revenue, the company's market share remained constant at 0.3% throughout the six-year period. Similarly, the profit margin remained stable at 17.7% for all years shown. This suggests that while the company experienced revenue growth, it maintained consistent market positioning and profitability ratios during this time frame.# IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# | Year | Value 1 | Value 2 | Value 3 |
# |------|---------|---------|---------|
# | 2014 | 6503    | 0.3     | 17.7    |
# | 2015 | 6854    | 0.3     | 17.7    |
# | 2016 | 7214    | 0.3     | 17.7    |
# | 2017 | 7402    | 0.3     | 15.7    |
# | 2018 | 7531    | 0.3     | 14.6    |
# | 2019 | 7726    | 0.3     | 15.9    |
# | 2020 | 9437    | 0.3     | 20.9    |
# | 2021 | 10335   | 0.3     | 23.8    |
# | 2022 | 10335   | 0.3     | 23.8    |
# | 2023 | 10335   | 0.3     | 23.8    |
# | 2024 | 10335   | 0.3     | 23.8    |
#
# The table presents data on Healthcare and Social Assistance in the US from 2014 to 2024. The first column shows a steady increase in Value 1 from 6503 in 2014 to 10335 in 2021, after which it remains constant through 2024. Value 2 remains constant at 0.3 throughout the entire period. Value 3 shows fluctuations, starting at 17.7 from 2014 to 2016, then decreasing to 14.6 in 2018, before rising again to reach 23.8 in 2021 and remaining at that level through 2024.
#
# ************
# 156
#
# | Year | Industry Revenue ($ million) | Market Share (%) | Profit Margin (%) |
# |------|------------------------------|-------------------|-------------------|
# | 2016 | 2479                         | 0.1               | 0.5               |
# | 2017 | 2766                         | 0.1               | 0.6               |
# | 2018 | 2880                         | 0.1               | 0.6               |
# | 2019 | 2876                         | 0.1               | 1.5               |
# | 2020 | 3645                         | 0.1               | 8.5               |
# | 2021 | 3370                         | 0.1               | 8.5               |
# | 2022 | 3370                         | 0.1               | 8.5               |
# | 2023 | 3370                         | 0.1               | 8.5               |
# | 2024 | 3370                         | 0.1               | 8.5               |
#
# The table shows Feeding America's financial performance from 2016 to 2024. The company's industry revenue grew steadily from $2,479 million in 2016 to $3,645 million in 2020, then stabilized at $3,370 million from 2021 to 2024. The market share remained constant at 0.1% throughout the period. The profit margin showed significant improvement, starting at 0.5% in 2016 and increasing to 8.5% in 2020, maintaining this level through 2024. This indicates a substantial increase in profitability despite a consistent market share, suggesting improved operational efficiency or cost management.
#
# ************
# 172
#
# | Year | Industry Revenue ($ million) | Market Share (%) | Profit Margin (%) |
# |------|------------------------------|-------------------|-------------------|
# | 2016 | 155                          | 0.0               | 10.2              |
# | 2017 | 362                          | 0.0               | 10.2              |
# | 2018 | 514                          | 0.0               | 10.2              |
# | 2019 | 668                          | 0.0               | 10.2              |
# | 2020 | 936                          | 0.0               | 10.2              |
# | 2021 | 703                          | 0.0               | 10.2              |
# | 2022 | 678                          | 0.0               | 10.2              |
# | 2023 | 678                          | 0.0               | 10.2              |
# | 2024 | 678                          | 0.0               | 10.2              |
#
# The table presents Fresenius Kabi AG's industry revenue, market share, and profit margin from 2016 to 2024. The company's industry revenue shows significant growth from $155 million in 2016 to $936 million in 2020, followed by a decrease to $703 million in 2021 and stabilization at $678 million from 2022 to 2024. Despite these revenue fluctuations, the company's market share remains consistently at 0.0% throughout the period. Similarly, the profit margin remains steady at 10.2% across all years, indicating consistent profitability regardless of revenue changes.
#
# ************
# 202
#
# | Year | Revenue per Employee ($) | Revenue per Enterprise ($ Million) | Employees per Estab. (Units) | Employees per Ent. (Units) | Average Wage ($) | Wages/ Revenue (%) | Estab. per Enterprise (Units) | IVA/ Revenue (%) |
# |------|--------------------------|-----------------------------------|------------------------------|----------------------------|-------------------|--------------------|-----------------------------|-------------------|
# | 2005 | 132,192                  | 1.0                               | 7.3                          | 7.8                        | 52,763            | 39.9               | 1.1                         | 47.1              |
# | 2006 | 131,449                  | 1.0                               | 7.3                          | 7.8                        | 52,919            | 40.3               | 1.1                         | 48.2              |
# | 2007 | 133,342                  | 1.0                               | 7.3                          | 7.8                        | 53,783            | 40.3               | 1.1                         | 48.2              |
# | 2008 | 134,883                  | 1.1                               | 7.3                          | 7.8                        | 54,429            | 40.4               | 1.1                         | 48.1              |
#
# The Key Ratios table presents financial and operational metrics for the Healthcare and Social Assistance industry in the US from 2005 to 2008. The data shows:
#
# 1. Revenue per Employee: Increased steadily from $132,192 in 2005 to $134,883 in 2008, indicating a slight improvement in employee productivity.
#
# 2. Revenue per Enterprise: Remained stable at $1.0 million from 2005 to 2007, then increased to $1.1 million in 2008, suggesting a small growth in average enterprise size.
#
# 3. Employees per Establishment and per Enterprise: Remained constant at 7.3 and 7.8 respectively throughout the period, indicating stability in organizational structure.
#
# 4. Average Wage: Grew consistently from $52,763 in 2005 to $54,429 in 2008, reflecting a gradual increase in employee compensation.
#
# 5. Wages/Revenue Percentage: Increased slightly from 39.9% in 2005 to 40.4% in 2008, suggesting a marginally higher proportion of revenue being allocated to wages.
#
# 6. Establishments per Enterprise: Remained steady at 1.1 throughout the period, indicating no significant change in the average number of establishments per enterprise.
#
# 7. IVA/Revenue Percentage: Increased from 47.1% in 2005 to 48.2% in 2006 and 2007, then slightly decreased to 48.1% in 2008, showing a relatively stable value addition as a percentage of revenue.
#
# Overall, the data suggests a period of steady but modest growth in the industry, with slight improvements in revenue generation and wages, while maintaining stable organizational structures.# IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# | Year | Column 1 | Column 2 | Column 3 | Column 4 | Column 5 | Column 6 | Column 7 | Column 8 |
# |------|----------|----------|----------|----------|----------|----------|----------|----------|
# | 2009 | 136,753  | 1.1      | 7.3      | 7.8      | 55,100   | 40.3     | 1.1      | 48.9     |
# | 2010 | 137,584  | 1.1      | 7.2      | 7.7      | 54,802   | 39.8     | 1.1      | 51.1     |
# | 2011 | 138,027  | 1.1      | 7.2      | 7.7      | 54,770   | 39.7     | 1.1      | 50.5     |
# | 2012 | 138,491  | 1.1      | 7.3      | 7.9      | 55,295   | 39.9     | 1.1      | 50.7     |
# | 2013 | 137,644  | 1.1      | 7.3      | 7.9      | 54,878   | 39.9     | 1.1      | 51.3     |
# | 2014 | 139,208  | 1.1      | 7.3      | 7.9      | 54,985   | 39.5     | 1.1      | 50.8     |
# | 2015 | 142,946  | 1.1      | 7.4      | 8.0      | 56,343   | 39.4     | 1.1      | 50.6     |
# | 2016 | 145,708  | 1.2      | 7.6      | 8.3      | 56,585   | 38.8     | 1.1      | 50.2     |
# | 2017 | 146,136  | 1.2      | 7.8      | 8.5      | 57,560   | 39.4     | 1.1      | 51.0     |
# | 2018 | 146,451  | 1.2      | 7.6      | 8.3      | 57,743   | 39.4     | 1.1      | 51.1     |
# | 2019 | 149,716  | 1.3      | 7.7      | 8.4      | 58,573   | 39.1     | 1.1      | 51.1     |
# | 2020 | 147,958  | 1.3      | 7.9      | 8.7      | 58,422   | 39.5     | 1.1      | 51.4     |
# | 2021 | 158,275  | 1.3      | 7.5      | 8.2      | 60,638   | 38.3     | 1.1      | 50.6     |
# | 2022 | 148,600  | 1.2      | 7.5      | 8.3      | 59,590   | 40.1     | 1.1      | 51.9     |
# | 2023 | 149,090  | 1.2      | 7.5      | 8.3      | 59,625   | 40.0     | 1.1      | 51.8     |
# | 2024 | 148,559  | 1.2      | 7.5      | 8.3      | 59,582   | 40.1     | 1.1      | 51.9     |
# | 2025 | 149,419  | 1.2      | 7.5      | 8.3      | 59,651   | 39.9     | 1.1      | 51.8     |
# | 2026 | 150,127  | 1.3      | 7.6      | 8.3      | 59,708   | 39.8     | 1.1      | 51.6     |
# | 2027 | 150,731  | 1.3      | 7.6      | 8.4      | 59,756   | 39.6     | 1.1      | 51.5     |
# | 2028 | 151,581  | 1.3      | 7.6      | 8.4      | 59,823   | 39.5     | 1.1      | 51.4     |
# | 2029 | 151,197  | 1.3      | 7.6      | 8.4      | 59,793   | 39.5     | 1.1      | 51.5     |
# | 2030 | 151,328  | 1.3      | 7.6      | 8.4      | 59,803   | 39.5     | 1.1      | 51.5     |
#
# *Figures are inflation adjusted to 2024
#
# This table presents data on Healthcare and Social Assistance in the US from 2009 to 2030. The data is inflation-adjusted to 2024 values. Here's a detailed analysis of the trends:
#
# 1. Column 1 (likely representing total industry value or employment):
#    - Shows an overall increasing trend from 136,753 in 2009 to 151,328 in 2030.
#    - Notable peaks in 2021 (158,275) and 2019 (149,716).
#    - Slight fluctuations observed, with some years showing decreases (e.g., 2020, 2022).
#
# 2. Column 2 (possibly market share or growth rate):
#    - Remains relatively stable, ranging from 1.1 to 1.3.
#    - Slight increase observed from 2016 onwards, with more years at 1.2 and 1.3.
#
# 3. Columns 3 and 4 (possibly representing different industry metrics):
#    - Column 3 shows a general increase from 7.3 in 2009 to 7.6 in 2030, with fluctuations.
#    - Column 4 follows a similar pattern, increasing from 7.8 in 2009 to 8.4 in 2030.
#
# 4. Column 5 (possibly representing industry revenue or employment in a specific sector):
#    - Shows an overall increasing trend from 55,100 in 2009 to 59,803 in 2030.
#    - Peak value observed in 2021 (60,638).
#
# 5. Column 6 (possibly representing a percentage or ratio):
#    - Fluctuates between 38.3% (2021) and 40.3% (2009).
#    - No clear long-term trend, but shows some variability year to year.
#
# 6. Column 7:
#    - Remains constant at 1.1 throughout the entire period.
#
# 7. Column 8 (possibly representing another industry metric or ratio):
#    - Shows an overall increasing trend from 48.9 in 2009 to 51.5 in 2030.
#    - Highest value observed in 2022 and 2024 (51.9).
#
# Overall, the data suggests a growing industry with increasing values in most metrics, but with some fluctuations and variations across different measures. The year 2021 stands out with peak values in several columns, possibly indicating a significant event or change in the industry that year.# Key Statistics
#
# Discover 14 years of historical, current and forward-looking industry performance data in table format.
#
# The image shows a page from what appears to be a market research report. The page has a bright red background with a large, stylized number "10" in a lighter shade of red taking up most of the right side of the image. The text "Key Statistics" is prominently displayed in white letters on the left side of the page, followed by a brief description in smaller white text.
#
# The page number 76 is visible in the bottom right corner, indicating this is likely part of a larger report or document.
#
# This introductory page suggests that the following section will contain detailed statistical data covering a 14-year period, including past, present, and future projections for the industry being analyzed. The data is promised to be presented in a table format, which implies easy readability and comparison of figures across different time periods.
#
# The design of the page, with its bold red color and large numeral, creates a strong visual impact and emphasizes the importance of the upcoming statistical information.# IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
# ************
# 205
#
# | Year | Revenue ($ Million) | IVA ($ Million) | Establishments (Units) | Enterprises (Units) | Employment (Units) | Wages ($ Million) |
# |------|---------------------|------------------|------------------------|----------------------|---------------------|-------------------|
# | 2005 | 2,339,027.4 | 1,102,667.1 | 2,415,640 | 2,268,432 | 17,694,187 | 933,599.3 |
# | 2006 | 2,389,725.8 | 1,152,341.2 | 2,490,936 | 2,334,330 | 18,179,846 | 962,059.1 |
# | 2007 | 2,475,596.5 | 1,192,852.6 | 2,552,324 | 2,383,160 | 18,565,740 | 998,518.3 |
# | 2008 | 2,566,681.9 | 1,233,365.9 | 2,602,651 | 2,432,609 | 19,028,900 | 1,035,731.3 |
# | 2009 | 2,653,111.7 | 1,297,155.2 | 2,668,952 | 2,495,545 | 19,400,823 | 1,068,987.6 |
# | 2010 | 2,713,529.1 | 1,387,472.8 | 2,747,691 | 2,566,257 | 19,722,690 | 1,080,844.1 |
# | 2011 | 2,764,294.4 | 1,395,441.4 | 2,786,825 | 2,601,677 | 20,027,211 | 1,096,897.6 |
# | 2012 | 2,814,322.8 | 1,427,614.9 | 2,776,911 | 2,583,752 | 20,321,370 | 1,123,668.0 |
# | 2013 | 2,829,750.2 | 1,450,790.1 | 2,803,326 | 2,606,496 | 20,558,434 | 1,128,198.6 |
# | 2014 | 2,900,825.2 | 1,473,572.1 | 2,841,294 | 2,637,228 | 20,838,080 | 1,145,778.8 |
# | 2015 | 3,030,557.9 | 1,533,939.0 | 2,854,922 | 2,636,040 | 21,200,714 | 1,194,516.5 |
# | 2016 | 3,160,341.4 | 1,587,572.4 | 2,844,321 | 2,615,445 | 21,689,510 | 1,227,293.5 |
# | 2017 | 3,241,665.3 | 1,652,853.5 | 2,838,732 | 2,596,166 | 22,182,535 | 1,276,820.3 |
# | 2018 | 3,305,377.2 | 1,689,978.6 | 2,978,551 | 2,734,918 | 22,569,878 | 1,303,249.5 |
# | 2019 | 3,432,647.9 | 1,754,857.1 | 2,981,341 | 2,728,239 | 22,927,718 | 1,342,939.4 |
# | 2020 | 3,436,282.1 | 1,767,371.5 | 2,936,363 | 2,679,287 | 23,224,758 | 1,356,831.6 |
# | 2021 | 3,603,374.3 | 1,821,667.4 | 3,032,512 | 2,767,646 | 22,766,535 | 1,380,510.5 |
# | 2022 | 3,463,078.6 | 1,796,442.9 | 3,097,981 | 2,820,322 | 23,304,679 | 1,388,714.6 |
# | 2023 | 3,545,302.4 | 1,836,875.0 | 3,149,743 | 2,865,549 | 23,779,558 | 1,417,859.4 |
# | 2024 | 3,554,946.9 | 1,844,603.9 | 3,181,313 | 2,895,235 | 23,929,599 | 1,425,773.5 |
# | 2025 | 3,667,452.8 | 1,898,128.1 | 3,253,262 | 2,958,777 | 24,544,783 | 1,464,121.1 |
# | 2026 | 3,768,451.0 | 1,945,861.5 | 3,314,065 | 3,011,926 | 25,101,782 | 1,498,765.6 |
# | 2027 | 3,869,536.2 | 1,994,568.2 | 3,380,099 | 3,070,257 | 25,671,761 | 1,534,031.9 |
# | 2028 | 4,004,346.9 | 2,058,764.5 | 3,468,429 | 3,148,506 | 26,417,157 | 1,580,353.9 |
# | 2029 | 4,055,017.5 | 2,087,278.3 | 3,526,323 | 3,201,660 | 26,819,483 | 1,603,608.2 |
# | 2030 | 4,146,094.8 | 2,133,374.1 | 3,597,535 | 3,265,707 | 27,398,086 | 1,638,488.7 |
#
# This table presents key industry data for Healthcare and Social Assistance in the US from 2005 to 2030. It shows annual figures for Revenue, Industry Value Added (IVA), number of Establishments, number of Enterprises, Employment, and Wages.
#
# The data reveals several trends:
#
# 1. Revenue: There is a consistent increase in revenue from $2,339,027.4 million in 2005 to a projected $4,146,094.8 million in 2030, indicating steady growth in the industry.
#
# 2. IVA: Industry Value Added also shows an upward trend, rising from $1,102,667.1 million in 2005 to an estimated $2,133,374.1 million in 2030.
#
# 3. Establishments: The number of establishments has grown from 2,415,640 in 2005 to a projected 3,597,535 in 2030, suggesting expansion in the industry's physical presence.
#
# 4. Enterprises: The number of enterprises follows a similar growth pattern, increasing from 2,268,432 in 2005 to an estimated 3,265,707 in 2030.
#
# 5. Employment: The industry has seen significant job growth, with employment numbers rising from 17,694,187 in 2005 to a projected 27,398,086 in 2030.
#
# 6. Wages: Total wages in the industry have also increased substantially, from $933,599.3 million in 2005 to an estimated $1,638,488.7 million in 2030.
#
# The data indicates consistent growth across all metrics, with occasional slight fluctuations. Notable is the continued growth even through economic challenges such as the 2008 financial crisis and the 2020 pandemic, suggesting the resilience of the Healthcare and Social Assistance industry in the US.# IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
# *Figures are inflation adjusted to 2024
#
# The image appears to be a title page or header for a report on Healthcare and Social Assistance in the United States. The page is mostly blank, with minimal text content. The title and date are positioned at the top of the page, while a small footnote about inflation adjustment is placed below. At the bottom right corner of the page, there is a page number "78" enclosed in a red circle, indicating this is likely page 78 of the report.# IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
# ************
# 206
#
# | Year | Revenue % | IVA % | Establishments % | Enterprises % | Employment % | Wages % |
# |------|-----------|-------|------------------|---------------|--------------|---------|
# | 2005 | N/A | N/A | N/A | N/A | N/A | N/A |
# | 2006 | 2.2 | 4.5 | 3.1 | 2.9 | 2.7 | 3.0 |
# | 2007 | 3.6 | 3.5 | 2.5 | 2.1 | 2.1 | 3.8 |
# | 2008 | 3.7 | 3.4 | 2.0 | 2.1 | 2.5 | 3.7 |
# | 2009 | 3.4 | 5.2 | 2.5 | 2.6 | 2.0 | 3.2 |
# | 2010 | 2.3 | 7.0 | 3.0 | 2.8 | 1.7 | 1.1 |
# | 2011 | 1.9 | 0.6 | 1.4 | 1.4 | 1.5 | 1.5 |
# | 2012 | 1.8 | 2.3 | -0.4 | -0.7 | 1.5 | 2.4 |
# | 2013 | 0.5 | 1.6 | 1.0 | 0.9 | 1.2 | 0.4 |
# | 2014 | 2.5 | 1.6 | 1.4 | 1.2 | 1.4 | 1.6 |
# | 2015 | 4.5 | 4.1 | 0.5 | 0.0 | 1.7 | 4.3 |
# | 2016 | 4.3 | 3.5 | -0.4 | -0.8 | 2.3 | 2.7 |
# | 2017 | 2.6 | 4.1 | -0.2 | -0.7 | 2.3 | 4.0 |
# | 2018 | 2.0 | 2.2 | 4.9 | 5.3 | 1.7 | 2.1 |
# | 2019 | 3.9 | 3.8 | 0.1 | -0.2 | 1.6 | 3.0 |
# | 2020 | 0.1 | 0.7 | -1.5 | -1.8 | 1.3 | 1.0 |
# | 2021 | 4.9 | 3.1 | 3.3 | 3.3 | -2.0 | 1.7 |
# | 2022 | -3.9 | -1.4 | 2.2 | 1.9 | 2.4 | 0.6 |
# | 2023 | 2.4 | 2.3 | 1.7 | 1.6 | 2.0 | 2.1 |
# | 2024 | 0.3 | 0.4 | 1.0 | 1.0 | 0.6 | 0.6 |
# | 2025 | 3.2 | 2.9 | 2.3 | 2.2 | 2.6 | 2.7 |
# | 2026 | 2.8 | 2.5 | 1.9 | 1.8 | 2.3 | 2.4 |
# | 2027 | 2.7 | 2.5 | 2.0 | 1.9 | 2.3 | 2.4 |
# | 2028 | 3.5 | 3.2 | 2.6 | 2.5 | 2.9 | 3.0 |
# | 2029 | 1.3 | 1.4 | 1.7 | 1.7 | 1.5 | 1.5 |
# | 2030 | 2.2 | 2.2 | 2.0 | 2.0 | 2.2 | 2.2 |
#
# The table presents annual changes in various metrics for the Healthcare and Social Assistance industry in the US from 2005 to 2030. The metrics include Revenue, IVA (Industry Value Added), Establishments, Enterprises, Employment, and Wages, all expressed as percentages.
#
# Key observations:
#
# 1. Data for 2005 is not available (N/A) across all metrics.
#
# 2. Revenue growth was highest in 2021 (4.9%) and lowest in 2022 (-3.9%).
#
# 3. IVA growth peaked in 2010 (7.0%) and was lowest in 2022 (-1.4%).
#
# 4. Establishments and Enterprises growth rates generally follow similar patterns, with the highest growth in 2018 (4.9% and 5.3% respectively) and the lowest in 2020 (-1.5% and -1.8% respectively).
#
# 5. Employment growth was highest in 2006 (2.7%) and lowest in 2021 (-2.0%), the only year showing negative growth.
#
# 6. Wage growth was highest in 2015 (4.3%) and lowest in 2013 (0.4%).
#
# 7. The industry shows some volatility, particularly in recent years (2020-2022), likely reflecting the impact of external factors such as the COVID-19 pandemic.
#
# 8. Projections for 2024-2030 suggest relatively stable growth across all metrics, with most values ranging between 1.5% and 3.5%.
#
# *Figures are inflation adjusted to 2024
# ************

# %%
# let's process the tree and split the nodes with text size more than 500 words into multiple nodes
size_based_splitter = split_text_to_chunk_size
set_text_and_split_necessary_nodes(root, splitter_func=size_based_splitter, chunk_size=500)
# Out:
# Splitting node:  43
# Node children:  0
# Splitting into:  2
# Splitting node:  98
# Node children:  0
# Splitting into:  3
# Splitting node:  141
# Node children:  0
# Splitting into:  2
# Splitting node:  147
# Node children:  0
# Splitting into:  2
# Splitting node:  156
# Node children:  0
# Splitting into:  2
# Splitting node:  172
# Node children:  0
# Splitting into:  2
# Splitting node:  202
# Node children:  0
# Splitting into:  6
# Splitting node:  205
# Node children:  0
# Splitting into:  2
# Splitting node:  206
# Node children:  0
# Splitting into:  2

# %%
# iterate over large nodes and print their text, also print the text of their children and if they are partial nodes

def print_large_nodes_and_children(large_nodes):
    for node in large_nodes:
        print(node.refined_output_idx)
        print(get_node_text(node))
        for child in node.children:
            print("child: ", child)
            if child.is_partial_node:
                print("Partial Node")
            print(get_node_text(child))
            print("************")  
    return

print_large_nodes_and_children(large_nodes)
# Out:
# 43
#
# child:  self index: 0 level: 4 loc: <(16, 17)> content:
# Partial Node
#
# The Revenue Volatility is described as Moderate.
#
# ### Revenue
#
# The graph presents the total value ($) and annual change from 2011 - 2029, including a 5-year outlook.
#
# The graph illustrates the Annual Revenue ($bn) and Change (%) from 2011 to 2029, with forecasted data from 2024 onwards. Key observations include:
#
# 1. The Annual Revenue shows a general upward trend from 2011 to 2029.
# 2. The Change (%) fluctuates significantly over the years, with notable peaks and troughs.
# 3. For 2024, the Annual Revenue is projected to be $3554.9 billion, with a 0.3% change.
# 4. The graph indicates a sharp decline in the change percentage around 2020-2021, possibly reflecting the impact of external events.
# 5. After 2024, the revenue is forecasted to continue growing, while the change percentage shows moderate fluctuations.
# 6. The highest positive change appears to occur around 2014-2015.
# 7. The y-axis for Annual Revenue ranges from 0 to 5000 ($bn), while the Change (%) axis ranges from -5% to 7.5%.
# 8. The forecasted period (2024-2029) shows a relatively stable growth in revenue with slight variations in the change percentage.
#
# Source: IBISWorld# IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# ## Employees:
#
# The number of employees in the Healthcare and Social Assistance industry in the US is projected to grow at a Compound Annual Growth Rate (CAGR) of 0.9% from 2019 to 2024.
#
# ### Key Metrics:
#
# | Metric | Value | 2019-2024 Change | 2024-2029 Forecast |
# |--------|-------|------------------|-------------------|
# | Employees | 24m | +0.9% | +2.3% |
# | Employees per Business | 8 | -0.3% | +0.3% |
# | Revenue per Employee | $149k | -0.2% | +0.4% |
#
# This table presents key employee-related metrics for the Healthcare and Social Assistance industry in the US. The total number of employees is 24 million, with a growth of 0.9% from 2019 to 2024 and a projected growth of 2.3% from 2024 to 2029. The number of employees per business is 8, showing a slight decrease of 0.3% from 2019 to 2024 but expected to increase by 0.3% from 2024 to 2029. Revenue per employee stands at $149,000, with a small decline of 0.2% from 2019 to 2024 but anticipated to grow by 0.4% from 2024 to 2029.
#
# ## Employees
#
# Total number of employees and annual change from 2011 - 2029. Includes 5-year outlook.
#
# The graph illustrates the total number of employees and the annual percentage change in the Healthcare and Social Assistance industry in the US from 2011 to 2029, including a 5-year forecast. The blue line represents the number of annual employees, while the red dashed line shows the percentage change.
#
# Key observations from the graph:
#
# 1. The number of employees has been steadily increasing from 2011 to 2029, with a projected continued growth.
# 2. There's a notable dip in the percentage change around 2020-2021, likely due to the impact of the COVID-19 pandemic.
#
# ************
# child:  self index: 1 level: 4 loc: <(16, 17)> content:
# Partial Node
# 3. The 2024 Annual Employees are forecasted to be 23,929,599.
# 4. The 2024 Change is projected to be 0.6%.
# 5. After 2024, both the number of employees and the percentage change are expected to increase, with the change peaking around 2027-2028 before declining slightly.
# 6. The y-axis on the left shows the number of employees, ranging from 0 to 30,000,000.
# 7. The y-axis on the right shows the percentage change, ranging from -2.4% to 3.6%.
#
# Overall, the graph indicates a general trend of growth in employment in this sector, with some fluctuations in the rate of change over time.
#
# Source: IBISWorld# IBISWorld | Healthcare and Social Assistance in the US
#
# *Mar 2024*
#
#
# ************
# 98
#
# child:  self index: 0 level: 4 loc: <(40, 5)> content:
# Partial Node
# Percentage of total industry Establishments in each region
#
# The image shows a map of the United States illustrating the business concentration of healthcare and social assistance establishments across different states. The concentration is represented by varying shades of blue, with darker shades indicating a higher percentage of establishments.
#
# Key observations from the map:
# - California appears to have the highest concentration, represented by the darkest shade of blue.
# - Texas and Florida also show relatively high concentrations.
# - The Northeast region, including states like New York, Pennsylvania, and Massachusetts, displays moderate to high concentrations.
# - Many central and western states show lighter shades, suggesting lower concentrations of healthcare and social assistance establishments.
#
# The map includes a legend titled "Percentage of Establishments (%)" with a scale from 0 to 15, indicating the range of concentration percentages across states.
#
# Below the map is a table:
#
# | County | Establishments Units | Population % |
# |--------|----------------------|--------------|
# | California | 12.9 | |
# | Texas | 7.9 | |
# | Florida | 7.1 | |
# | New York | 6.3 | |
#
# This table provides specific data on the percentage of total industry establishments in four key states. California leads with 12.9% of establishments, followed by Texas (7.9%), Florida (7.1%), and New York (6.3%). The "Population %" column is empty in the provided image.
#
# The data in the table correlates with the map visualization, confirming that California has the highest concentration of healthcare and social assistance establishments among the states listed.
#
# At the bottom right corner of the page, there is a page number "40" in a red circle.# IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# | State           | Value |
# |-----------------|-------|
# | Pennsylvania    | 4.1   |
# | Illinois        | 3.8   |
# | Ohio            | 3.2   |
# | New Jersey      | 3.1   |
# | Michigan        | 3.0   |
# | Georgia         | 2.9   |
# | North Carolina  | 2.7   |
# | Missouri        | 2.4   |
# | Washington      | 2.4   |
# | Virginia        | 2.3   |
# | Arizona         | 2.1   |
# | Massachusetts   | 2.1   |
# | Colorado        | 1.9   |
# | Indiana         | 1.9   |
#
# ************
# child:  self index: 1 level: 4 loc: <(40, 5)> content:
# Partial Node
# | Maryland        | 1.9   |
# | Minnesota       | 1.9   |
# | Wisconsin       | 1.8   |
# | Tennessee       | 1.7   |
# | Oregon          | 1.6   |
# | Louisiana       | 1.4   |
# | Alabama         | 1.3   |
# | Kentucky        | 1.3   |
# | Connecticut     | 1.2   |
# | Oklahoma        | 1.2   |
# | South Carolina  | 1.2   |
# | Utah            | 1.0   |
# | Arkansas        | 0.9   |
# | Iowa            | 0.9   |
# | Kansas          | 0.9   |
# | Nevada          | 0.9   |
# | Mississippi     | 0.7   |
# | Idaho           | 0.6   |
# | Nebraska        | 0.6   |
#
# The table presents data related to Healthcare and Social Assistance in the United States, categorized by state. The values associated with each state likely represent a measure of significance or contribution to the sector, though the specific metric is not explicitly stated.
#
# Pennsylvania leads with the highest value of 4.1, followed by Illinois at 3.8 and Ohio at 3.2. The top five states (Pennsylvania, Illinois, Ohio, New Jersey, and Michigan) all have values of 3.0 or higher, indicating they are significant contributors to the Healthcare and Social Assistance sector in the US.
#
# There's a noticeable decline in values as we move down the list. The middle range of states, including Colorado, Indiana, Maryland, and Minnesota, all share a value of 1.9. The lowest values are observed for Mississippi (0.7), Idaho (0.6), and Nebraska (0.6), suggesting these states have a comparatively smaller impact on the sector.
#
# The data shows a wide range of values across states, from 4.1 to 0.6, indicating significant variation in the healthcare and social assistance landscape across different regions of the United States. This variation could be due to factors such as population size, state policies, economic conditions, or other regional characteristics.
#
# The page number 41 is visible at the bottom right corner of the image.# IBISWorld | Healthcare and Social Assistance in the US
#
# *Mar 2024*
#
#
# ************
# child:  self index: 2 level: 4 loc: <(40, 5)> content:
# Partial Node
# | State | Value |
# |-------|-------|
# | New Mexico | 0.6 |
# | Maine | 0.5 |
# | West Virginia | 0.5 |
# | Delaware | 0.4 |
# | Hawaii | 0.4 |
# | Montana | 0.4 |
# | New Hampshire | 0.4 |
# | Alaska | 0.3 |
# | Rhode Island | 0.3 |
# | South Dakota | 0.3 |
# | District of Columbia | 0.2 |
# | North Dakota | 0.2 |
# | Vermont | 0.2 |
# | Wyoming | 0.2 |
#
# This table presents data related to healthcare and social assistance across various states in the US. The values associated with each state likely represent a specific metric or indicator, though the exact measure is not specified in the image.
#
# New Mexico leads with the highest value of 0.6, followed by Maine and West Virginia, both at 0.5. Delaware, Hawaii, Montana, and New Hampshire share the same value of 0.4. Alaska, Rhode Island, and South Dakota have a value of 0.3 each. The lowest value of 0.2 is shared by the District of Columbia, North Dakota, Vermont, and Wyoming.
#
# The data shows a range from 0.2 to 0.6, with most states falling between 0.2 and 0.4. This could indicate variations in healthcare and social assistance provision, funding, or utilization across these states. However, without more context, it's difficult to determine the exact nature of these variations or their significance.
#
# The inclusion of the District of Columbia alongside states suggests this data covers all major US jurisdictions, not just states. The date "Mar 2024" at the top right corner implies this data is a projection or forecast for that future date.
#
# *42*# IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
#
# ************
# 141
#
# child:  self index: 0 level: 4 loc: <(55, 29)> content:
# Partial Node
#
# | Year | Industry Revenue ($ million) | Market Share (%) | Profit Margin (%) |
# |------|------------------------------|-------------------|-------------------|
# | 2008 | 20382                        | 1.1               | 11.6              |
# | 2009 | 21215                        | 1.1               | 11.6              |
# | 2010 | 21961                        | 1.1               | 11.6              |
# | 2011 | 22833                        | 1.1               | 11.6              |
# | 2012 | 23681                        | 1.1               | 11.6              |
# | 2013 | 26955                        | 1.3               | 11.6              |
# | 2014 | 30366                        | 1.4               | 11.6              |
#
#
# ************
# child:  self index: 1 level: 4 loc: <(55, 29)> content:
# Partial Node
# The table presents Hca Healthcare, Inc.'s performance from 2008 to 2014. The company's industry revenue showed consistent growth, increasing from $20,382 million in 2008 to $30,366 million in 2014. Market share remained stable at 1.1% from 2008 to 2012, then increased to 1.3% in 2013 and 1.4% in 2014. Notably, the profit margin remained constant at 11.6% throughout the entire period, indicating consistent profitability despite the growth in revenue and market share.# IBISWorld | Healthcare and Social Assistance in the US
#
# *Mar 2024*
#
# | Year | Column 2 | Column 3 | Column 4 |
# |------|----------|----------|----------|
# | 2015 | 35408    | 1.5      | 11.6     |
# | 2016 | 41490    | 1.7      | 11.6     |
# | 2017 | 43614    | 1.7      | 10.0     |
# | 2018 | 46677    | 1.7      | 11.4     |
# | 2019 | 51336    | 1.8      | 10.2     |
# | 2020 | 51533    | 1.8      | 10.5     |
# | 2021 | 52649    | 1.7      | 12.5     |
# | 2022 | 52649    | 1.6      | 12.5     |
# | 2023 | 52649    | 1.5      | 12.5     |
# | 2024 | 52649    | 1.5      | 12.5     |
#
# The table presents data for the Healthcare and Social Assistance industry in the US from 2015 to 2024. The second column shows a steady increase in values from 35,408 in 2015 to 52,649 in 2021, after which it remains constant through 2024. This could represent industry revenue or another key financial metric.
#
# The third column shows fluctuations in values between 1.5 and 1.8 over the years. These figures peak at 1.8 in 2019 and 2020, then decrease to 1.5 by 2023 and remain at that level in 2024. This might represent a ratio or percentage related to industry performance.
#
# The fourth column displays values ranging from 10.0 to 12.5. There's some variability in earlier years, but from 2021 onwards, the value stabilizes at 12.5. This could represent a growth rate, profit margin, or another important industry indicator.
#
# The data suggests a period of growth and subsequent stabilization in the Healthcare and Social Assistance industry in the US. The consistent values in recent years might indicate a mature market or the impact of regulatory changes.# IBISWorld | Healthcare and Social Assistance in the US
#
#
# ************
# 147
#
# child:  self index: 0 level: 4 loc: <(57, 31)> content:
# Partial Node
#
# | Year | Industry Revenue ($ million) | Market Share (%) | Profit Margin (%) |
# |------|------------------------------|-------------------|-------------------|
# | 2008 | 5253                         | 0.3               | 17.7              |
# | 2009 | 5467                         | 0.3               | 17.7              |
# | 2010 | 5660                         | 0.3               | 17.7              |
# | 2011 | 5884                         | 0.3               | 17.7              |
# | 2012 | 6103                         | 0.3               | 17.7              |
# | 2013 | 6237                         | 0.3               | 17.7              |
#
# The table shows Quest Diagnostics Inc.'s financial performance from 2008 to 2013. The company's industry revenue has shown steady growth over this period, increasing from $5,253 million in 2008 to $6,237 million in 2013. Despite this growth in revenue, the company's market share remained constant at 0.3% throughout the six-year period. Similarly, the profit margin remained stable at 17.7% for all years shown. This suggests that while the company experienced revenue growth, it maintained consistent market positioning and profitability ratios during this time frame.# IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# | Year | Value 1 | Value 2 | Value 3 |
# |------|---------|---------|---------|
#
# ************
# child:  self index: 1 level: 4 loc: <(57, 31)> content:
# Partial Node
# | 2014 | 6503    | 0.3     | 17.7    |
# | 2015 | 6854    | 0.3     | 17.7    |
# | 2016 | 7214    | 0.3     | 17.7    |
# | 2017 | 7402    | 0.3     | 15.7    |
# | 2018 | 7531    | 0.3     | 14.6    |
# | 2019 | 7726    | 0.3     | 15.9    |
# | 2020 | 9437    | 0.3     | 20.9    |
# | 2021 | 10335   | 0.3     | 23.8    |
# | 2022 | 10335   | 0.3     | 23.8    |
# | 2023 | 10335   | 0.3     | 23.8    |
# | 2024 | 10335   | 0.3     | 23.8    |
#
# The table presents data on Healthcare and Social Assistance in the US from 2014 to 2024. The first column shows a steady increase in Value 1 from 6503 in 2014 to 10335 in 2021, after which it remains constant through 2024. Value 2 remains constant at 0.3 throughout the entire period. Value 3 shows fluctuations, starting at 17.7 from 2014 to 2016, then decreasing to 14.6 in 2018, before rising again to reach 23.8 in 2021 and remaining at that level through 2024.
#
#
# ************
# 156
#
# child:  self index: 0 level: 4 loc: <(60, 20)> content:
# Partial Node
#
# | Year | Industry Revenue ($ million) | Market Share (%) | Profit Margin (%) |
# |------|------------------------------|-------------------|-------------------|
# | 2016 | 2479                         | 0.1               | 0.5               |
# | 2017 | 2766                         | 0.1               | 0.6               |
# | 2018 | 2880                         | 0.1               | 0.6               |
# | 2019 | 2876                         | 0.1               | 1.5               |
# | 2020 | 3645                         | 0.1               | 8.5               |
# | 2021 | 3370                         | 0.1               | 8.5               |
# | 2022 | 3370                         | 0.1               | 8.5               |
#
# ************
# child:  self index: 1 level: 4 loc: <(60, 20)> content:
# Partial Node
# | 2023 | 3370                         | 0.1               | 8.5               |
# | 2024 | 3370                         | 0.1               | 8.5               |
#
# The table shows Feeding America's financial performance from 2016 to 2024. The company's industry revenue grew steadily from $2,479 million in 2016 to $3,645 million in 2020, then stabilized at $3,370 million from 2021 to 2024. The market share remained constant at 0.1% throughout the period. The profit margin showed significant improvement, starting at 0.5% in 2016 and increasing to 8.5% in 2020, maintaining this level through 2024. This indicates a substantial increase in profitability despite a consistent market share, suggesting improved operational efficiency or cost management.
#
#
# ************
# 172
#
# child:  self index: 0 level: 4 loc: <(64, 18)> content:
# Partial Node
#
# | Year | Industry Revenue ($ million) | Market Share (%) | Profit Margin (%) |
# |------|------------------------------|-------------------|-------------------|
# | 2016 | 155                          | 0.0               | 10.2              |
# | 2017 | 362                          | 0.0               | 10.2              |
# | 2018 | 514                          | 0.0               | 10.2              |
# | 2019 | 668                          | 0.0               | 10.2              |
# | 2020 | 936                          | 0.0               | 10.2              |
# | 2021 | 703                          | 0.0               | 10.2              |
# | 2022 | 678                          | 0.0               | 10.2              |
#
# ************
# child:  self index: 1 level: 4 loc: <(64, 18)> content:
# Partial Node
# | 2023 | 678                          | 0.0               | 10.2              |
# | 2024 | 678                          | 0.0               | 10.2              |
#
# The table presents Fresenius Kabi AG's industry revenue, market share, and profit margin from 2016 to 2024. The company's industry revenue shows significant growth from $155 million in 2016 to $936 million in 2020, followed by a decrease to $703 million in 2021 and stabilization at $678 million from 2022 to 2024. Despite these revenue fluctuations, the company's market share remains consistently at 0.0% throughout the period. Similarly, the profit margin remains steady at 10.2% across all years, indicating consistent profitability regardless of revenue changes.
#
#
# ************
# 202
#
# child:  self index: 0 level: 3 loc: <(74, 29)> content:
# Partial Node
#
# | Year | Revenue per Employee ($) | Revenue per Enterprise ($ Million) | Employees per Estab. (Units) | Employees per Ent. (Units) | Average Wage ($) | Wages/ Revenue (%) | Estab. per Enterprise (Units) | IVA/ Revenue (%) |
# |------|--------------------------|-----------------------------------|------------------------------|----------------------------|-------------------|--------------------|-----------------------------|-------------------|
# | 2005 | 132,192                  | 1.0                               | 7.3                          | 7.8                        | 52,763            | 39.9               | 1.1                         | 47.1              |
# | 2006 | 131,449                  | 1.0                               | 7.3                          | 7.8                        | 52,919            | 40.3               | 1.1                         | 48.2              |
#
# ************
# child:  self index: 1 level: 3 loc: <(74, 29)> content:
# Partial Node
# | 2007 | 133,342                  | 1.0                               | 7.3                          | 7.8                        | 53,783            | 40.3               | 1.1                         | 48.2              |
# | 2008 | 134,883                  | 1.1                               | 7.3                          | 7.8                        | 54,429            | 40.4               | 1.1                         | 48.1              |
#
# The Key Ratios table presents financial and operational metrics for the Healthcare and Social Assistance industry in the US from 2005 to 2008. The data shows:
#
# 1. Revenue per Employee: Increased steadily from $132,192 in 2005 to $134,883 in 2008, indicating a slight improvement in employee productivity.
#
# 2. Revenue per Enterprise: Remained stable at $1.0 million from 2005 to 2007, then increased to $1.1 million in 2008, suggesting a small growth in average enterprise size.
#
# 3. Employees per Establishment and per Enterprise: Remained constant at 7.3 and 7.8 respectively throughout the period, indicating stability in organizational structure.
#
# 4. Average Wage: Grew consistently from $52,763 in 2005 to $54,429 in 2008, reflecting a gradual increase in employee compensation.
#
# 5. Wages/Revenue Percentage: Increased slightly from 39.9% in 2005 to 40.4% in 2008, suggesting a marginally higher proportion of revenue being allocated to wages.
#
# ************
# child:  self index: 2 level: 3 loc: <(74, 29)> content:
# Partial Node
#
# 6. Establishments per Enterprise: Remained steady at 1.1 throughout the period, indicating no significant change in the average number of establishments per enterprise.
#
# 7. IVA/Revenue Percentage: Increased from 47.1% in 2005 to 48.2% in 2006 and 2007, then slightly decreased to 48.1% in 2008, showing a relatively stable value addition as a percentage of revenue.
#
# Overall, the data suggests a period of steady but modest growth in the industry, with slight improvements in revenue generation and wages, while maintaining stable organizational structures.# IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# | Year | Column 1 | Column 2 | Column 3 | Column 4 | Column 5 | Column 6 | Column 7 | Column 8 |
# |------|----------|----------|----------|----------|----------|----------|----------|----------|
# | 2009 | 136,753  | 1.1      | 7.3      | 7.8      | 55,100   | 40.3     | 1.1      | 48.9     |
# | 2010 | 137,584  | 1.1      | 7.2      | 7.7      | 54,802   | 39.8     | 1.1      | 51.1     |
# | 2011 | 138,027  | 1.1      | 7.2      | 7.7      | 54,770   | 39.7     | 1.1      | 50.5     |
# | 2012 | 138,491  | 1.1      | 7.3      | 7.9      | 55,295   | 39.9     | 1.1      | 50.7     |
# | 2013 | 137,644  | 1.1      | 7.3      | 7.9      | 54,878   | 39.9     | 1.1      | 51.3     |
# | 2014 | 139,208  | 1.1      | 7.3      | 7.9      | 54,985   | 39.5     | 1.1      | 50.8     |
# | 2015 | 142,946  | 1.1      | 7.4      | 8.0      | 56,343   | 39.4     | 1.1      | 50.6     |
#
# ************
# child:  self index: 3 level: 3 loc: <(74, 29)> content:
# Partial Node
# | 2016 | 145,708  | 1.2      | 7.6      | 8.3      | 56,585   | 38.8     | 1.1      | 50.2     |
# | 2017 | 146,136  | 1.2      | 7.8      | 8.5      | 57,560   | 39.4     | 1.1      | 51.0     |
# | 2018 | 146,451  | 1.2      | 7.6      | 8.3      | 57,743   | 39.4     | 1.1      | 51.1     |
# | 2019 | 149,716  | 1.3      | 7.7      | 8.4      | 58,573   | 39.1     | 1.1      | 51.1     |
# | 2020 | 147,958  | 1.3      | 7.9      | 8.7      | 58,422   | 39.5     | 1.1      | 51.4     |
# | 2021 | 158,275  | 1.3      | 7.5      | 8.2      | 60,638   | 38.3     | 1.1      | 50.6     |
# | 2022 | 148,600  | 1.2      | 7.5      | 8.3      | 59,590   | 40.1     | 1.1      | 51.9     |
# | 2023 | 149,090  | 1.2      | 7.5      | 8.3      | 59,625   | 40.0     | 1.1      | 51.8     |
# | 2024 | 148,559  | 1.2      | 7.5      | 8.3      | 59,582   | 40.1     | 1.1      | 51.9     |
#
# ************
# child:  self index: 4 level: 3 loc: <(74, 29)> content:
# Partial Node
# | 2025 | 149,419  | 1.2      | 7.5      | 8.3      | 59,651   | 39.9     | 1.1      | 51.8     |
# | 2026 | 150,127  | 1.3      | 7.6      | 8.3      | 59,708   | 39.8     | 1.1      | 51.6     |
# | 2027 | 150,731  | 1.3      | 7.6      | 8.4      | 59,756   | 39.6     | 1.1      | 51.5     |
# | 2028 | 151,581  | 1.3      | 7.6      | 8.4      | 59,823   | 39.5     | 1.1      | 51.4     |
# | 2029 | 151,197  | 1.3      | 7.6      | 8.4      | 59,793   | 39.5     | 1.1      | 51.5     |
# | 2030 | 151,328  | 1.3      | 7.6      | 8.4      | 59,803   | 39.5     | 1.1      | 51.5     |
#
# *Figures are inflation adjusted to 2024
#
# This table presents data on Healthcare and Social Assistance in the US from 2009 to 2030. The data is inflation-adjusted to 2024 values. Here's a detailed analysis of the trends:
#
# 1. Column 1 (likely representing total industry value or employment):
#    - Shows an overall increasing trend from 136,753 in 2009 to 151,328 in 2030.
#    - Notable peaks in 2021 (158,275) and 2019 (149,716).
#    - Slight fluctuations observed, with some years showing decreases (e.g., 2020, 2022).
#
# 2. Column 2 (possibly market share or growth rate):
#    - Remains relatively stable, ranging from 1.1 to 1.3.
#    - Slight increase observed from 2016 onwards, with more years at 1.2 and 1.3.
#
# 3. Columns 3 and 4 (possibly representing different industry metrics):
#    - Column 3 shows a general increase from 7.3 in 2009 to 7.6 in 2030, with fluctuations.
#    - Column 4 follows a similar pattern, increasing from 7.8 in 2009 to 8.4 in 2030.
#
# 4. Column 5 (possibly representing industry revenue or employment in a specific sector):
#
# ************
# child:  self index: 5 level: 3 loc: <(74, 29)> content:
# Partial Node
#    - Shows an overall increasing trend from 55,100 in 2009 to 59,803 in 2030.
#    - Peak value observed in 2021 (60,638).
#
# 5. Column 6 (possibly representing a percentage or ratio):
#    - Fluctuates between 38.3% (2021) and 40.3% (2009).
#    - No clear long-term trend, but shows some variability year to year.
#
# 6. Column 7:
#    - Remains constant at 1.1 throughout the entire period.
#
# 7. Column 8 (possibly representing another industry metric or ratio):
#    - Shows an overall increasing trend from 48.9 in 2009 to 51.5 in 2030.
#    - Highest value observed in 2022 and 2024 (51.9).
#
# Overall, the data suggests a growing industry with increasing values in most metrics, but with some fluctuations and variations across different measures. The year 2021 stands out with peak values in several columns, possibly indicating a significant event or change in the industry that year.# Key Statistics
#
# Discover 14 years of historical, current and forward-looking industry performance data in table format.
#
# The image shows a page from what appears to be a market research report. The page has a bright red background with a large, stylized number "10" in a lighter shade of red taking up most of the right side of the image. The text "Key Statistics" is prominently displayed in white letters on the left side of the page, followed by a brief description in smaller white text.
#
# The page number 76 is visible in the bottom right corner, indicating this is likely part of a larger report or document.
#
# This introductory page suggests that the following section will contain detailed statistical data covering a 14-year period, including past, present, and future projections for the industry being analyzed. The data is promised to be presented in a table format, which implies easy readability and comparison of figures across different time periods.
#
# The design of the page, with its bold red color and large numeral, creates a strong visual impact and emphasizes the importance of the upcoming statistical information.# IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
#
# ************
# 205
#
# child:  self index: 0 level: 4 loc: <(77, 11)> content:
# Partial Node
#
# | Year | Revenue ($ Million) | IVA ($ Million) | Establishments (Units) | Enterprises (Units) | Employment (Units) | Wages ($ Million) |
# |------|---------------------|------------------|------------------------|----------------------|---------------------|-------------------|
# | 2005 | 2,339,027.4 | 1,102,667.1 | 2,415,640 | 2,268,432 | 17,694,187 | 933,599.3 |
# | 2006 | 2,389,725.8 | 1,152,341.2 | 2,490,936 | 2,334,330 | 18,179,846 | 962,059.1 |
# | 2007 | 2,475,596.5 | 1,192,852.6 | 2,552,324 | 2,383,160 | 18,565,740 | 998,518.3 |
# | 2008 | 2,566,681.9 | 1,233,365.9 | 2,602,651 | 2,432,609 | 19,028,900 | 1,035,731.3 |
# | 2009 | 2,653,111.7 | 1,297,155.2 | 2,668,952 | 2,495,545 | 19,400,823 | 1,068,987.6 |
# | 2010 | 2,713,529.1 | 1,387,472.8 | 2,747,691 | 2,566,257 | 19,722,690 | 1,080,844.1 |
# | 2011 | 2,764,294.4 | 1,395,441.4 | 2,786,825 | 2,601,677 | 20,027,211 | 1,096,897.6 |
# | 2012 | 2,814,322.8 | 1,427,614.9 | 2,776,911 | 2,583,752 | 20,321,370 | 1,123,668.0 |
# | 2013 | 2,829,750.2 | 1,450,790.1 | 2,803,326 | 2,606,496 | 20,558,434 | 1,128,198.6 |
# | 2014 | 2,900,825.2 | 1,473,572.1 | 2,841,294 | 2,637,228 | 20,838,080 | 1,145,778.8 |
# | 2015 | 3,030,557.9 | 1,533,939.0 | 2,854,922 | 2,636,040 | 21,200,714 | 1,194,516.5 |
# | 2016 | 3,160,341.4 | 1,587,572.4 | 2,844,321 | 2,615,445 | 21,689,510 | 1,227,293.5 |
# | 2017 | 3,241,665.3 | 1,652,853.5 | 2,838,732 | 2,596,166 | 22,182,535 | 1,276,820.3 |
# | 2018 | 3,305,377.2 | 1,689,978.6 | 2,978,551 | 2,734,918 | 22,569,878 | 1,303,249.5 |
# | 2019 | 3,432,647.9 | 1,754,857.1 | 2,981,341 | 2,728,239 | 22,927,718 | 1,342,939.4 |
# | 2020 | 3,436,282.1 | 1,767,371.5 | 2,936,363 | 2,679,287 | 23,224,758 | 1,356,831.6 |
# | 2021 | 3,603,374.3 | 1,821,667.4 | 3,032,512 | 2,767,646 | 22,766,535 | 1,380,510.5 |
# | 2022 | 3,463,078.6 | 1,796,442.9 | 3,097,981 | 2,820,322 | 23,304,679 | 1,388,714.6 |
# | 2023 | 3,545,302.4 | 1,836,875.0 | 3,149,743 | 2,865,549 | 23,779,558 | 1,417,859.4 |
# | 2024 | 3,554,946.9 | 1,844,603.9 | 3,181,313 | 2,895,235 | 23,929,599 | 1,425,773.5 |
# | 2025 | 3,667,452.8 | 1,898,128.1 | 3,253,262 | 2,958,777 | 24,544,783 | 1,464,121.1 |
# | 2026 | 3,768,451.0 | 1,945,861.5 | 3,314,065 | 3,011,926 | 25,101,782 | 1,498,765.6 |
# | 2027 | 3,869,536.2 | 1,994,568.2 | 3,380,099 | 3,070,257 | 25,671,761 | 1,534,031.9 |
# | 2028 | 4,004,346.9 | 2,058,764.5 | 3,468,429 | 3,148,506 | 26,417,157 | 1,580,353.9 |
# | 2029 | 4,055,017.5 | 2,087,278.3 | 3,526,323 | 3,201,660 | 26,819,483 | 1,603,608.2 |
# | 2030 | 4,146,094.8 | 2,133,374.1 | 3,597,535 | 3,265,707 | 27,398,086 | 1,638,488.7 |
#
# This table presents key industry data for Healthcare and Social Assistance in the US from 2005 to 2030. It shows annual figures for Revenue, Industry Value Added (IVA), number of Establishments, number of Enterprises, Employment, and Wages.
#
# The data reveals several trends:
#
# 1. Revenue: There is a consistent increase in revenue from $2,339,027.4 million in 2005 to a projected $4,146,094.8 million in 2030, indicating steady growth in the industry.
#
#
# ************
# child:  self index: 1 level: 4 loc: <(77, 11)> content:
# Partial Node
# 2. IVA: Industry Value Added also shows an upward trend, rising from $1,102,667.1 million in 2005 to an estimated $2,133,374.1 million in 2030.
#
# 3. Establishments: The number of establishments has grown from 2,415,640 in 2005 to a projected 3,597,535 in 2030, suggesting expansion in the industry's physical presence.
#
# 4. Enterprises: The number of enterprises follows a similar growth pattern, increasing from 2,268,432 in 2005 to an estimated 3,265,707 in 2030.
#
# 5. Employment: The industry has seen significant job growth, with employment numbers rising from 17,694,187 in 2005 to a projected 27,398,086 in 2030.
#
# 6. Wages: Total wages in the industry have also increased substantially, from $933,599.3 million in 2005 to an estimated $1,638,488.7 million in 2030.
#
# The data indicates consistent growth across all metrics, with occasional slight fluctuations. Notable is the continued growth even through economic challenges such as the 2008 financial crisis and the 2020 pandemic, suggesting the resilience of the Healthcare and Social Assistance industry in the US.# IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
# *Figures are inflation adjusted to 2024
#
# The image appears to be a title page or header for a report on Healthcare and Social Assistance in the United States. The page is mostly blank, with minimal text content. The title and date are positioned at the top of the page, while a small footnote about inflation adjustment is placed below. At the bottom right corner of the page, there is a page number "78" enclosed in a red circle, indicating this is likely page 78 of the report.# IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
#
# ************
# 206
#
# child:  self index: 0 level: 3 loc: <(79, 5)> content:
# Partial Node
#
# | Year | Revenue % | IVA % | Establishments % | Enterprises % | Employment % | Wages % |
# |------|-----------|-------|------------------|---------------|--------------|---------|
# | 2005 | N/A | N/A | N/A | N/A | N/A | N/A |
# | 2006 | 2.2 | 4.5 | 3.1 | 2.9 | 2.7 | 3.0 |
# | 2007 | 3.6 | 3.5 | 2.5 | 2.1 | 2.1 | 3.8 |
# | 2008 | 3.7 | 3.4 | 2.0 | 2.1 | 2.5 | 3.7 |
# | 2009 | 3.4 | 5.2 | 2.5 | 2.6 | 2.0 | 3.2 |
# | 2010 | 2.3 | 7.0 | 3.0 | 2.8 | 1.7 | 1.1 |
# | 2011 | 1.9 | 0.6 | 1.4 | 1.4 | 1.5 | 1.5 |
# | 2012 | 1.8 | 2.3 | -0.4 | -0.7 | 1.5 | 2.4 |
# | 2013 | 0.5 | 1.6 | 1.0 | 0.9 | 1.2 | 0.4 |
# | 2014 | 2.5 | 1.6 | 1.4 | 1.2 | 1.4 | 1.6 |
# | 2015 | 4.5 | 4.1 | 0.5 | 0.0 | 1.7 | 4.3 |
# | 2016 | 4.3 | 3.5 | -0.4 | -0.8 | 2.3 | 2.7 |
# | 2017 | 2.6 | 4.1 | -0.2 | -0.7 | 2.3 | 4.0 |
# | 2018 | 2.0 | 2.2 | 4.9 | 5.3 | 1.7 | 2.1 |
# | 2019 | 3.9 | 3.8 | 0.1 | -0.2 | 1.6 | 3.0 |
# | 2020 | 0.1 | 0.7 | -1.5 | -1.8 | 1.3 | 1.0 |
# | 2021 | 4.9 | 3.1 | 3.3 | 3.3 | -2.0 | 1.7 |
# | 2022 | -3.9 | -1.4 | 2.2 | 1.9 | 2.4 | 0.6 |
# | 2023 | 2.4 | 2.3 | 1.7 | 1.6 | 2.0 | 2.1 |
# | 2024 | 0.3 | 0.4 | 1.0 | 1.0 | 0.6 | 0.6 |
# | 2025 | 3.2 | 2.9 | 2.3 | 2.2 | 2.6 | 2.7 |
# | 2026 | 2.8 | 2.5 | 1.9 | 1.8 | 2.3 | 2.4 |
# | 2027 | 2.7 | 2.5 | 2.0 | 1.9 | 2.3 | 2.4 |
# | 2028 | 3.5 | 3.2 | 2.6 | 2.5 | 2.9 | 3.0 |
# | 2029 | 1.3 | 1.4 | 1.7 | 1.7 | 1.5 | 1.5 |
# | 2030 | 2.2 | 2.2 | 2.0 | 2.0 | 2.2 | 2.2 |
#
# The table presents annual changes in various metrics for the Healthcare and Social Assistance industry in the US from 2005 to 2030. The metrics include Revenue, IVA (Industry Value Added), Establishments, Enterprises, Employment, and Wages, all expressed as percentages.
#
# Key observations:
#
# 1. Data for 2005 is not available (N/A) across all metrics.
#
# 2. Revenue growth was highest in 2021 (4.9%) and lowest in 2022 (-3.9%).
#
# 3. IVA growth peaked in 2010 (7.0%) and was lowest in 2022 (-1.4%).
#
#
# ************
# child:  self index: 1 level: 3 loc: <(79, 5)> content:
# Partial Node
# 4. Establishments and Enterprises growth rates generally follow similar patterns, with the highest growth in 2018 (4.9% and 5.3% respectively) and the lowest in 2020 (-1.5% and -1.8% respectively).
#
# 5. Employment growth was highest in 2006 (2.7%) and lowest in 2021 (-2.0%), the only year showing negative growth.
#
# 6. Wage growth was highest in 2015 (4.3%) and lowest in 2013 (0.4%).
#
# 7. The industry shows some volatility, particularly in recent years (2020-2022), likely reflecting the impact of external factors such as the COVID-19 pandemic.
#
# 8. Projections for 2024-2030 suggest relatively stable growth across all metrics, with most values ranging between 1.5% and 3.5%.
#
# *Figures are inflation adjusted to 2024
#
# ************

# %%
# iterate over the tree and print nodes with text size more than 500 words
new_large_nodes = []
print_nodes_with_text_size_more_than_500_words(root, new_large_nodes)
print(len(new_large_nodes))
# Out:
# 0

# %%
# for each node in the tree, set embedding text which is all the headings of the ancestors prefixed to the text of the node

def set_embedding_text(node, recursive_headings=[]):
    if node.level != 0 and node.text is not None:
        node.embedding_text = "\n".join(recursive_headings) + "\n" + node.heading + "\n" + node.text
    if len(node.children) > 0:
        for child in node.children:
            recursive_headings.append(node.heading)
            set_embedding_text(child, recursive_headings)
            recursive_headings.pop()
    return

set_embedding_text(root)

# %%
print(root.children[0].children[1].embedding_text)
# Out:
# # Healthcare and Social Assistance in the US
# ## Table Of Contents
#
# Standard
#
# 1. About............................................................ 5
#    Codes............................................................5
#    Definition....................................................... 5
#    Related Terms.............................................. 5
#    What's Included............................................ 6
#    Companies....................................................6
#    Related Industries......................................... 6
#    Additional Resources.................................... 6
#
# 2. At a Glance...................................................9
#    Key Takeaways.............................................9
#    Products and Services................................ 10
#    Major Players.............................................. 11
#    Key External Drivers................................... 12
#    Industry Structure........................................12
#    SWOT......................................................... 13
#    Executive Summary.................................... 13
#
# 3. Performance............................................... 15
#    Highlights.................................................... 15
#    Key Takeaways...........................................15
#    Performance Snapshot............................... 16
#    Outlook........................................................25
#    Life Cycle.................................................... 28
#
# 4. Products and Markets.................................30
#    Key Takeaways...........................................30
#    Products and Services................................ 30
#    Major Markets............................................. 35
#    International Trade......................................37
#
# 5. Geographic Breakdown.............................. 39
#    Key Takeaways...........................................39
#    Business Locations..................................... 40
#
# 6. Competitive Forces.....................................46
#    Key Takeaways...........................................46
#    Concentration..............................................46
#    Barriers to Entry.......................................... 47
#    Substitutes.................................................. 48
#    Buyer & Supplier Power..............................49
#
# 7. Companies................................................. 52
#    Key Takeaways...........................................52
#    Market Share.............................................. 53
#    Companies..................................................54
#
# 8. External Environment................................. 67
#    Key Takeaways...........................................67
#    External Drivers.......................................... 67
#    Regulation & Policy..................................... 69
#    Assistance...................................................71
#
# 9. Financial Benchmarks................................ 73
#    Key Takeaways...........................................73
#    Cost Structure............................................. 73
#    Key Ratios...................................................74
#
# 10. Key Statistics............................................ 77
#     Industry Data...............................................77
#
# The image displays a table of contents for a report on Healthcare and Social Assistance in the US. The table is comprehensive, covering various aspects of the industry from basic information to detailed analysis. It includes sections on industry overview, performance metrics, market analysis, competitive landscape, and financial benchmarks. The structure suggests a thorough examination of the sector, providing both broad insights and specific data points across 77 pages. The content is organized into 10 main sections, each with multiple subsections, indicating a detailed and well-structured report.# About
#
# A quick definition of the industry, its products and services, major companies and other key identifiers help you confirm you're in the right place.
#
# The image shows a primarily red background with a large white number "1" or a stylized shape resembling the number 1 on the right side. This shape is slightly lighter in color than the surrounding red background, creating a subtle contrast. The text "About" is displayed prominently in white at the bottom left corner of the image, followed by a brief description in smaller white text. The page number "4" is visible in the bottom right corner.
#
# This appears to be an introductory or section divider page for a report or presentation, setting the stage for information about an industry or business sector. The stark red color and minimalist design create a bold, attention-grabbing visual impact.

# %%
# create llama-index text nodes from the tree structure
from llama_index.core.schema import TextNode
def create_text_nodes_from_tree(node, llama_text_nodes):
    if node.level != 0 and node.embedding_text is not None:
        text_node = TextNode(
            text=node.embedding_text,
            metadata={"page_number": node.page, "line_number": node.line_number, "level": node.level}
        )
        llama_text_nodes.append(text_node)
    if len(node.children) > 0:
        for child in node.children:
            create_text_nodes_from_tree(child, llama_text_nodes)
    return

# %%
llama_text_nodes = []
create_text_nodes_from_tree(root, llama_text_nodes)
print(len(llama_text_nodes))
# Out:
# 230

# %%
import weaviate

cluster_url = "https://a0dlgmcaspopjrn2mtx4ha.c0.us-east1.gcp.weaviate.cloud"
api_key = "7ZfUCibywHnzM0WKMPx7YevuN79nUtS4KJgT"

client = weaviate.connect_to_wcs(
    cluster_url=cluster_url,
    auth_credentials=weaviate.auth.AuthApiKey(api_key),
)

# %%
from llama_index.vector_stores.weaviate import WeaviateVectorStore
from llama_index.core import VectorStoreIndex
import uuid

# generate unique index for multiple runs
INDEX_NAME = ('X' + str(uuid.uuid4())).replace('-', '_')

vector_store = WeaviateVectorStore(
    weaviate_client=client, index_name=INDEX_NAME
)

vector_index = VectorStoreIndex(llama_text_nodes, vector_store=vector_store)
# Out:
# /Users/mbajaj/anaconda/envs/rag_omega/lib/python3.10/site-packages/weaviate/warnings.py:305: ResourceWarning: Con004: The connection to Weaviate was not closed properly. This can lead to memory leaks.
#             Please make sure to close the connection using `client.close()`.
#   warnings.warn(

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model=MODEL_ID, api_key = OPENAI_API_KEY)
query_engine = vector_index.as_query_engine(similarity_top_k=TOP_K, llm=llm)

# %%
import braintrust
use_braintrust_dataset = False
if use_braintrust_dataset:
    dataset = braintrust.init_dataset(project="RagMetrics", name=DOC_ID)
    df = []
    for row in dataset:
        df.append(row)
    # convert list of dict to pandas dataframe
    dff = pd.DataFrame(df)
    dff['question'] = dff['input'].apply(lambda x: x.split(">")[1])
else:

    df = pd.read_csv(COMPARISON_FILE)
    if NUM_QUESTIONS == -1:
        dff = df.copy()
    else:
        dff = df.head(NUM_QUESTIONS).copy()

# %%
print(dff.shape)
print(dff.head())
# Out:
# (213, 7)
#                                             question  \
# 0  What types of enterprises are included in the ...
# 1  How is telemedicine defined in the context of ...
# 2  What are Health Insurance Exchanges in the US ...
# 3  What services are included in the Healthcare a...
# 4  Who are some of the major companies operating ...
#
#                                               answer source type answer type  \
# 0  The Healthcare and Social Assistance sector in...        text       other
# 1  Telemedicine is defined as an application of c...        text       other
# 2  Health Insurance Exchanges are sets of state-r...        text       other
# 3  The Healthcare and Social Assistance industry ...        text       other
# 4  Major companies in the industry include Hca He...        text       other
#
#    page                                               file  \
# 0     5  62 Healthcare and Social Assistance in the US ...
# 1     5  62 Healthcare and Social Assistance in the US ...
# 2     5  62 Healthcare and Social Assistance in the US ...
# 3     6  62 Healthcare and Social Assistance in the US ...
# 4     6  62 Healthcare and Social Assistance in the US ...
#
#                                          explanation
# 0  Understanding the scope of the Healthcare and ...
# 1  Identifying key technological trends like tele...
# 2  Understanding the structure of health insuranc...
# 3  Understanding the scope of services in the ind...
# 4  Identifying key players helps in understanding...

# %%
result = []
references = []
contexts = []

# %%
start_idx = len(result) 
for idx in range(start_idx, len(dff)):
    question = dff.iloc[idx][QUESTION_COL]
    response = query_engine.query(question)
    result.append((response.response))
    metadata = response.metadata
    refs = []
    for m in metadata.values():
        refs.append(m['page_number'])
    references.append(refs)
    q_contexts = []
    for n in response.source_nodes:
        q_contexts.append(n.text)
    contexts.append(q_contexts)

# %%
dff[RESPONSE_COL] = result
dff['references'] = references
dff['context'] = contexts
dff.to_csv(OUTPUT_FILE, index=False)

# %%
dff.head()
# Out:
#                                             question  \
# 0  What types of enterprises are included in the ...
# 1  How is telemedicine defined in the context of ...
# 2  What are Health Insurance Exchanges in the US ...
# 3  What services are included in the Healthcare a...
# 4  Who are some of the major companies operating ...
#
#                                               answer source type answer type  \
# 0  The Healthcare and Social Assistance sector in...        text       other
# 1  Telemedicine is defined as an application of c...        text       other
# 2  Health Insurance Exchanges are sets of state-r...        text       other
# 3  The Healthcare and Social Assistance industry ...        text       other
# 4  Major companies in the industry include Hca He...        text       other
#
#    page                                               file  \
# 0     5  62 Healthcare and Social Assistance in the US ...
# 1     5  62 Healthcare and Social Assistance in the US ...
# 2     5  62 Healthcare and Social Assistance in the US ...
# 3     6  62 Healthcare and Social Assistance in the US ...
# 4     6  62 Healthcare and Social Assistance in the US ...
#
#                                          explanation  \
# 0  Understanding the scope of the Healthcare and ...
# 1  Identifying key technological trends like tele...
# 2  Understanding the structure of health insuranc...
# 3  Understanding the scope of services in the ind...
# 4  Identifying key players helps in understanding...
#
#                                   rag_model_response    references  \
# 0  The Healthcare and Social Assistance sector in...   [5, 32, 36]
# 1  Telemedicine is defined as an application of c...   [25, 5, 32]
# 2  Health Insurance Exchanges in the US healthcar...    [5, 36, 5]
# 3  The Healthcare and Social Assistance industry ...   [5, 30, 10]
# 4  Some of the major companies operating in the H...  [11, 30, 53]
#
#                                              context
# 0  [\n# Healthcare and Social Assistance in the U...
# 1  [\n# Healthcare and Social Assistance in the U...
# 2  [\n# Healthcare and Social Assistance in the U...
# 3  [\n# Healthcare and Social Assistance in the U...
# 4  [\n# Healthcare and Social Assistance in the U...

# %%
print(len(result), len(references), len(contexts))
# Out:
# 213 213 213

# %%
def print_multi_line(response, max_chars=100):
    # print max 20 words of the response in single line and then move to next line
    response_text = response.response
    response_text_words = response_text.split(" ")
    response_text_lines = []
    current_line = ""
    for word in response_text_words:
        if len(current_line) + len(word) < 100:
            current_line += word + " "
        else:
            response_text_lines.append(current_line)
            current_line = word + " "

    response_text_lines.append(current_line)

    return response_text_lines

# %%
question = "What are US healthcare total revenue figures for recent years?"
response = query_engine.query(question)
ans = print_multi_line(response)
print("\n".join(ans))
# Out:
# The total revenue for the US healthcare sector is projected to be $3.6 trillion for 2024. Over the
# past five years, revenue has been expanding at a compound annual growth rate (CAGR) of 0.7%.
# Looking ahead, the revenue growth rate is expected to increase to 2.7% for the period from 2024 to
# 2029.

# %%
def get_references(response):
    references = []
    for n in response.source_nodes:
        references.append({"page number": n.metadata["page_number"], "line number": n.metadata["line_number"]})
    return references

# %%
question = "what are the fragments and their proportion of total revenue?"
response = query_engine.query(question)
ans = print_multi_line(response)
print("\n".join(ans))
print("references: ", get_references(response))
# Out:
# The fragments and their proportions of total revenue in the Healthcare and Social Assistance
# industry for 2024 are as follows:
#
# 1. Private health insurance: 30.4% ($1.1 trillion)
# 2. Medicare:
# 22.2% ($789.2 billion)
# 3. Medicaid: 19.0% ($675.4 billion)
# 4. Other third-party payers: 13.3%
# ($472.8 billion)
# 5. Out-of-pocket expenses: 11.1% ($394.6 billion)
# 6. Other health insurance
# programs: 4.0% ($142.2 billion)
# references:  [{'page number': 35, 'line number': 5}, {'page number': 73, 'line number': 18}, {'page number': 74, 'line number': 29}]

# %%
question = "what are the profit margins in the industry?"
response = query_engine.query(question)
ans = print_multi_line(response)
print("\n".join(ans))
print("references: ", get_references(response))
# Out:
# The profit margin for the Healthcare and Social Assistance sector in the US is 10.0%. For Feeding
# America, the profit margin is 8.5%, which has been maintained from 2020 through 2024.
# references:  [{'page number': 73, 'line number': 1}, {'page number': 74, 'line number': 19}, {'page number': 60, 'line number': 20}]

# %%
node_x = root.children[0].children[4].children[3].children[0]
print(node_x, node_x.refined_output_idx)
print(refined_output[node_x.refined_output_idx])
print(refined_output[node_x.refined_output_idx+1])
# Out:
# self index: 0 level: 4 loc: <(20, 7)> content: #### What's driving current industry performance? 46
# (20, 7, "#### What's driving current industry performance?", 4)
# (20, 9, '##### Demographic trends shape the healthcare landscape', 5)

# %%
doc = Document(text="hello")
print(root.children[0].children[4].children[3].children[0].heading)
print(root.children[0].children[4].children[3].children[0].children)
text1 = get_node_text(root.children[0].children[4].children[3].children[0].children[2])
print(text1)
# Out:
# #### What's driving current industry performance?
# [self index: 0 level: 5 loc: <(20, 9)> content: ##### Demographic trends shape the healthcare landscape, self index: 1 level: 5 loc: <(20, 17)> content: ##### Healthcare providers grapple with persistent workforce shortages, self index: 2 level: 5 loc: <(20, 27)> content: ##### The pandemic accelerated existing consolidation trends in healthcare, self index: 3 level: 5 loc: <(21, 7)> content: ##### Social assistance providers fill in the gaps as pandemic-era benefits end]
#
# - Larger health systems eye acquisitions to create economies of scale, lower costs and gain negotiating power. The pandemic accelerated the rising consolidation activity that had been occurring in recent years.
#
# - Private and public insurers only partially cover the cost of delivering healthcare, incentivizing healthcare providers to acquire an upper hand in provider-payer negotiations. Independent (often small or rural) practices risking service eliminations or closure have been targets of acquisitions.# IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# - The dramatic rise in the adoption of telemedicine in 2020 has fallen from its pandemic high but is still more integral to healthcare delivery in 2024 than pre-COVID, especially for providers offering mental health treatment.
#
# - The challenges impacting healthcare providers are also expediting the adoption of other digital tools (AI, patient engagement products, data analytics) to streamline operations and produce cost savings.

# %%
output_list[2]
# Out:
# '<1, 5> # Healthcare and Social Assistance in the US'

# %%
root.children[0].children[5].children
# Out:
# [self index: 0 level: 3 loc: <(30, 11)> content: ### Key Takeaways,
#  self index: 1 level: 3 loc: <(30, 16)> content: ### Products and Services,
#  self index: 2 level: 3 loc: <(34, 5)> content: ### Key Success Factor,
#  self index: 3 level: 3 loc: <(35, 3)> content: ### Major Markets,
#  self index: 4 level: 3 loc: <(37, 5)> content: ### International Trade]

# %% [markdown]
# # let's detail cases that are possible if we make text under each

# %%
all_sentences[0]
# Out:
# ['# IBISWorld',
#  '',
#  '## INDUSTRY REPORT',
#  '',
#  '# Healthcare and Social Assistance in the US',
#  '',
#  '### Mar 2024',
#  '',
#  'The image shows the cover page of an industry report by IBISWorld. The report focuses on Healthcare and Social Assistance in the United States, dated March 2024. The design features a dark blue background with red circular elements in the corners. The IBISWorld logo appears in a red rectangular shape at the top left corner of the page. The title and information are presented in white text, creating a strong contrast against the dark background. This cover page design suggests a professional and authoritative report on the healthcare and social assistance sectors in the US market.']
