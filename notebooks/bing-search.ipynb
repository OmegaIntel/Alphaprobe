# %%
from api.search import bing_search

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
search = bing_search.BingSearch()

results = search.search("US Open Tennis 2024 results")
# Out:
# searching internet for US Open Tennis 2024 results

# %%
results
# Out:
# {'_type': 'SearchResponse',
#  'queryContext': {'originalQuery': 'US Open Tennis 2024 results'},
#  'webPages': {'webSearchUrl': 'https://www.bing.com/search?q=US+Open+Tennis+2024+results',
#   'totalEstimatedMatches': 18900000,
#   'value': [{'id': 'https://api.bing.microsoft.com/api/v7/#WebPages.0',
#     'name': 'Live Scores - Official Site of the 2024 US Open Tennis Championships ...',
#     'url': 'https://www.usopen.org/en_US/scores/index.html',
#     'isFamilyFriendly': True,
#     'displayUrl': 'https://www.us<b>open</b>.org/en_US/scores',
#     'snippet': 'View your favorite players and locate their matches. EDIT. Men&#39;s SinglesR2. Serve Speed: 88 MPH. Arthur Ashe Stadium Duration: 2:06. L. Djere. 0. 4. 4.',
#     'deepLinks': [{'name': 'Event Statistics',
#       'url': 'https://www.usopen.org/en_US/scores/extrastats/index.html',
#       'snippet': 'US Open Tennis Championships youtube.com/user/usopen. US Open tiktok.com/@usopen. August 19 - September 8, 2024'},
# ...

# %%
summaries = search.parse_search_results(results)
# Out:
# fetching https://www.usopen.org/en_US/scores/index.html
# fetching https://www.usopen.org/en_US/scores/completed_matches/index.html
# fetching https://www.sportingnews.com/us/tennis/news/us-open-results-2024-live-tennis-scores-bracket-flushing/8ae7f10ea0d15b21bbbe7678
# content loaded
# summary generated
# fetching https://www.usopen.org/index.html
# fetching https://www.cbssports.com/tennis/news/us-open-tennis-2024-schedule-bracket-live-updates-scores-results-highlights-start-times-where-to-watch/live/
# content loaded
# summary generated

# %%
summaries
# Out:
# [{'name': 'Live Scores - Official Site of the 2024 US Open Tennis Championships ...',
#   'url': 'https://www.usopen.org/en_US/scores/index.html',
#   'snippet': 'View your favorite players and locate their matches. EDIT. Men&#39;s SinglesR2. Serve Speed: 88 MPH. Arthur Ashe Stadium Duration: 2:06. L. Djere. 0. 4. 4. | Summary: Request timed out.',
#   'dateLastCrawled': '2024-08-28T13:14:00.0000000Z'},
#  {'name': 'Results - Official Site of the 2024 US Open Tennis Championships - A ...',
#   'url': 'https://www.usopen.org/en_US/scores/completed_matches/index.html',
#   'snippet': 'August 19 - September 8, <b>2024</b>. Stay up to date with live scoring and results from every match at the US <b>Open</b>, <b>including</b> singles and doubles plus the junior and wheelchair tournaments. | Summary: Request timed out.',
#   'dateLastCrawled': '2024-08-28T13:33:00.0000000Z'},
#  {'name': 'US Open results 2024: Live tennis scores, full draw, bracket at ...',
# ...
