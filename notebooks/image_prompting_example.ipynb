# %%
IMAGE_PROMPT = """
Given an image of a page from a market research report, your task is to convert all the information on the page into markdown format, preserving the original structure and content.

- Transcribe all text, including paragraphs and headings, verbatim from the page to markdown, maintaining the original format. Do not modify, omit, or add any text.
- If the page includes numerical information with arrows, percentages etc, describe the text in full sentences in markdown format. For example, if there's a box with the text "revenue of wine industry" and an arrow pointing up saying "10% (2015-2020)", describe this as "Revenue of wine industry increased by 10% from 2015 to 2020" instead of just copying the text.
- Do not explain any text that is clearly written in the page, including headings, subheadings, and paragraphs. Copy the text as it is.
- If the text structure is unclear, use your best judgement to format it in markdown.
- If the page contains tables, convert them into markdown table format and provide an explnation as well. Explain all the data that can be inferred from each table. For example, if a table shows sales data for different products, explain the sales trends and patterns with respect to each product. Try to provide as much detail as possible.
- If the page includes a plot or graph, describe it objectively in markdown format. Explain all the details that can be inferred from the plot or graph. For example, if a plot shows sales trends over time, describe the sales trends and patterns observed. Provide a detailed explanation of the data represented in the plot or graph.
- When explaining any component, understand the context of the entire page and be as specific as possible without any ambiguity. The position of the explanation should match the position of the component in the page.
- The output should not contain personal opinions or biases. Do not add personal comments or any information not present on the page. Avoid referring to the page or the report - explain without reference.
- Ensure no important information from the page is missed, as capturing all details is crucial.
"""

# %%
from pdf2image import convert_from_path
import os
import base64
import requests
import logging
from openai import OpenAI
import pickle
from langchain_core.documents import Document


os.environ["OPENAI_API_KEY"] = 
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')


model = "gpt-4o-mini"

def request_openai_with_image(base64_image):
    responded = False
    num_tries = 0
    while not responded and num_tries < 5:
        num_tries += 1

        client = OpenAI()
        response = client.chat.completions.create(
            model=model,
            messages=[
                {
                    "role": "system",
                    "content": {"type": "text", "text": "You are a profession converter that converts all the details in given image of page of a market research report to markdown format while preserving all the structure."}
                },
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": IMAGE_PROMPT},
                        {
                            "type": "image_url",
                            "image_url": {
                                "url": f"data:image/png;base64,{base64_image}",
                                "detail": "high"
                            },
                        },
                        {"type": "text", "text": "Please describe the provided page in markdown format. Strictly follow the criteria mentioned above to describe each component of the page."},
                    ],
                }
            ],
            max_tokens=10000,
        )

        print(response)
        response_txt = response.choices[0].message.content
        print(response_txt)

    
        try:
            response_txt = response.choices[0].message.content
            responded = True
            return response_txt
        except:
            continue
    return ""

data_dir = "./data/report2"
pdf_path = os.path.join(data_dir, "health.pdf")
img_dir = os.path.join(data_dir, "imgs")
if not os.path.exists(img_dir):
    os.makedirs(img_dir)

output_text = os.path.join(data_dir, f"./_{model}_pages.txt")
output_pickle = os.path.join(data_dir, f"{model}_pages.pkl")


images = convert_from_path(pdf_path)
pages = []
# Iterate over the images
for i, image in enumerate(images):
    # Define the path to save the image
    image_path = os.path.join(img_dir, f'page_{i+1}.png')

    # Save the image
    image.save(image_path, 'PNG')
    logging.info(f"Saved image {i+1} to {image_path}")
    base64_image = encode_image(image_path)
    response = request_openai_with_image(base64_image)

    # convert the response to langchain document
    doc = Document(page_content=response, metadata={"page": i+1})
    pages.append(doc)

# save the pages as txt file
txt_path = output_text
with open(txt_path, "w") as f:
    for page in pages:
        print(page.page_content)
        #write page number
        f.write(f"Page {page.metadata['page']}\n")
        f.write(page.page_content)
        f.write("\n")

pickle.dump(pages, open(output_pickle, "wb"))
# Out:
# ChatCompletion(id='chatcmpl-AE046HCyz9WyqqL1YhzYdeiZKyCIW', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```markdown\n# INDUSTRY REPORT\n## Healthcare and Social Assistance in the US\n\n### Mar 2024\n```', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1727900206, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_74ba47b4ac', usage=CompletionUsage(completion_tokens=24, prompt_tokens=37304, total_tokens=37328, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}))
# ```markdown
# # INDUSTRY REPORT
# ## Healthcare and Social Assistance in the US
#
# ### Mar 2024
# ```
# ChatCompletion(id='chatcmpl-AE049QHhvpF5PmmUgofDp1TFI2Hsq', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```markdown\n# About IBISWorld\n\nIBISWorld specializes in industry research with coverage on thousands of global industries. Our comprehensive data and in-depth analysis help businesses of all types gain quick and actionable insights on industries around the world. Busy professionals can spend less time researching and preparing for meetings, and more time focused on making strategic business decisions.\n```', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1727900209, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_74ba47b4ac', usage=CompletionUsage(completion_tokens=70, prompt_tokens=37304, total_tokens=37374, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}))
# ```markdown
# # About IBISWorld
#
# IBISWorld specializes in industry research with coverage on thousands of global industries. Our comprehensive data and in-depth analysis help businesses of all types gain quick and actionable insights on industries around the world. Busy professionals can spend less time researching and preparing for meetings, and more time focused on making strategic business decisions.
# ```
# ChatCompletion(id='chatcmpl-AE04CxEFy4W54sFxH9lkU99N3BEsX', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```markdown\n# IBISWorld | Healthcare and Social Assistance in the US\n**Mar 2024**\n\n## Table Of Contents\n\n1. About............................................................ 5\n   - Codes....................................................... 5\n   - Definition................................................. 5\n   - Related Terms........................................... 5\n   - What’s Included.......................................... 6\n   - Companies................................................. 6\n   - Related Industries....................................... 6\n   - Additional Resources.................................... 6\n\n2. At a Glance..................................................... 9\n   - Key Takeaways............................................. 9\n   - Products and Services.................................. 10\n   - Major Players................................................ 11\n   - Key External Drivers..................................... 12\n   - Industry Structure......................................... 12\n   - SWOT................................................................ 13\n   - Executive Summary...................................... 13\n\n3. Performance.................................................. 15\n   - Highlights.................................................. 15\n   - Key Takeaways............................................. 15\n   - Performance Snapshot................................. 16\n   - Outlook...................................................... 25\n   - Life Cycle.................................................. 28\n\n4. Products and Markets....................................... 30\n   - Key Takeaways............................................. 30\n   - Products and Services.................................. 30\n   - Major Markets................................................ 35\n   \n5. Geographic Breakdown..................................... 39\n   - Key Takeaways............................................. 39\n   - Business Locations....................................... 40\n\n6. Competitive Forces.......................................... 46\n   - Key Takeaways............................................. 46\n   - Concentration.............................................. 46\n   - Barriers to Entry......................................... 47\n   - Substitutes................................................ 48\n   - Buyer & Supplier Power................................ 49\n\n7. Companies.................................................... 52\n   - Key Takeaways............................................. 52\n   - Market Share................................................ 53\n   - Companies..................................................... 54\n\n8. External Environment..................................... 67\n   - Key Takeaways............................................. 67\n   - External Drivers.......................................... 67\n   - Regulation & Policy..................................... 69\n   - Assistance................................................... 71\n\n9. Financial Benchmarks...................................... 73\n   - Key Takeaways............................................. 73\n   - Cost Structure............................................. 73\n   - Key Ratios................................................... 74\n\n10. Key Statistics................................................. 77\n    - Industry Data.............................................. 77\n```\n\n### Explanation of Components\n\n- The table of contents details the sections of the report, with subsections listed under relevant headings.\n- Each section contains page numbers indicating where the information can be found within the document. \n- Key topics such as "Performance," "Pr ...
# ```markdown
# # IBISWorld | Healthcare and Social Assistance in the US
# **Mar 2024**
#
# ## Table Of Contents
#
# 1. About............................................................ 5
#    - Codes....................................................... 5
#    - Definition................................................. 5
#    - Related Terms........................................... 5
#    - What’s Included.......................................... 6
#    - Companies................................................. 6
#    - Related Industries....................................... 6
#    - Additional Resources.................................... 6
#
# 2. At a Glance..................................................... 9
#    - Key Takeaways............................................. 9
#    - Products and Services.................................. 10
#    - Major Players................................................ 11
#    - Key External Drivers..................................... 12
#    - Industry Structure......................................... 12
#    - SWOT................................................................ 13
#    - Executive Summary...................................... 13
#
# 3. Performance.................................................. 15
#    - Highlights.................................................. 15
#    - Key Takeaways............................................. 15
#    - Performance Snapshot................................. 16
#    - Outlook...................................................... 25
#    - Life Cycle.................................................. 28
#
# 4. Products and Markets....................................... 30
#    - Key Takeaways............................................. 30
#    - Products and Services.................................. 30
#    - Major Markets................................................ 35
#
# 5. Geographic Breakdown..................................... 39
#    - Key Takeaways............................................. 39
#    - Business Locations....................................... 40
#
# 6. Competitive Forces.......................................... 46
#    - Key Takeaways............................................. 46
#    - Concentration.............................................. 46
#    - Barriers to Entry......................................... 47
#    - Substitutes................................................ 48
#    - Buyer & Supplier Power................................ 49
#
# 7. Companies.................................................... 52
#    - Key Takeaways............................................. 52
#    - Market Share................................................ 53
#    - Companies..................................................... 54
#
# 8. External Environment..................................... 67
#    - Key Takeaways............................................. 67
#    - External Drivers.......................................... 67
#    - Regulation & Policy..................................... 69
#    - Assistance................................................... 71
#
# 9. Financial Benchmarks...................................... 73
#    - Key Takeaways............................................. 73
#    - Cost Structure............................................. 73
#    - Key Ratios................................................... 74
#
# 10. Key Statistics................................................. 77
#     - Industry Data.............................................. 77
# ```
#
# ### Explanation of Components
#
# - The table of contents details the sections of the report, with subsections listed under relevant headings.
# - Each section contains page numbers indicating where the information can be found within the document.
# - Key topics such as "Performance," "Products and Markets," and "Competitive Forces" reflect the main themes of the report.
# - The structured format implies a comprehensive analysis spanning industry definitions, structures, and factors influencing market dynamics in healthcare and social assistance in the US.
# - No additional information is provided outside of the content listed above, ensuring clarity and accuracy as per the original document's structure.
# ```
# ChatCompletion(id='chatcmpl-AE04SepFyr4EkxGZvR8qY7jAg3R1R', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```markdown\n# About\n\nA quick definition of the industry, its products and services, major companies and other key identifiers help you confirm you’re in the right place.\n```', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1727900228, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_74ba47b4ac', usage=CompletionUsage(completion_tokens=35, prompt_tokens=37304, total_tokens=37339, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}))
# ```markdown
# # About
#
# A quick definition of the industry, its products and services, major companies and other key identifiers help you confirm you’re in the right place.
# ```
# ChatCompletion(id='chatcmpl-AE04UypvwdkkQg0hg0Crb9rnW8XaT', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="# 1. About\n[https://my.ibisworld.com/us/en/industry/62/about](https://my.ibisworld.com/us/en/industry/62/about)\n\n## Codes\n- **NAICS 2017 - USA**: 62\n- **NAICS 2022 - USA**: 62\n\n## Definition\nThe Healthcare and Social Assistance sector is composed of enterprises that provide healthcare and social assistance for individuals in the United States, including hospitals, ambulatory service providers and nursing and residential care facilities. Social assistance also includes counselors and social workers, family and welfare services and natural disaster and emergency relief services.\n\n## Related Terms\n\n### ELECTRONIC HEALTH RECORD (EHR)\nThe systematic collection and maintenance of electronic health information about an individual patient.\n\n### TELEMEDICINE\nAn application of clinical medicine whereby medical information is transferred through interactive audiovisual media for the purpose of consulting and remote medical procedures or examinations.\n\n### HEALTH INSURANCE EXCHANGE\nA set of state-regulated and standardized healthcare plans from which individuals may purchase health insurance eligible for federal subsidies.\n\n### FEE-FOR-SERVICE\nA health plan where individuals choose the doctor, hospital or clinic and the insurance pays for part or all of the cost according to a schedule laid out in the policy.\n\n### MEDICARE AND MEDICAID\nCost-coverage programs. Medicare pays all or part of a stay following hospitalization of at least three days; Medicaid covers a stay of any length for individuals who meet income requirements.\n\n### LONG-TERM CARE\nTreatment for a chronic condition, trauma, or illness that limits a person's ability to carry out basic self-care tasks, called activities of daily living (ADLs).\n\n### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)\nA federal agency designed to prepare for, mitigate against, respond to and help individuals and communities recover from natural and man-made disasters.", refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1727900230, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_74ba47b4ac', usage=CompletionUsage(completion_tokens=380, prompt_tokens=37304, total_tokens=37684, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}))
# # 1. About
# [https://my.ibisworld.com/us/en/industry/62/about](https://my.ibisworld.com/us/en/industry/62/about)
#
# ## Codes
# - **NAICS 2017 - USA**: 62
# - **NAICS 2022 - USA**: 62
#
# ## Definition
# The Healthcare and Social Assistance sector is composed of enterprises that provide healthcare and social assistance for individuals in the United States, including hospitals, ambulatory service providers and nursing and residential care facilities. Social assistance also includes counselors and social workers, family and welfare services and natural disaster and emergency relief services.
#
# ## Related Terms
#
# ### ELECTRONIC HEALTH RECORD (EHR)
# The systematic collection and maintenance of electronic health information about an individual patient.
#
# ### TELEMEDICINE
# An application of clinical medicine whereby medical information is transferred through interactive audiovisual media for the purpose of consulting and remote medical procedures or examinations.
#
# ### HEALTH INSURANCE EXCHANGE
# A set of state-regulated and standardized healthcare plans from which individuals may purchase health insurance eligible for federal subsidies.
#
# ### FEE-FOR-SERVICE
# A health plan where individuals choose the doctor, hospital or clinic and the insurance pays for part or all of the cost according to a schedule laid out in the policy.
#
# ### MEDICARE AND MEDICAID
# Cost-coverage programs. Medicare pays all or part of a stay following hospitalization of at least three days; Medicaid covers a stay of any length for individuals who meet income requirements.
#
# ### LONG-TERM CARE
# Treatment for a chronic condition, trauma, or illness that limits a person's ability to carry out basic self-care tasks, called activities of daily living (ADLs).
#
# ### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)
# A federal agency designed to prepare for, mitigate against, respond to and help individuals and communities recover from natural and man-made disasters.
# ChatCompletion(id='chatcmpl-AE04crzUB7ADgn6mXgn94Y1mFMM29', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```markdown\n# IBISWorld | Healthcare and Social Assistance in the US  \nMar 2024\n\n## GROUP HOME  \nA private residence designed to serve as a nonsecure home for unrelated persons who share a common characteristic.\n\n## MANAGED CARE  \nA system of financing and delivering healthcare to enrollees intended to reduce the cost of providing health benefits and improve the quality of care.\n\n## What’s Included  \n- Ambulatory healthcare services  \n- Hospitals  \n- Nursing homes and residential care facilities  \n- Social assistance  \n\n## Companies  \n- Hca Healthcare, Inc.  \n- Quest Diagnostics Inc.  \n- Feeding America  \n- Brookdale Senior Living Inc.  \n- Fresenius Kabi AG  \n\n## Related Industries  \n\n### Industries in the Same Sector  \n- **Competitors:**  \n  - No data available  \n\n- **Complementors:**  \n  - Wholesale Trade in the US  \n  - Information in the US  \n  - Educational Services in the US  \n\n### International Industries  \n- Global Life & Health Insurance Carriers  \n- Hospitals in Canada  \n- Hospitals in Mexico  \n\n## Additional Resources  \n- Centers for Medicare & Medicaid Services  \n- Centers for Disease Control and Prevention  \n```', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1727900238, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_74ba47b4ac', usage=CompletionUsage(completion_tokens=235, prompt_tokens=37304, total_tokens=37539, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}))
# ```markdown
# # IBISWorld | Healthcare and Social Assistance in the US
# Mar 2024
#
# ## GROUP HOME
# A private residence designed to serve as a nonsecure home for unrelated persons who share a common characteristic.
#
# ## MANAGED CARE
# A system of financing and delivering healthcare to enrollees intended to reduce the cost of providing health benefits and improve the quality of care.
#
# ## What’s Included
# - Ambulatory healthcare services
# - Hospitals
# - Nursing homes and residential care facilities
# - Social assistance
#
# ## Companies
# - Hca Healthcare, Inc.
# - Quest Diagnostics Inc.
# - Feeding America
# - Brookdale Senior Living Inc.
# - Fresenius Kabi AG
#
# ## Related Industries
#
# ### Industries in the Same Sector
# - **Competitors:**
#   - No data available
#
# - **Complementors:**
#   - Wholesale Trade in the US
#   - Information in the US
#   - Educational Services in the US
#
# ### International Industries
# - Global Life & Health Insurance Carriers
# - Hospitals in Canada
# - Hospitals in Mexico
#
# ## Additional Resources
# - Centers for Medicare & Medicaid Services
# - Centers for Disease Control and Prevention
# ```
# ChatCompletion(id='chatcmpl-AE04iqrVz6HpKWJUhF7QpO08dqcV9', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```markdown\n# IBISWorld | Healthcare and Social Assistance in the US\nMar 2024\n\n- Henry J. Kaiser Family Foundation\n- National Institutes of Health\n- American Medical Association\n- Federal Emergency Management Agency\n``` \n\nThis page includes a title indicating it is part of an IBISWorld report on Healthcare and Social Assistance in the US, dated March 2024. It lists four organizations related to healthcare and social services.', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1727900244, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_74ba47b4ac', usage=CompletionUsage(completion_tokens=89, prompt_tokens=37304, total_tokens=37393, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}))
# ```markdown
# # IBISWorld | Healthcare and Social Assistance in the US
# Mar 2024
#
# - Henry J. Kaiser Family Foundation
# - National Institutes of Health
# - American Medical Association
# - Federal Emergency Management Agency
# ```
#
# This page includes a title indicating it is part of an IBISWorld report on Healthcare and Social Assistance in the US, dated March 2024. It lists four organizations related to healthcare and social services.
# ChatCompletion(id='chatcmpl-AE04m9FFbZhmzo1HEzSwHOJrYdnNg', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```markdown\n# At a Glance\n\nEvaluate key industry data and trends and get an overview of important report sections to use in meetings and presentations.\n```', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1727900248, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_74ba47b4ac', usage=CompletionUsage(completion_tokens=31, prompt_tokens=37304, total_tokens=37335, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}))
# ```markdown
# # At a Glance
#
# Evaluate key industry data and trends and get an overview of important report sections to use in meetings and presentations.
# ```
# ChatCompletion(id='chatcmpl-AE04ouJZpFf7fI9fNpsNZFtMROriJ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```markdown\n# 2. At a Glance\n[https://my.ibisworld.com/us/en/industry/62/at-a-glance](https://my.ibisworld.com/us/en/industry/62/at-a-glance)\n\n| **Revenue** | **Employees** | **Businesses** |\n|-------------|---------------|----------------|\n| $3.6tr     | 24m           | 3m             |\n| ‘19-‘24    | ↑ 0.7 %       | ‘19-‘24        | ↑ 1.2 %       |\n| ‘24-‘29    | ↑ 2.7 %       | ‘24-‘29        | ↑ 2.0 %       |\n\n| **Profit**      | **Profit Margin** | **Wages**   |\n|-----------------|-------------------|-------------|\n| $355.5bn        | 10.0%             | $1.4tr      |\n| ‘19-‘24         | ↑ 0.1 %           | ‘19-‘24     | ↑ 1.2 %     |\n| ‘24-‘29         |                   | ‘24-‘29     | ↑ 2.4 %     |\n\n## Key Takeaways\n\n### Performance\n- COVID-19 created unprecedented challenges for healthcare and social assistance providers. Staffing shortages and rising costs continue to impact providers and businesses.\n- Healthcare and social assistance providers are vital to older adults. As these people continue to age, their expanding and complex medical needs will require various health and social services.\n\n### External Environment\n- Healthcare and social assistance facilities operate within one of the most regulated environments. A dizzying amount of federal, state and local laws apply in this sector, enforced by multiple agencies and regulators.\n- Healthcare providers received over $200.0 billion to ease pandemic-related financial and operational pressures. Since pandemic relief fizzled out, healthcare facilities have faced unprecedented financial strain.\n```', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1727900250, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_74ba47b4ac', usage=CompletionUsage(completion_tokens=398, prompt_tokens=37304, total_tokens=37702, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}))
# ```markdown
# # 2. At a Glance
# [https://my.ibisworld.com/us/en/industry/62/at-a-glance](https://my.ibisworld.com/us/en/industry/62/at-a-glance)
#
# | **Revenue** | **Employees** | **Businesses** |
# |-------------|---------------|----------------|
# | $3.6tr     | 24m           | 3m             |
# | ‘19-‘24    | ↑ 0.7 %       | ‘19-‘24        | ↑ 1.2 %       |
# | ‘24-‘29    | ↑ 2.7 %       | ‘24-‘29        | ↑ 2.0 %       |
#
# | **Profit**      | **Profit Margin** | **Wages**   |
# |-----------------|-------------------|-------------|
# | $355.5bn        | 10.0%             | $1.4tr      |
# | ‘19-‘24         | ↑ 0.1 %           | ‘19-‘24     | ↑ 1.2 %     |
# | ‘24-‘29         |                   | ‘24-‘29     | ↑ 2.4 %     |
#
# ## Key Takeaways
#
# ### Performance
# - COVID-19 created unprecedented challenges for healthcare and social assistance providers. Staffing shortages and rising costs continue to impact providers and businesses.
# - Healthcare and social assistance providers are vital to older adults. As these people continue to age, their expanding and complex medical needs will require various health and social services.
#
# ### External Environment
# - Healthcare and social assistance facilities operate within one of the most regulated environments. A dizzying amount of federal, state and local laws apply in this sector, enforced by multiple agencies and regulators.
# - Healthcare providers received over $200.0 billion to ease pandemic-related financial and operational pressures. Since pandemic relief fizzled out, healthcare facilities have faced unprecedented financial strain.
# ```
# ChatCompletion(id='chatcmpl-AE04v3LEj7HQlR9cnpUxXjsDtQeQU', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```markdown\n# IBISWorld | Healthcare and Social Assistance in the US\n**Mar 2024**\n\n## Products and Services\n\n### Products & Services Segmentation\nIndustry revenue in 2024 broken down by key product and service lines.\n\n#### Revenue Breakdown\n- **Hospitals**: $1.5 trillion (41.7%)\n- **Ambulatory healthcare services**: $1.4 trillion (40.7%)\n- **Nursing homes and residential facilities**: $330.6 billion (9.3%)\n- **Social assistance**: $295 billion (8.3%)\n\nThe data indicates that in 2024, the largest segment of industry revenue comes from hospitals, accounting for 41.7% of the total revenue, followed closely by ambulatory healthcare services at 40.7%. Nursing homes and residential facilities represent 9.3% of revenue, while social assistance makes up 8.3%.\n\n### Pie Chart Explanation\nThe pie chart visually represents the segmentation of the healthcare and social assistance industry by product and service lines. The sections of the chart correspond to the revenue shares of each category, clearly indicating that hospitals and ambulatory healthcare services dominate the market.\n\n**Source**: IBISWorld\n```', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1727900257, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_74ba47b4ac', usage=CompletionUsage(completion_tokens=250, prompt_tokens=37304, total_tokens=37554, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}))
# ```markdown
# # IBISWorld | Healthcare and Social Assistance in the US
# **Mar 2024**
#
# ## Products and Services
#
# ### Products & Services Segmentation
# Industry revenue in 2024 broken down by key product and service lines.
#
# #### Revenue Breakdown
# - **Hospitals**: $1.5 trillion (41.7%)
# - **Ambulatory healthcare services**: $1.4 trillion (40.7%)
# - **Nursing homes and residential facilities**: $330.6 billion (9.3%)
# - **Social assistance**: $295 billion (8.3%)
#
# The data indicates that in 2024, the largest segment of industry revenue comes from hospitals, accounting for 41.7% of the total revenue, followed closely by ambulatory healthcare services at 40.7%. Nursing homes and residential facilities represent 9.3% of revenue, while social assistance makes up 8.3%.
#
# ### Pie Chart Explanation
# The pie chart visually represents the segmentation of the healthcare and social assistance industry by product and service lines. The sections of the chart correspond to the revenue shares of each category, clearly indicating that hospitals and ambulatory healthcare services dominate the market.
#
# **Source**: IBISWorld
# ```
# ChatCompletion(id='chatcmpl-AE051PgahDsM4bGXojrNxA9CK88nL', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='```markdown\n# Major Players\n\n## Major Players\n\n![Pie Chart](chart_placeholder.png)\n\n- HCA Healthcare, Inc. ($52.6bn) - 1.6%\n- Quest Diagnostics Inc. ($10.3bn) - 0.3%\n- Feeding America ($3.4bn) - 0.1%\n- Brookdale Senior Living Inc. ($3.3bn) - 0.1%\n- Other Companies ($3.5tr) - 98.0%\n\n**Source:** IBISWorld\n```\n\n### Explanation of Components\n\n1. **Major Players Section**:\n   - The section provides information about key players in the healthcare and social assistance market.\n\n2. **List of Major Players**:\n   - HCA Healthcare, Inc. represents 1.6% of the market, with a revenue of $52.6 billion.\n   - Quest Diagnostics Inc. has a market share of 0.3%, with revenues of $10.3 billion.\n   - Feeding America accounts for 0.1% of the market, with $3.4 billion in revenue.\n   - Brookdale Senior Living Inc. also holds 0.1% of the market, generating $3.3 billion.\n   - Other Companies dominate the market with 98.0%, amounting to $3.5 trillion in revenue.\n\n3. **Pie Chart**:\n   - The pie chart visually represents the market share of these players, highlighting that a significant portion of the market is held by "Other Companies."\n\nThis breakdown provides a clear understanding of the market composition and revenue distributions among the major players indicated in the report.', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1727900263, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier=None, system_fingerprint='fp_74ba47b4ac', usage=CompletionUsage(completion_tokens=337, prompt_tokens=37304, total_tokens=37641, prompt_tokens_details={'cached_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0}))
# ```markdown
# # Major Players
#
# ## Major Players
#
# ![Pie Chart](chart_placeholder.png)
#
# - HCA Healthcare, Inc. ($52.6bn) - 1.6%
# - Quest Diagnostics Inc. ($10.3bn) - 0.3%
# - Feeding America ($3.4bn) - 0.1%
# - Brookdale Senior Living Inc. ($3.3bn) - 0.1%
# - Other Companies ($3.5tr) - 98.0%
#
# **Source:** IBISWorld
# ```
#
# ### Explanation of Components
#
# 1. **Major Players Section**:
#    - The section provides information about key players in the healthcare and social assistance market.
#
# 2. **List of Major Players**:
#    - HCA Healthcare, Inc. represents 1.6% of the market, with a revenue of $52.6 billion.
#    - Quest Diagnostics Inc. has a market share of 0.3%, with revenues of $10.3 billion.
#    - Feeding America accounts for 0.1% of the market, with $3.4 billion in revenue.
#    - Brookdale Senior Living Inc. also holds 0.1% of the market, generating $3.3 billion.
#    - Other Companies dominate the market with 98.0%, amounting to $3.5 trillion in revenue.
#
# 3. **Pie Chart**:
#    - The pie chart visually represents the market share of these players, highlighting that a significant portion of the market is held by "Other Companies."
#
# This breakdown provides a clear understanding of the market composition and revenue distributions among the major players indicated in the report.
# ```markdown
# # INDUSTRY REPORT
# ## Healthcare and Social Assistance in the US
#
# ### Mar 2024
# ```
# ```markdown
# # About IBISWorld
#
# IBISWorld specializes in industry research with coverage on thousands of global industries. Our comprehensive data and in-depth analysis help businesses of all types gain quick and actionable insights on industries around the world. Busy professionals can spend less time researching and preparing for meetings, and more time focused on making strategic business decisions.
# ```
# ```markdown
# # IBISWorld | Healthcare and Social Assistance in the US
# **Mar 2024**
#
# ## Table Of Contents
#
# 1. About............................................................ 5
#    - Codes....................................................... 5
#    - Definition................................................. 5
#    - Related Terms........................................... 5
#    - What’s Included.......................................... 6
#    - Companies................................................. 6
#    - Related Industries....................................... 6
#    - Additional Resources.................................... 6
#
# 2. At a Glance..................................................... 9
#    - Key Takeaways............................................. 9
#    - Products and Services.................................. 10
#    - Major Players................................................ 11
#    - Key External Drivers..................................... 12
#    - Industry Structure......................................... 12
#    - SWOT................................................................ 13
#    - Executive Summary...................................... 13
#
# 3. Performance.................................................. 15
#    - Highlights.................................................. 15
#    - Key Takeaways............................................. 15
#    - Performance Snapshot................................. 16
#    - Outlook...................................................... 25
#    - Life Cycle.................................................. 28
#
# 4. Products and Markets....................................... 30
#    - Key Takeaways............................................. 30
#    - Products and Services.................................. 30
#    - Major Markets................................................ 35
#
# 5. Geographic Breakdown..................................... 39
#    - Key Takeaways............................................. 39
#    - Business Locations....................................... 40
#
# 6. Competitive Forces.......................................... 46
#    - Key Takeaways............................................. 46
#    - Concentration.............................................. 46
#    - Barriers to Entry......................................... 47
#    - Substitutes................................................ 48
#    - Buyer & Supplier Power................................ 49
#
# 7. Companies.................................................... 52
#    - Key Takeaways............................................. 52
#    - Market Share................................................ 53
#    - Companies..................................................... 54
#
# 8. External Environment..................................... 67
#    - Key Takeaways............................................. 67
#    - External Drivers.......................................... 67
#    - Regulation & Policy..................................... 69
#    - Assistance................................................... 71
#
# 9. Financial Benchmarks...................................... 73
#    - Key Takeaways............................................. 73
#    - Cost Structure............................................. 73
#    - Key Ratios................................................... 74
#
# 10. Key Statistics................................................. 77
#     - Industry Data.............................................. 77
# ```
#
# ### Explanation of Components
#
# - The table of contents details the sections of the report, with subsections listed under relevant headings.
# - Each section contains page numbers indicating where the information can be found within the document.
# - Key topics such as "Performance," "Products and Markets," and "Competitive Forces" reflect the main themes of the report.
# - The structured format implies a comprehensive analysis spanning industry definitions, structures, and factors influencing market dynamics in healthcare and social assistance in the US.
# - No additional information is provided outside of the content listed above, ensuring clarity and accuracy as per the original document's structure.
# ```
# ```markdown
# # About
#
# A quick definition of the industry, its products and services, major companies and other key identifiers help you confirm you’re in the right place.
# ```
# # 1. About
# [https://my.ibisworld.com/us/en/industry/62/about](https://my.ibisworld.com/us/en/industry/62/about)
#
# ## Codes
# - **NAICS 2017 - USA**: 62
# - **NAICS 2022 - USA**: 62
#
# ## Definition
# The Healthcare and Social Assistance sector is composed of enterprises that provide healthcare and social assistance for individuals in the United States, including hospitals, ambulatory service providers and nursing and residential care facilities. Social assistance also includes counselors and social workers, family and welfare services and natural disaster and emergency relief services.
#
# ## Related Terms
#
# ### ELECTRONIC HEALTH RECORD (EHR)
# The systematic collection and maintenance of electronic health information about an individual patient.
#
# ### TELEMEDICINE
# An application of clinical medicine whereby medical information is transferred through interactive audiovisual media for the purpose of consulting and remote medical procedures or examinations.
#
# ### HEALTH INSURANCE EXCHANGE
# A set of state-regulated and standardized healthcare plans from which individuals may purchase health insurance eligible for federal subsidies.
#
# ### FEE-FOR-SERVICE
# A health plan where individuals choose the doctor, hospital or clinic and the insurance pays for part or all of the cost according to a schedule laid out in the policy.
#
# ### MEDICARE AND MEDICAID
# Cost-coverage programs. Medicare pays all or part of a stay following hospitalization of at least three days; Medicaid covers a stay of any length for individuals who meet income requirements.
#
# ### LONG-TERM CARE
# Treatment for a chronic condition, trauma, or illness that limits a person's ability to carry out basic self-care tasks, called activities of daily living (ADLs).
#
# ### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)
# A federal agency designed to prepare for, mitigate against, respond to and help individuals and communities recover from natural and man-made disasters.
# ```markdown
# # IBISWorld | Healthcare and Social Assistance in the US
# Mar 2024
#
# ## GROUP HOME
# A private residence designed to serve as a nonsecure home for unrelated persons who share a common characteristic.
#
# ## MANAGED CARE
# A system of financing and delivering healthcare to enrollees intended to reduce the cost of providing health benefits and improve the quality of care.
#
# ## What’s Included
# - Ambulatory healthcare services
# - Hospitals
# - Nursing homes and residential care facilities
# - Social assistance
#
# ## Companies
# - Hca Healthcare, Inc.
# - Quest Diagnostics Inc.
# - Feeding America
# - Brookdale Senior Living Inc.
# - Fresenius Kabi AG
#
# ## Related Industries
#
# ### Industries in the Same Sector
# - **Competitors:**
#   - No data available
#
# - **Complementors:**
#   - Wholesale Trade in the US
#   - Information in the US
#   - Educational Services in the US
#
# ### International Industries
# - Global Life & Health Insurance Carriers
# - Hospitals in Canada
# - Hospitals in Mexico
#
# ## Additional Resources
# - Centers for Medicare & Medicaid Services
# - Centers for Disease Control and Prevention
# ```
# ```markdown
# # IBISWorld | Healthcare and Social Assistance in the US
# Mar 2024
#
# - Henry J. Kaiser Family Foundation
# - National Institutes of Health
# - American Medical Association
# - Federal Emergency Management Agency
# ```
#
# This page includes a title indicating it is part of an IBISWorld report on Healthcare and Social Assistance in the US, dated March 2024. It lists four organizations related to healthcare and social services.
# ```markdown
# # At a Glance
#
# Evaluate key industry data and trends and get an overview of important report sections to use in meetings and presentations.
# ```
# ```markdown
# # 2. At a Glance
# [https://my.ibisworld.com/us/en/industry/62/at-a-glance](https://my.ibisworld.com/us/en/industry/62/at-a-glance)
#
# | **Revenue** | **Employees** | **Businesses** |
# |-------------|---------------|----------------|
# | $3.6tr     | 24m           | 3m             |
# | ‘19-‘24    | ↑ 0.7 %       | ‘19-‘24        | ↑ 1.2 %       |
# | ‘24-‘29    | ↑ 2.7 %       | ‘24-‘29        | ↑ 2.0 %       |
#
# | **Profit**      | **Profit Margin** | **Wages**   |
# |-----------------|-------------------|-------------|
# | $355.5bn        | 10.0%             | $1.4tr      |
# | ‘19-‘24         | ↑ 0.1 %           | ‘19-‘24     | ↑ 1.2 %     |
# | ‘24-‘29         |                   | ‘24-‘29     | ↑ 2.4 %     |
#
# ## Key Takeaways
#
# ### Performance
# - COVID-19 created unprecedented challenges for healthcare and social assistance providers. Staffing shortages and rising costs continue to impact providers and businesses.
# - Healthcare and social assistance providers are vital to older adults. As these people continue to age, their expanding and complex medical needs will require various health and social services.
#
# ### External Environment
# - Healthcare and social assistance facilities operate within one of the most regulated environments. A dizzying amount of federal, state and local laws apply in this sector, enforced by multiple agencies and regulators.
# - Healthcare providers received over $200.0 billion to ease pandemic-related financial and operational pressures. Since pandemic relief fizzled out, healthcare facilities have faced unprecedented financial strain.
# ```
# ```markdown
# # IBISWorld | Healthcare and Social Assistance in the US
# **Mar 2024**
#
# ## Products and Services
#
# ### Products & Services Segmentation
# Industry revenue in 2024 broken down by key product and service lines.
#
# #### Revenue Breakdown
# - **Hospitals**: $1.5 trillion (41.7%)
# - **Ambulatory healthcare services**: $1.4 trillion (40.7%)
# - **Nursing homes and residential facilities**: $330.6 billion (9.3%)
# - **Social assistance**: $295 billion (8.3%)
#
# The data indicates that in 2024, the largest segment of industry revenue comes from hospitals, accounting for 41.7% of the total revenue, followed closely by ambulatory healthcare services at 40.7%. Nursing homes and residential facilities represent 9.3% of revenue, while social assistance makes up 8.3%.
#
# ### Pie Chart Explanation
# The pie chart visually represents the segmentation of the healthcare and social assistance industry by product and service lines. The sections of the chart correspond to the revenue shares of each category, clearly indicating that hospitals and ambulatory healthcare services dominate the market.
#
# **Source**: IBISWorld
# ```
# ```markdown
# # Major Players
#
# ## Major Players
#
# ![Pie Chart](chart_placeholder.png)
#
# - HCA Healthcare, Inc. ($52.6bn) - 1.6%
# - Quest Diagnostics Inc. ($10.3bn) - 0.3%
# - Feeding America ($3.4bn) - 0.1%
# - Brookdale Senior Living Inc. ($3.3bn) - 0.1%
# - Other Companies ($3.5tr) - 98.0%
#
# **Source:** IBISWorld
# ```
#
# ### Explanation of Components
#
# 1. **Major Players Section**:
#    - The section provides information about key players in the healthcare and social assistance market.
#
# 2. **List of Major Players**:
#    - HCA Healthcare, Inc. represents 1.6% of the market, with a revenue of $52.6 billion.
#    - Quest Diagnostics Inc. has a market share of 0.3%, with revenues of $10.3 billion.
#    - Feeding America accounts for 0.1% of the market, with $3.4 billion in revenue.
#    - Brookdale Senior Living Inc. also holds 0.1% of the market, generating $3.3 billion.
#    - Other Companies dominate the market with 98.0%, amounting to $3.5 trillion in revenue.
#
# 3. **Pie Chart**:
#    - The pie chart visually represents the market share of these players, highlighting that a significant portion of the market is held by "Other Companies."
#
# This breakdown provides a clear understanding of the market composition and revenue distributions among the major players indicated in the report.

# %%
from pdf2image import convert_from_path
import os
import base64
import requests
import logging
from openai import OpenAI
import anthropic
import pickle
from langchain_core.documents import Document

os.environ["ANTHROPIC_API_KEY"] = 
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')


model = "claude-3-5-sonnet-20240620"

def request_openai_with_image(base64_image):
    responded = False
    num_tries = 0
    while not responded and num_tries < 5:
        num_tries += 1

        client = anthropic.Anthropic()
        response = client.messages.create(
            model=model,
            max_tokens=5000,
            system = "You are a profession converter that converts all the details in given image of page of a market research report to markdown format while preserving all the structure.",
            messages=[
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": IMAGE_PROMPT},
                        {
                            "type": "image",
                            "source": {
                                "type": "base64",
                                "media_type": "image/png",
                                "data": base64_image,
                            },
                        },
                        {"type": "text", "text": "Please describe the provided page in markdown format. Strictly follow the criteria mentioned above to describe each component of the page."},
                    ],
                }
            ],
        )

        print(response)
        response_txt = response.content[0].text
        print(response_txt)

    
        try:
            response_txt = response.content[0].text
            responded = True
            return response_txt
        except:
            continue
    return ""


data_dir = "./data/report2"
pdf_path = os.path.join(data_dir, "health.pdf")
img_dir = os.path.join(data_dir, "imgs")
if not os.path.exists(img_dir):
    os.makedirs(img_dir)

output_text = os.path.join(data_dir, f"./_{model}_pages.txt")
output_pickle = os.path.join(data_dir, f"{model}_pages.pkl")


images = convert_from_path(pdf_path)
pages = []
# Iterate over the images
for i, image in enumerate(images):
    # Define the path to save the image
    image_path = os.path.join(img_dir, f'page_{i+1}.png')

    # Save the image
    image.save(image_path, 'PNG')
    logging.info(f"Saved image {i+1} to {image_path}")
    base64_image = encode_image(image_path)
    response = request_openai_with_image(base64_image)

    # convert the response to langchain document
    doc = Document(page_content=response, metadata={"page": i+1})
    pages.append(doc)

# save the pages as txt file
txt_path = output_text
with open(txt_path, "w") as f:
    for page in pages:
        print(page.page_content)
        #write page number
        f.write(f"Page {page.metadata['page']}\n")
        f.write(page.page_content)
        f.write("\n")

pickle.dump(pages, open(output_pickle, "wb"))
# Out:
# Message(id='msg_012Ly8rHGXAzZBckQeHiDvvV', content=[TextBlock(text='# IBISWorld\n\n## INDUSTRY REPORT\n\n# Healthcare and Social Assistance in the US\n\n## Mar 2024\n\nThe image shows the cover page of an industry report by IBISWorld. The report focuses on Healthcare and Social Assistance in the US, and is dated March 2024. The title and information are presented on a dark blue background with red circular design elements in the corners and bottom of the page. The IBISWorld logo, featuring white text on a red background, is prominently displayed at the top left corner of the page.', type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=2083, output_tokens=118))
# # IBISWorld
#
# ## INDUSTRY REPORT
#
# # Healthcare and Social Assistance in the US
#
# ## Mar 2024
#
# The image shows the cover page of an industry report by IBISWorld. The report focuses on Healthcare and Social Assistance in the US, and is dated March 2024. The title and information are presented on a dark blue background with red circular design elements in the corners and bottom of the page. The IBISWorld logo, featuring white text on a red background, is prominently displayed at the top left corner of the page.
# Message(id='msg_019pfLqVSViobCujPhNgh2UD', content=[TextBlock(text='# IBISWorld | Healthcare and Social Assistance in the US\n\n*Mar 2024*\n\n## About IBISWorld\n\nIBISWorld specializes in industry research with coverage on thousands of global industries. Our comprehensive data and in-depth analysis help businesses of all types gain quick and actionable insights on industries around the world. Busy professionals can spend less time researching and preparing for meetings, and more time focused on making strategic business decisions.', type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=2083, output_tokens=94))
# # IBISWorld | Healthcare and Social Assistance in the US
#
# *Mar 2024*
#
# ## About IBISWorld
#
# IBISWorld specializes in industry research with coverage on thousands of global industries. Our comprehensive data and in-depth analysis help businesses of all types gain quick and actionable insights on industries around the world. Busy professionals can spend less time researching and preparing for meetings, and more time focused on making strategic business decisions.
# Message(id='msg_01SpoT3f3MfQ1cqiYjFUt5rL', content=[TextBlock(text="# IBISWorld | Healthcare and Social Assistance in the US\n\nMar 2024\n\n## Table Of Contents\n\nStandard\n\n1. About............................................................ 5\n   Codes............................................................5\n   Definition....................................................... 5\n   Related Terms.............................................. 5\n   What's Included............................................ 6\n   Companies....................................................6\n   Related Industries......................................... 6\n   Additional Resources.................................... 6\n\n2. At a Glance...................................................9\n   Key Takeaways.............................................9\n   Products and Services................................ 10\n   Major Players.............................................. 11\n   Key External Drivers................................... 12\n   Industry Structure........................................ 12\n   SWOT......................................................... 13\n   Executive Summary.................................... 13\n\n3. Performance............................................... 15\n   Highlights.................................................... 15\n   Key Takeaways........................................... 15\n   Performance Snapshot............................... 16\n   Outlook........................................................25\n   Life Cycle.................................................... 28\n\n4. Products and Markets.................................30\n   Key Takeaways...........................................30\n   Products and Services................................ 30\n   Major Markets............................................. 35\n   International Trade......................................37\n\n5. Geographic Breakdown.............................. 39\n   Key Takeaways...........................................39\n   Business Locations..................................... 40\n\n6. Competitive Forces.....................................46\n   Key Takeaways...........................................46\n   Concentration..............................................46\n   Barriers to Entry.......................................... 47\n   Substitutes.................................................. 48\n   Buyer & Supplier Power..............................49\n\n7. Companies................................................. 52\n   Key Takeaways...........................................52\n   Market Share.............................................. 53\n   Companies..................................................54\n\n8. External Environment................................. 67\n   Key Takeaways...........................................67\n   External Drivers.......................................... 67\n   Regulation & Policy..................................... 69\n   Assistance...................................................71\n\n9. Financial Benchmarks................................ 73\n   Key Takeaways...........................................73\n   Cost Structure............................................. 73\n   Key Ratios...................................................74\n\n10. Key Statistics............................................ 77\n    Industry Data...............................................77\n\nThe image displays a detailed table of contents for a report on Healthcare and Social Assistance in the US. The table is divided into 10 main sections, each with various subsections. The sections cover a wide range of topics including an overview, industry performance, products and markets, geographic breakdown, competitive forces, companies, external environment, financial benchmarks, and key statistics. Each section and subsection is accompanied by its corresponding page numbe ...
# # IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
# ## Table Of Contents
#
# Standard
#
# 1. About............................................................ 5
#    Codes............................................................5
#    Definition....................................................... 5
#    Related Terms.............................................. 5
#    What's Included............................................ 6
#    Companies....................................................6
#    Related Industries......................................... 6
#    Additional Resources.................................... 6
#
# 2. At a Glance...................................................9
#    Key Takeaways.............................................9
#    Products and Services................................ 10
#    Major Players.............................................. 11
#    Key External Drivers................................... 12
#    Industry Structure........................................ 12
#    SWOT......................................................... 13
#    Executive Summary.................................... 13
#
# 3. Performance............................................... 15
#    Highlights.................................................... 15
#    Key Takeaways........................................... 15
#    Performance Snapshot............................... 16
#    Outlook........................................................25
#    Life Cycle.................................................... 28
#
# 4. Products and Markets.................................30
#    Key Takeaways...........................................30
#    Products and Services................................ 30
#    Major Markets............................................. 35
#    International Trade......................................37
#
# 5. Geographic Breakdown.............................. 39
#    Key Takeaways...........................................39
#    Business Locations..................................... 40
#
# 6. Competitive Forces.....................................46
#    Key Takeaways...........................................46
#    Concentration..............................................46
#    Barriers to Entry.......................................... 47
#    Substitutes.................................................. 48
#    Buyer & Supplier Power..............................49
#
# 7. Companies................................................. 52
#    Key Takeaways...........................................52
#    Market Share.............................................. 53
#    Companies..................................................54
#
# 8. External Environment................................. 67
#    Key Takeaways...........................................67
#    External Drivers.......................................... 67
#    Regulation & Policy..................................... 69
#    Assistance...................................................71
#
# 9. Financial Benchmarks................................ 73
#    Key Takeaways...........................................73
#    Cost Structure............................................. 73
#    Key Ratios...................................................74
#
# 10. Key Statistics............................................ 77
#     Industry Data...............................................77
#
# The image displays a detailed table of contents for a report on Healthcare and Social Assistance in the US. The table is divided into 10 main sections, each with various subsections. The sections cover a wide range of topics including an overview, industry performance, products and markets, geographic breakdown, competitive forces, companies, external environment, financial benchmarks, and key statistics. Each section and subsection is accompanied by its corresponding page number, indicating a comprehensive and well-structured report. The page number at the bottom right corner suggests this is page 3 of the report.
# Message(id='msg_01SPGnMPiZkccZbKzec3NX4g', content=[TextBlock(text='# About\n\nA quick definition of the industry, its products and services, major companies and other key identifiers help you confirm you\'re in the right place.\n\nThe image shows a page with a bright red background. In the bottom right corner of the page, there is a large, stylized number "1" in a lighter shade of red, creating a subtle contrast with the background. The text "About" is prominently displayed in white in the bottom left quadrant of the page, followed by a brief description in smaller white text. The page number "4" is visible in the bottom right corner.\n\nThis page appears to be an introductory or section divider page in a report or presentation, designed to provide a brief overview of what follows. The stark color scheme and minimalist design draw attention to the text and create a bold visual impact.', type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=2083, output_tokens=178))
# # About
#
# A quick definition of the industry, its products and services, major companies and other key identifiers help you confirm you're in the right place.
#
# The image shows a page with a bright red background. In the bottom right corner of the page, there is a large, stylized number "1" in a lighter shade of red, creating a subtle contrast with the background. The text "About" is prominently displayed in white in the bottom left quadrant of the page, followed by a brief description in smaller white text. The page number "4" is visible in the bottom right corner.
#
# This page appears to be an introductory or section divider page in a report or presentation, designed to provide a brief overview of what follows. The stark color scheme and minimalist design draw attention to the text and create a bold visual impact.
# Message(id='msg_01A2Rhcwv9CZCwCNYHCRpx6d', content=[TextBlock(text="# 1. About\n\nhttps://my.ibisworld.com/us/en/industry/62/about\n\n## Codes\n\n| NAICS 2017 - USA | 62 |\n|------------------|------|\n| NAICS 2022 - USA | 62 |\n\nThe table shows the NAICS (North American Industry Classification System) codes for the Healthcare and Social Assistance sector in the USA. Both the 2017 and 2022 versions of NAICS assign the code 62 to this sector, indicating no change in classification between these years.\n\n## Definition\n\nThe Healthcare and Social Assistance sector is composed of enterprises that provide healthcare and social assistance for individuals in the United States, including hospitals, ambulatory service providers and nursing and residential care facilities. Social assistance also includes counselors and social workers, family and welfare services and natural disaster and emergency relief services.\n\n## Related Terms\n\n### ELECTRONIC HEALTH RECORD (EHR)\n\nThe systematic collection and maintenance of electronic health information about an individual patient.\n\n### TELEMEDICINE\n\nAn application of clinical medicine whereby medical information is transferred through interactive audiovisual media for the purpose of consulting and remote medical procedures or examinations.\n\n### HEALTH INSURANCE EXCHANGE\n\nA set of state-regulated and standardized healthcare plans from which individuals may purchase health insurance eligible for federal subsidies.\n\n### FEE-FOR-SERVICE\n\nA health plan where individuals choose the doctor, hospital or clinic and the insurance pays for part or all of the cost according to a schedule laid out in the policy.\n\n### MEDICARE AND MEDICAID\n\nCost-coverage programs. Medicare pays all or part of a stay following hospitalization of at least three days; Medicaid covers a stay of any length for individuals who meet income requirements.\n\n### LONG-TERM CARE\n\nTreatment for a chronic condition, trauma, or illness that limits a person's ability to carry out basic self-care tasks, called activities of daily living (ADLs).\n\n### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)\n\nA federal agency designed to prepare for, mitigate against, respond to and help individuals and communities recover from natural and man-made disasters.", type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=2083, output_tokens=473))
# # 1. About
#
# https://my.ibisworld.com/us/en/industry/62/about
#
# ## Codes
#
# | NAICS 2017 - USA | 62 |
# |------------------|------|
# | NAICS 2022 - USA | 62 |
#
# The table shows the NAICS (North American Industry Classification System) codes for the Healthcare and Social Assistance sector in the USA. Both the 2017 and 2022 versions of NAICS assign the code 62 to this sector, indicating no change in classification between these years.
#
# ## Definition
#
# The Healthcare and Social Assistance sector is composed of enterprises that provide healthcare and social assistance for individuals in the United States, including hospitals, ambulatory service providers and nursing and residential care facilities. Social assistance also includes counselors and social workers, family and welfare services and natural disaster and emergency relief services.
#
# ## Related Terms
#
# ### ELECTRONIC HEALTH RECORD (EHR)
#
# The systematic collection and maintenance of electronic health information about an individual patient.
#
# ### TELEMEDICINE
#
# An application of clinical medicine whereby medical information is transferred through interactive audiovisual media for the purpose of consulting and remote medical procedures or examinations.
#
# ### HEALTH INSURANCE EXCHANGE
#
# A set of state-regulated and standardized healthcare plans from which individuals may purchase health insurance eligible for federal subsidies.
#
# ### FEE-FOR-SERVICE
#
# A health plan where individuals choose the doctor, hospital or clinic and the insurance pays for part or all of the cost according to a schedule laid out in the policy.
#
# ### MEDICARE AND MEDICAID
#
# Cost-coverage programs. Medicare pays all or part of a stay following hospitalization of at least three days; Medicaid covers a stay of any length for individuals who meet income requirements.
#
# ### LONG-TERM CARE
#
# Treatment for a chronic condition, trauma, or illness that limits a person's ability to carry out basic self-care tasks, called activities of daily living (ADLs).
#
# ### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)
#
# A federal agency designed to prepare for, mitigate against, respond to and help individuals and communities recover from natural and man-made disasters.
# Message(id='msg_01DdBbSPL7c33xuXpg1zk34b', content=[TextBlock(text="# IBISWorld | Healthcare and Social Assistance in the US\n\nMar 2024\n\n## GROUP HOME\n\nA private residence designed to serve as a nonsecure home for unrelated persons who share a common characteristic.\n\n## MANAGED CARE\n\nA system of financing and delivering healthcare to enrollees intended to reduce the cost of providing health benefits and improve the quality of care.\n\n## What's Included\n\n- Ambulatory healthcare services\n- Hospitals\n- Nursing homes and residential care facilities\n- Social assistance\n\n## Companies\n\n- Hca Healthcare, Inc.\n- Quest Diagnostics Inc.\n- Feeding America\n- Brookdale Senior Living Inc.\n- Fresenius Kabi AG\n\n## Related Industries\n\n### Industries in the Same Sector\n\n- Competitors:\n  - No data available\n\n- Complementors:\n  - Wholesale Trade in the US\n  - Information in the US\n  - Educational Services in the US\n\n### International Industries\n\n- Global Life & Health Insurance Carriers\n- Hospitals in Canada\n- Hospitals in Mexico\n\n## Additional Resources\n\n- Centers for Medicare & Medicaid Services\n- Centers for Disease Control and Prevention\n\n6", type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=2083, output_tokens=257))
# # IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
# ## GROUP HOME
#
# A private residence designed to serve as a nonsecure home for unrelated persons who share a common characteristic.
#
# ## MANAGED CARE
#
# A system of financing and delivering healthcare to enrollees intended to reduce the cost of providing health benefits and improve the quality of care.
#
# ## What's Included
#
# - Ambulatory healthcare services
# - Hospitals
# - Nursing homes and residential care facilities
# - Social assistance
#
# ## Companies
#
# - Hca Healthcare, Inc.
# - Quest Diagnostics Inc.
# - Feeding America
# - Brookdale Senior Living Inc.
# - Fresenius Kabi AG
#
# ## Related Industries
#
# ### Industries in the Same Sector
#
# - Competitors:
#   - No data available
#
# - Complementors:
#   - Wholesale Trade in the US
#   - Information in the US
#   - Educational Services in the US
#
# ### International Industries
#
# - Global Life & Health Insurance Carriers
# - Hospitals in Canada
# - Hospitals in Mexico
#
# ## Additional Resources
#
# - Centers for Medicare & Medicaid Services
# - Centers for Disease Control and Prevention
#
# 6
# Message(id='msg_01WLnJLnogMoU7xKZMWvH2ma', content=[TextBlock(text='# IBISWorld | Healthcare and Social Assistance in the US Mar 2024\n\n- Henry J. Kaiser Family Foundation\n- National Institutes of Health\n- American Medical Association\n- Federal Emergency Management Agency\n\nThe image displays a page from a market research report titled "Healthcare and Social Assistance in the US" by IBISWorld, dated March 2024. The page contains a list of four organizations related to healthcare and social assistance in the United States. These organizations are likely key players or important sources of information in the healthcare and social assistance sector. The list is presented in a simple bullet point format, indicating equal importance or no particular hierarchical order among these entities.\n\nAt the bottom right corner of the page, there is a page number "7", suggesting this is the seventh page of the report.', type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=2083, output_tokens=169))
# # IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# - Henry J. Kaiser Family Foundation
# - National Institutes of Health
# - American Medical Association
# - Federal Emergency Management Agency
#
# The image displays a page from a market research report titled "Healthcare and Social Assistance in the US" by IBISWorld, dated March 2024. The page contains a list of four organizations related to healthcare and social assistance in the United States. These organizations are likely key players or important sources of information in the healthcare and social assistance sector. The list is presented in a simple bullet point format, indicating equal importance or no particular hierarchical order among these entities.
#
# At the bottom right corner of the page, there is a page number "7", suggesting this is the seventh page of the report.
# Message(id='msg_01VHE1ufZr4ZVXkRUYuZw7jW', content=[TextBlock(text='# At a Glance\n\nEvaluate key industry data and trends\nand get an overview of important\nreport sections to use in meetings\nand presentations.\n\nThe image shows a page with a bright red background. In the lower right corner of the page, there is a large, semi-transparent numeral "2" that spans most of the height of the page. The text "At a Glance" appears in large white letters in the top left portion of the page, followed by a brief description in smaller white text. At the bottom right corner, there is a small white "8", likely indicating this is page 8 of a document.', type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=2083, output_tokens=138))
# # At a Glance
#
# Evaluate key industry data and trends
# and get an overview of important
# report sections to use in meetings
# and presentations.
#
# The image shows a page with a bright red background. In the lower right corner of the page, there is a large, semi-transparent numeral "2" that spans most of the height of the page. The text "At a Glance" appears in large white letters in the top left portion of the page, followed by a brief description in smaller white text. At the bottom right corner, there is a small white "8", likely indicating this is page 8 of a document.
# Message(id='msg_01XuW5LKKH26PS6d2HTv5dJV', content=[TextBlock(text='# IBISWorld | Healthcare and Social Assistance in the US Mar 2024\n\n## 2. At a Glance\n\nhttps://my.ibisworld.com/us/en/industry/62/at-a-glance\n\nRevenue for the Healthcare and Social Assistance industry in the US is $3.6tr. From 2019 to 2024, revenue increased by 0.7%, and it is projected to grow by 2.7% from 2024 to 2029.\n\nThe industry employs 24m people. Employee numbers grew by 0.9% from 2019 to 2024 and are expected to increase by 2.3% from 2024 to 2029.\n\nThere are 3m businesses in this sector. The number of businesses increased by 1.2% from 2019 to 2024 and is forecast to grow by 2.0% from 2024 to 2029.\n\nThe profit for the industry stands at $355.5bn, showing a growth of 0.1% from 2019 to 2024.\n\nThe profit margin is 10.0%, which decreased by 0.3 percentage points from 2019 to 2024.\n\nWages in the industry amount to $1.4tr. Wages increased by 1.2% from 2019 to 2024 and are projected to grow by 2.4% from 2024 to 2029.\n\n## Key Takeaways\n\n### Performance\n\n- COVID-19 created unprecedented challenges for healthcare and social assistance providers. Staffing shortages and rising costs continue to impact providers and businesses.\n- Healthcare and social assistance providers are vital to older adults. As these people continue to age, their expanding and complex medical needs will require various health and social services.\n\n### External Environment\n\n- Healthcare and social assistance facilities operate within one of the most regulated environments. A dizzying amount of federal, state and local laws apply in this sector, enforced by multiple agencies and regulators.\n- Healthcare providers received over $200.0 billion to ease pandemic-related financial and operational pressures. Since pandemic relief fizzled out, healthcare facilities have faced unprecedented financial strain.', type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=2083, output_tokens=495))
# # IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# ## 2. At a Glance
#
# https://my.ibisworld.com/us/en/industry/62/at-a-glance
#
# Revenue for the Healthcare and Social Assistance industry in the US is $3.6tr. From 2019 to 2024, revenue increased by 0.7%, and it is projected to grow by 2.7% from 2024 to 2029.
#
# The industry employs 24m people. Employee numbers grew by 0.9% from 2019 to 2024 and are expected to increase by 2.3% from 2024 to 2029.
#
# There are 3m businesses in this sector. The number of businesses increased by 1.2% from 2019 to 2024 and is forecast to grow by 2.0% from 2024 to 2029.
#
# The profit for the industry stands at $355.5bn, showing a growth of 0.1% from 2019 to 2024.
#
# The profit margin is 10.0%, which decreased by 0.3 percentage points from 2019 to 2024.
#
# Wages in the industry amount to $1.4tr. Wages increased by 1.2% from 2019 to 2024 and are projected to grow by 2.4% from 2024 to 2029.
#
# ## Key Takeaways
#
# ### Performance
#
# - COVID-19 created unprecedented challenges for healthcare and social assistance providers. Staffing shortages and rising costs continue to impact providers and businesses.
# - Healthcare and social assistance providers are vital to older adults. As these people continue to age, their expanding and complex medical needs will require various health and social services.
#
# ### External Environment
#
# - Healthcare and social assistance facilities operate within one of the most regulated environments. A dizzying amount of federal, state and local laws apply in this sector, enforced by multiple agencies and regulators.
# - Healthcare providers received over $200.0 billion to ease pandemic-related financial and operational pressures. Since pandemic relief fizzled out, healthcare facilities have faced unprecedented financial strain.
# Message(id='msg_01DBtVQDUw3xFRKwDrgJXYc6', content=[TextBlock(text="# IBISWorld | Healthcare and Social Assistance in the US Mar 2024\n\n## Products and Services\n\n### Products & Services Segmentation\nIndustry revenue in 2024 broken down by key product and service lines.\n\nThe image shows a donut chart representing the segmentation of products and services in the Healthcare and Social Assistance industry in the US for 2024. The chart is divided into four segments, each representing a different sector of the industry:\n\n1. Hospitals ($1.5tr): This segment occupies the largest portion of the chart, representing 41.7% of the industry revenue.\n\n2. Ambulatory healthcare services ($1.4tr): This is the second-largest segment, accounting for 40.7% of the industry revenue.\n\n3. Nursing homes and residential facilities ($330.6bn): This segment represents 9.3% of the industry revenue.\n\n4. Social assistance ($295.1bn): This is the smallest segment, comprising 8.3% of the industry revenue.\n\nThe chart provides a clear visual representation of the relative sizes of these four sectors within the Healthcare and Social Assistance industry. Hospitals and ambulatory healthcare services dominate the industry, together accounting for over 82% of the total revenue. Nursing homes and residential facilities, along with social assistance, make up the remaining 17.6% of the industry revenue.\n\nThis segmentation offers insights into the structure of the US healthcare and social assistance market, highlighting the significant role of hospitals and ambulatory services in the industry's revenue generation.\n\nSource: IBISWorld", type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=2083, output_tokens=336))
# # IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# ## Products and Services
#
# ### Products & Services Segmentation
# Industry revenue in 2024 broken down by key product and service lines.
#
# The image shows a donut chart representing the segmentation of products and services in the Healthcare and Social Assistance industry in the US for 2024. The chart is divided into four segments, each representing a different sector of the industry:
#
# 1. Hospitals ($1.5tr): This segment occupies the largest portion of the chart, representing 41.7% of the industry revenue.
#
# 2. Ambulatory healthcare services ($1.4tr): This is the second-largest segment, accounting for 40.7% of the industry revenue.
#
# 3. Nursing homes and residential facilities ($330.6bn): This segment represents 9.3% of the industry revenue.
#
# 4. Social assistance ($295.1bn): This is the smallest segment, comprising 8.3% of the industry revenue.
#
# The chart provides a clear visual representation of the relative sizes of these four sectors within the Healthcare and Social Assistance industry. Hospitals and ambulatory healthcare services dominate the industry, together accounting for over 82% of the total revenue. Nursing homes and residential facilities, along with social assistance, make up the remaining 17.6% of the industry revenue.
#
# This segmentation offers insights into the structure of the US healthcare and social assistance market, highlighting the significant role of hospitals and ambulatory services in the industry's revenue generation.
#
# Source: IBISWorld
# Message(id='msg_01HYnaGj3EKPuHsMBWsogQtj', content=[TextBlock(text='# IBISWorld | Healthcare and Social Assistance in the US\n\n## Major Players\n\n### Major Players\n\nThe image contains a donut chart representing the major players in the Healthcare and Social Assistance industry in the US. The chart provides a breakdown of market share for different companies:\n\n- Hca Healthcare, Inc. holds the largest share among the named companies with 1.5% of the market, representing $52.6bn in value.\n- Quest Diagnostics Inc. follows with 0.3% market share, equivalent to $10.3bn.\n- Feeding America has a 0.1% market share, valued at $3.4bn.\n- Brookdale Senior Living Inc. also holds a 0.1% market share, with a value of $3.3bn.\n- The majority of the market, 98.0%, is held by Other Companies, representing $3.5tr in value.\n\nThis distribution indicates a highly fragmented market where the top named companies collectively hold only 2% of the market share, while the vast majority is distributed among numerous other companies.\n\nSource: IBISWorld\n\n11', type='text')], model='claude-3-5-sonnet-20240620', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(input_tokens=2083, output_tokens=247))
# # IBISWorld | Healthcare and Social Assistance in the US
#
# ## Major Players
#
# ### Major Players
#
# The image contains a donut chart representing the major players in the Healthcare and Social Assistance industry in the US. The chart provides a breakdown of market share for different companies:
#
# - Hca Healthcare, Inc. holds the largest share among the named companies with 1.5% of the market, representing $52.6bn in value.
# - Quest Diagnostics Inc. follows with 0.3% market share, equivalent to $10.3bn.
# - Feeding America has a 0.1% market share, valued at $3.4bn.
# - Brookdale Senior Living Inc. also holds a 0.1% market share, with a value of $3.3bn.
# - The majority of the market, 98.0%, is held by Other Companies, representing $3.5tr in value.
#
# This distribution indicates a highly fragmented market where the top named companies collectively hold only 2% of the market share, while the vast majority is distributed among numerous other companies.
#
# Source: IBISWorld
#
# 11
# # IBISWorld
#
# ## INDUSTRY REPORT
#
# # Healthcare and Social Assistance in the US
#
# ## Mar 2024
#
# The image shows the cover page of an industry report by IBISWorld. The report focuses on Healthcare and Social Assistance in the US, and is dated March 2024. The title and information are presented on a dark blue background with red circular design elements in the corners and bottom of the page. The IBISWorld logo, featuring white text on a red background, is prominently displayed at the top left corner of the page.
# # IBISWorld | Healthcare and Social Assistance in the US
#
# *Mar 2024*
#
# ## About IBISWorld
#
# IBISWorld specializes in industry research with coverage on thousands of global industries. Our comprehensive data and in-depth analysis help businesses of all types gain quick and actionable insights on industries around the world. Busy professionals can spend less time researching and preparing for meetings, and more time focused on making strategic business decisions.
# # IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
# ## Table Of Contents
#
# Standard
#
# 1. About............................................................ 5
#    Codes............................................................5
#    Definition....................................................... 5
#    Related Terms.............................................. 5
#    What's Included............................................ 6
#    Companies....................................................6
#    Related Industries......................................... 6
#    Additional Resources.................................... 6
#
# 2. At a Glance...................................................9
#    Key Takeaways.............................................9
#    Products and Services................................ 10
#    Major Players.............................................. 11
#    Key External Drivers................................... 12
#    Industry Structure........................................ 12
#    SWOT......................................................... 13
#    Executive Summary.................................... 13
#
# 3. Performance............................................... 15
#    Highlights.................................................... 15
#    Key Takeaways........................................... 15
#    Performance Snapshot............................... 16
#    Outlook........................................................25
#    Life Cycle.................................................... 28
#
# 4. Products and Markets.................................30
#    Key Takeaways...........................................30
#    Products and Services................................ 30
#    Major Markets............................................. 35
#    International Trade......................................37
#
# 5. Geographic Breakdown.............................. 39
#    Key Takeaways...........................................39
#    Business Locations..................................... 40
#
# 6. Competitive Forces.....................................46
#    Key Takeaways...........................................46
#    Concentration..............................................46
#    Barriers to Entry.......................................... 47
#    Substitutes.................................................. 48
#    Buyer & Supplier Power..............................49
#
# 7. Companies................................................. 52
#    Key Takeaways...........................................52
#    Market Share.............................................. 53
#    Companies..................................................54
#
# 8. External Environment................................. 67
#    Key Takeaways...........................................67
#    External Drivers.......................................... 67
#    Regulation & Policy..................................... 69
#    Assistance...................................................71
#
# 9. Financial Benchmarks................................ 73
#    Key Takeaways...........................................73
#    Cost Structure............................................. 73
#    Key Ratios...................................................74
#
# 10. Key Statistics............................................ 77
#     Industry Data...............................................77
#
# The image displays a detailed table of contents for a report on Healthcare and Social Assistance in the US. The table is divided into 10 main sections, each with various subsections. The sections cover a wide range of topics including an overview, industry performance, products and markets, geographic breakdown, competitive forces, companies, external environment, financial benchmarks, and key statistics. Each section and subsection is accompanied by its corresponding page number, indicating a comprehensive and well-structured report. The page number at the bottom right corner suggests this is page 3 of the report.
# # About
#
# A quick definition of the industry, its products and services, major companies and other key identifiers help you confirm you're in the right place.
#
# The image shows a page with a bright red background. In the bottom right corner of the page, there is a large, stylized number "1" in a lighter shade of red, creating a subtle contrast with the background. The text "About" is prominently displayed in white in the bottom left quadrant of the page, followed by a brief description in smaller white text. The page number "4" is visible in the bottom right corner.
#
# This page appears to be an introductory or section divider page in a report or presentation, designed to provide a brief overview of what follows. The stark color scheme and minimalist design draw attention to the text and create a bold visual impact.
# # 1. About
#
# https://my.ibisworld.com/us/en/industry/62/about
#
# ## Codes
#
# | NAICS 2017 - USA | 62 |
# |------------------|------|
# | NAICS 2022 - USA | 62 |
#
# The table shows the NAICS (North American Industry Classification System) codes for the Healthcare and Social Assistance sector in the USA. Both the 2017 and 2022 versions of NAICS assign the code 62 to this sector, indicating no change in classification between these years.
#
# ## Definition
#
# The Healthcare and Social Assistance sector is composed of enterprises that provide healthcare and social assistance for individuals in the United States, including hospitals, ambulatory service providers and nursing and residential care facilities. Social assistance also includes counselors and social workers, family and welfare services and natural disaster and emergency relief services.
#
# ## Related Terms
#
# ### ELECTRONIC HEALTH RECORD (EHR)
#
# The systematic collection and maintenance of electronic health information about an individual patient.
#
# ### TELEMEDICINE
#
# An application of clinical medicine whereby medical information is transferred through interactive audiovisual media for the purpose of consulting and remote medical procedures or examinations.
#
# ### HEALTH INSURANCE EXCHANGE
#
# A set of state-regulated and standardized healthcare plans from which individuals may purchase health insurance eligible for federal subsidies.
#
# ### FEE-FOR-SERVICE
#
# A health plan where individuals choose the doctor, hospital or clinic and the insurance pays for part or all of the cost according to a schedule laid out in the policy.
#
# ### MEDICARE AND MEDICAID
#
# Cost-coverage programs. Medicare pays all or part of a stay following hospitalization of at least three days; Medicaid covers a stay of any length for individuals who meet income requirements.
#
# ### LONG-TERM CARE
#
# Treatment for a chronic condition, trauma, or illness that limits a person's ability to carry out basic self-care tasks, called activities of daily living (ADLs).
#
# ### FEDERAL EMERGENCY MANAGEMENT AGENCY (FEMA)
#
# A federal agency designed to prepare for, mitigate against, respond to and help individuals and communities recover from natural and man-made disasters.
# # IBISWorld | Healthcare and Social Assistance in the US
#
# Mar 2024
#
# ## GROUP HOME
#
# A private residence designed to serve as a nonsecure home for unrelated persons who share a common characteristic.
#
# ## MANAGED CARE
#
# A system of financing and delivering healthcare to enrollees intended to reduce the cost of providing health benefits and improve the quality of care.
#
# ## What's Included
#
# - Ambulatory healthcare services
# - Hospitals
# - Nursing homes and residential care facilities
# - Social assistance
#
# ## Companies
#
# - Hca Healthcare, Inc.
# - Quest Diagnostics Inc.
# - Feeding America
# - Brookdale Senior Living Inc.
# - Fresenius Kabi AG
#
# ## Related Industries
#
# ### Industries in the Same Sector
#
# - Competitors:
#   - No data available
#
# - Complementors:
#   - Wholesale Trade in the US
#   - Information in the US
#   - Educational Services in the US
#
# ### International Industries
#
# - Global Life & Health Insurance Carriers
# - Hospitals in Canada
# - Hospitals in Mexico
#
# ## Additional Resources
#
# - Centers for Medicare & Medicaid Services
# - Centers for Disease Control and Prevention
#
# 6
# # IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# - Henry J. Kaiser Family Foundation
# - National Institutes of Health
# - American Medical Association
# - Federal Emergency Management Agency
#
# The image displays a page from a market research report titled "Healthcare and Social Assistance in the US" by IBISWorld, dated March 2024. The page contains a list of four organizations related to healthcare and social assistance in the United States. These organizations are likely key players or important sources of information in the healthcare and social assistance sector. The list is presented in a simple bullet point format, indicating equal importance or no particular hierarchical order among these entities.
#
# At the bottom right corner of the page, there is a page number "7", suggesting this is the seventh page of the report.
# # At a Glance
#
# Evaluate key industry data and trends
# and get an overview of important
# report sections to use in meetings
# and presentations.
#
# The image shows a page with a bright red background. In the lower right corner of the page, there is a large, semi-transparent numeral "2" that spans most of the height of the page. The text "At a Glance" appears in large white letters in the top left portion of the page, followed by a brief description in smaller white text. At the bottom right corner, there is a small white "8", likely indicating this is page 8 of a document.
# # IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# ## 2. At a Glance
#
# https://my.ibisworld.com/us/en/industry/62/at-a-glance
#
# Revenue for the Healthcare and Social Assistance industry in the US is $3.6tr. From 2019 to 2024, revenue increased by 0.7%, and it is projected to grow by 2.7% from 2024 to 2029.
#
# The industry employs 24m people. Employee numbers grew by 0.9% from 2019 to 2024 and are expected to increase by 2.3% from 2024 to 2029.
#
# There are 3m businesses in this sector. The number of businesses increased by 1.2% from 2019 to 2024 and is forecast to grow by 2.0% from 2024 to 2029.
#
# The profit for the industry stands at $355.5bn, showing a growth of 0.1% from 2019 to 2024.
#
# The profit margin is 10.0%, which decreased by 0.3 percentage points from 2019 to 2024.
#
# Wages in the industry amount to $1.4tr. Wages increased by 1.2% from 2019 to 2024 and are projected to grow by 2.4% from 2024 to 2029.
#
# ## Key Takeaways
#
# ### Performance
#
# - COVID-19 created unprecedented challenges for healthcare and social assistance providers. Staffing shortages and rising costs continue to impact providers and businesses.
# - Healthcare and social assistance providers are vital to older adults. As these people continue to age, their expanding and complex medical needs will require various health and social services.
#
# ### External Environment
#
# - Healthcare and social assistance facilities operate within one of the most regulated environments. A dizzying amount of federal, state and local laws apply in this sector, enforced by multiple agencies and regulators.
# - Healthcare providers received over $200.0 billion to ease pandemic-related financial and operational pressures. Since pandemic relief fizzled out, healthcare facilities have faced unprecedented financial strain.
# # IBISWorld | Healthcare and Social Assistance in the US Mar 2024
#
# ## Products and Services
#
# ### Products & Services Segmentation
# Industry revenue in 2024 broken down by key product and service lines.
#
# The image shows a donut chart representing the segmentation of products and services in the Healthcare and Social Assistance industry in the US for 2024. The chart is divided into four segments, each representing a different sector of the industry:
#
# 1. Hospitals ($1.5tr): This segment occupies the largest portion of the chart, representing 41.7% of the industry revenue.
#
# 2. Ambulatory healthcare services ($1.4tr): This is the second-largest segment, accounting for 40.7% of the industry revenue.
#
# 3. Nursing homes and residential facilities ($330.6bn): This segment represents 9.3% of the industry revenue.
#
# 4. Social assistance ($295.1bn): This is the smallest segment, comprising 8.3% of the industry revenue.
#
# The chart provides a clear visual representation of the relative sizes of these four sectors within the Healthcare and Social Assistance industry. Hospitals and ambulatory healthcare services dominate the industry, together accounting for over 82% of the total revenue. Nursing homes and residential facilities, along with social assistance, make up the remaining 17.6% of the industry revenue.
#
# This segmentation offers insights into the structure of the US healthcare and social assistance market, highlighting the significant role of hospitals and ambulatory services in the industry's revenue generation.
#
# Source: IBISWorld
# # IBISWorld | Healthcare and Social Assistance in the US
#
# ## Major Players
#
# ### Major Players
#
# The image contains a donut chart representing the major players in the Healthcare and Social Assistance industry in the US. The chart provides a breakdown of market share for different companies:
#
# - Hca Healthcare, Inc. holds the largest share among the named companies with 1.5% of the market, representing $52.6bn in value.
# - Quest Diagnostics Inc. follows with 0.3% market share, equivalent to $10.3bn.
# - Feeding America has a 0.1% market share, valued at $3.4bn.
# - Brookdale Senior Living Inc. also holds a 0.1% market share, with a value of $3.3bn.
# - The majority of the market, 98.0%, is held by Other Companies, representing $3.5tr in value.
#
# This distribution indicates a highly fragmented market where the top named companies collectively hold only 2% of the market share, while the vast majority is distributed among numerous other companies.
#
# Source: IBISWorld
#
# 11
